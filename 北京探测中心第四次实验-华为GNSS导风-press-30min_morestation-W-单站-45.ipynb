# %%
import xarray as xr
import pandas as pd
import numpy as np
import time

def haversine(lon1, lat1, lon2, lat2):
    """
    使用Haversine公式计算两个经纬度点之间的距离（单位：公里）。
    """
    # 将十进制度数转化为弧度
    lon1, lat1, lon2, lat2 = map(np.radians, [lon1, lat1, lon2, lat2])

    # haversine公式
    dlon = lon2 - lon1
    dlat = lat2 - lat1
    a = np.sin(dlat/2)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon/2)**2
    c = 2 * np.arcsin(np.sqrt(a))
    r = 6371 # 地球平均半径，单位为公里
    return c * r

def prepare_transformer_inputs_mem_efficient_robust(gnss_ds: xr.Dataset, wind_ds: xr.Dataset):
    """
    更稳健的版本，处理时间戳 dtype 不匹配的问题。
    (此函数无需任何修改)
    """
    start_time = time.time()
    
    gnss_ztd = gnss_ds['ztd']
    wind_u = wind_ds['W']
    
    sequence_length = 6
    time_step = pd.to_timedelta('5min')
    expected_duration = time_step * (sequence_length - 1)

    num_gnss_times = len(gnss_ztd.time)
    
    # --- Pass 1: 扫描并找到所有有效样本的起始索引 ---
    print("Pass 1: 正在扫描有效的连续序列 (稳健模式)...")
    
    gnss_dtype = gnss_ztd.time.dtype
    wind_dtype = wind_u.Datetime.dtype
    print(f"GNSS 时间 dtype: {gnss_dtype}, Wind 时间 dtype: {wind_dtype}")
    wind_dtype_unit = np.datetime_data(wind_dtype)[0]

    valid_start_indices = []
    wind_times_set = set(wind_u.Datetime.values)

    for i in range(num_gnss_times - sequence_length + 1):
        window_times = gnss_ztd.time[i : i + sequence_length]
        
        actual_duration = window_times[-1].values - window_times[0].values
        if np.abs(actual_duration - expected_duration) < pd.to_timedelta('1s'):
            
            target_wind_time_raw = window_times[-1].values + 6*time_step
            target_wind_time_converted = np.datetime64(target_wind_time_raw, wind_dtype_unit)

            if target_wind_time_converted in wind_times_set:
                valid_start_indices.append(i)
    
    num_samples = len(valid_start_indices)
    print(f"Pass 1 完成. 共找到 {num_samples} 个有效样本。耗时: {time.time() - start_time:.2f} 秒。")

    if num_samples == 0:
        print("在稳健模式下仍然未找到任何有效序列。请检查数据本身，例如风场数据是否覆盖了GNSS数据的时间范围。")
        return None, None

    # --- 内存分配 (Pass 2) ---
    print("正在预分配内存...")
    num_stations_gnss = len(gnss_ztd.station)
    num_stations_wind = len(wind_u.station)
    num_press_levels = len(wind_u.PRESS)
    
    vx_data = np.empty((num_samples, sequence_length, num_stations_gnss), dtype=np.float32)
    vy_data = np.empty((num_samples, num_stations_wind * num_press_levels), dtype=np.float32)

    print("Pass 2: 正在填充数据...")
    fill_start_time = time.time()
    gnss_ztd_values = gnss_ztd.values
    
    for k, start_idx in enumerate(valid_start_indices):
        end_idx = start_idx + sequence_length
        vx_data[k, :, :] = gnss_ztd_values[start_idx:end_idx, :]
        
        last_gnss_time = gnss_ztd.time[end_idx - 1]
        target_wind_time = last_gnss_time.values + 6*time_step
        
        target_wind_time_converted = np.datetime64(target_wind_time, wind_dtype_unit)
        vy_slice_values = wind_u.sel(Datetime=target_wind_time_converted).values
        vy_data[k, :] = vy_slice_values.flatten()
        
    print(f"Pass 2 完成. 数据填充完毕。耗时: {time.time() - fill_start_time:.2f} 秒。")

    print("正在创建最终的 xarray.DataArray...")
    sample_coords = gnss_ztd.time.values[valid_start_indices]
    vx = xr.DataArray(
        vx_data,
        dims=('sample', 'timesteps', 'station'),
        coords={'sample': sample_coords, 'timesteps': np.arange(sequence_length), 'station': gnss_ztd.station.values}
    )

    vy_flat_coords = wind_u.stack(station_press_flat=('station', 'PRESS')).coords['station_press_flat']
    vy = xr.DataArray(
        vy_data,
        dims=('sample', 'station_press_flat'),
        coords={'sample': sample_coords, 'station_press_flat': vy_flat_coords}
    )
    
    total_time = time.time() - start_time
    print(f"所有处理完成！总耗时: {total_time:.2f} 秒。")
    return vx, vy

# --- 主程序 ---
if __name__ == '__main__':
    # 1. 定义文件路径和目标站点信息
    gnss_nc_path = r'E:/gnss_ztd_combined_robust_morestation.nc'
    wind_nc_path = r'E:/merged_stations_6min_common_period_float32_no_nan_press.nc'
    gnss_info_path = r'E:\huawei_gnss_morestation\zj_allid.csv'
    
    target_wind_station_id = 58557 
    target_wind_station_lon = 120.0717
    target_wind_station_lat = 29.3619
    
    num_nearest_stations = 45 

    # 2. 加载原始数据文件
    print("正在加载原始数据文件...")
    gnss_file = xr.open_dataset(gnss_nc_path)
    wind_file = xr.open_dataset(wind_nc_path)
    gnss_info_df = pd.read_csv(gnss_info_path)
    print("文件加载完毕。")

    # 3. 对原始数据进行预处理（插值、填充等）
    print("正在对原始数据进行预处理...")
    wind_new_time = pd.date_range(wind_file.Datetime.values[0], wind_file.Datetime.values[-1], freq='5min')
    wind_file = wind_file.interp(Datetime=wind_new_time)
    gnss_file = gnss_file.interpolate_na(dim='time')
    gnss_file = gnss_file.ffill(dim='time').bfill(dim='time')
    print("预处理完成。")

    # 4. MODIFIED LOGIC: 寻找实际存在于数据中的最近10个GNSS站点
    print("\n--- 开始筛选站点 (新逻辑) ---")
    print(f"目标风场站点: {target_wind_station_id}")
    print(f"使用预设的目标站点经纬度: Lon={target_wind_station_lon}, Lat={target_wind_station_lat}")

    # 步骤 4.1: 获取gnss数据文件中实际存在的所有站点ID
    available_gnss_in_nc = gnss_file.station.values
    print(f"在GNSS数据文件中找到 {len(available_gnss_in_nc)} 个可用站点。")

    # 步骤 4.2: 从CSV站点信息中，只保留那些实际存在于gnss数据文件中的站点
    gnss_info_df['id'] = gnss_info_df['id'].astype(str)
    # 使用.copy()避免SettingWithCopyWarning
    valid_stations_info_df = gnss_info_df[gnss_info_df['id'].isin(available_gnss_in_nc)].copy()
    if valid_stations_info_df.empty:
        raise ValueError("CSV站点信息文件和GNSS数据文件之间没有共同的站点。")
    print(f"在CSV和GNSS数据文件中共有 {len(valid_stations_info_df)} 个共同站点。")


    # 步骤 4.3: 在这个有效站点子集上计算到目标的距离
    valid_stations_info_df['distance_km'] = valid_stations_info_df.apply(
        lambda row: haversine(target_wind_station_lon, target_wind_station_lat, row['lon'], row['lat']),
        axis=1
    )

    # 步骤 4.4: 按距离排序并选出最近的N个
    # 检查可用站点是否少于期望数量
    if len(valid_stations_info_df) < num_nearest_stations:
        print(f"警告: 可用站点总数 ({len(valid_stations_info_df)}) 小于期望的数量 ({num_nearest_stations})。将使用所有可用的站点。")
        num_to_select = len(valid_stations_info_df)
    else:
        num_to_select = num_nearest_stations

    nearest_stations_df = valid_stations_info_df.sort_values(by='distance_km').head(num_to_select)
    final_gnss_selection = nearest_stations_df['id'].tolist()
    
    print(f"找到的最近 {len(final_gnss_selection)} 个GNSS站点: {final_gnss_selection}")
    print("站点筛选完成。")


    # 5. 根据筛选出的站点ID来过滤xarray数据集
    print("\n--- 正在根据筛选结果过滤数据集 ---")
    
    # 确保目标站点存在于wind_file中
    if target_wind_station_id not in wind_file.station.values:
        raise ValueError(f"目标站点 {target_wind_station_id} 在风场数据中未找到!")

    gnss_file_filtered = gnss_file.sel(station=final_gnss_selection)
    wind_file_filtered = wind_file.sel(station=[target_wind_station_id])

    print("数据集过滤完成。")
    print(f"  - 过滤后GNSS数据站点数: {len(gnss_file_filtered.station)}")
    print(f"  - 过滤后风场数据站点数: {len(wind_file_filtered.station)}")

    # 6. 调用核心处理函数
    print("\n--- 开始调用数据准备函数 ---")
    vx, vy = prepare_transformer_inputs_mem_efficient_robust(gnss_file_filtered, wind_file_filtered)

    # 7. 打印最终结果
    if vx is not None and vy is not None:
        print("\n--- 处理后结果 ---")
        print("输入变量 vx:")
        print(f"  - 形状: {vx.shape}")
        print(f"  - 维度: {vx.dims}")
        print(f"  - 站点: {vx.station.values}")
        print(f"  - 内存占用: {vx.nbytes / 1e6:.2f} MB")
        
        print("\n目标变量 vy:")
        print(f"  - 形状: {vy.shape}")
        print(f"  - 维度: {vy.dims}")
        vy_station = vy.station_press_flat.to_index().get_level_values('station').unique().to_list()
        print(f"  - 站点: {vy_station}")
        print(f"  - 内存占用: {vy.nbytes / 1e6:.2f} MB")
# Out:
# 正在加载原始数据文件...
# 文件加载完毕。
# 正在对原始数据进行预处理...
# 预处理完成。
#
# --- 开始筛选站点 (新逻辑) ---
# 目标风场站点: 58557
# 使用预设的目标站点经纬度: Lon=120.0717, Lat=29.3619
# 在GNSS数据文件中找到 1215 个可用站点。
# 在CSV和GNSS数据文件中共有 1215 个共同站点。
# 找到的最近 45 个GNSS站点: ['H992830', 'H998276', 'H11705423', 'H11705435', 'H792737', 'H892451', 'H992254', 'H11705447', 'H11705440', 'H892504', 'H998585', 'H997648', 'H992221', 'H998596', 'H11705442', 'H11705404', 'H798684', 'H997915', 'H997714', 'H11705408', 'H892866', 'H992792', 'H992154', 'H991217', 'H998172', 'H997618', 'H992023', 'H756621', 'H999268', 'H990477', 'H999166', 'H756021', 'H996453', 'H990638', 'H998429', 'H990413', 'H999194', 'H991454', 'H999941', 'H999072', 'H990004', 'H799390', 'H990379', 'H999070', 'H990896']
# 站点筛选完成。
#
# --- 正在根据筛选结果过滤数据集 ---
# 数据集过滤完成。
#   - 过滤后GNSS数据站点数: 45
#   - 过滤后风场数据站点数: 1
#
# --- 开始调用数据准备函数 ---
# Pass 1: 正在扫描有效的连续序列 (稳健模式)...
# GNSS 时间 dtype: datetime64[ns], Wind 时间 dtype: datetime64[ns]
# Pass 1 完成. 共找到 17594 个有效样本。耗时: 19.22 秒。
# 正在预分配内存...
# Pass 2: 正在填充数据...
# Pass 2 完成. 数据填充完毕。耗时: 10.54 秒。
# 正在创建最终的 xarray.DataArray...
# 所有处理完成！总耗时: 29.77 秒。
#
# --- 处理后结果 ---
# 输入变量 vx:
#   - 形状: (17594, 6, 45)
#   - 维度: ('sample', 'timesteps', 'station')
#   - 站点: ['H992830' 'H998276' 'H11705423' 'H11705435' 'H792737' 'H892451' 'H992254'
#  'H11705447' 'H11705440' 'H892504' 'H998585' 'H997648' 'H992221' 'H998596'
#  'H11705442' 'H11705404' 'H798684' 'H997915' 'H997714' 'H11705408'
#  'H892866' 'H992792' 'H992154' 'H991217' 'H998172' 'H997618' 'H992023'
#  'H756621' 'H999268' 'H990477' 'H999166' 'H756021' 'H996453' 'H990638'
#  'H998429' 'H990413' 'H999194' 'H991454' 'H999941' 'H999072' 'H990004'
#  'H799390' 'H990379' 'H999070' 'H990896']
#   - 内存占用: 19.00 MB
#
# 目标变量 vy:
#   - 形状: (17594, 7)
#   - 维度: ('sample', 'station_press_flat')
#   - 站点: [58557]
#   - 内存占用: 0.49 MB

# %%
#Transformer网络
def Auto_Transformer(vy,vx,timestep,model_list,test_size=0.2,valid_size=0.1,k_fold=None,task_mode='regression',if_best_mode='no',modelpath=None,encoder_deep=1,num_heads=2,key_dim=2,ifdropout='no',trans_dropout_rate=0.0,trans_units=64,trans_activation='sigmoid',embedding_num=None,if_weight_initialize='no',weight_initialize_method='TruncatedNormal',weight_initialize_parameter1=0.00,weight_initialize_parameter2=0.05,if_print_model='yes',loss_function='default',optimizer='SGD',metrics='default',if_early_stopping=None,learning_rate=0.01,epochs=2000,batch_size=20,ifrandom_split='yes',ifweight='yes',ifmute='no',ifsave='no',savepath=None,device='cpu'):
    import tensorflow as tf
    if device=='gpu':
        gpus = tf.config.list_physical_devices('GPU')
        if gpus:
            try:
                # 设置只使用 GPU 0
                tf.config.set_visible_devices(gpus[0], 'GPU')
                # 设置 GPU 0 的内存动态增长
                tf.config.experimental.set_memory_growth(gpus[0], True)
            except RuntimeError as e:
                print(e)
    else:
        os.environ["CUDA_VISIBLE_DEVICES"] = "-1"
    from keras.models import Sequential,Model
    from keras.layers.core import Activation,Dropout,Dense
    from keras.layers import Input,BatchNormalization,LayerNormalization,Embedding,Add,MultiHeadAttention,Flatten
    from keras.initializers import TruncatedNormal,RandomNormal,RandomUniform
    from sklearn.model_selection import train_test_split
    from sklearn.model_selection import KFold
    import numpy as np
    from tensorflow.keras.optimizers import SGD,Adam
    import keras
    from scipy.stats import pearsonr
    import os
    from sklearn.metrics import accuracy_score,recall_score,precision_score,f1_score
    from keras.models import load_model
    import sklearn
    import copy
    from sklearn.utils.class_weight import compute_class_weight
    from tensorflow.keras import backend as K
    import warnings
    warnings.filterwarnings("ignore")
    
    if embedding_num==None:
        embedding_num=timestep+1
    if task_mode=='regression':
        if loss_function=='default' or loss_function=='MeanSquaredError':
            loss=tf.keras.losses.MeanSquaredError()
        elif loss_function=='MeanSquaredError':
            loss=tf.keras.losses.MeanSquaredError()
        elif loss_function=='MeanAbsoluteError':
            loss=tf.keras.losses.MeanAbsoluteError()
        elif loss_function=='MeanAbsolutePercentageError':
            loss=tf.keras.losses.MeanAbsolutePercentageError()
        elif loss_function=='MeanSquaredLogarithmicError':
            loss=tf.keras.losses.MeanSquaredLogarithmicError()
        elif loss_function=='CosineSimilarity':
            loss=tf.keras.losses.CosineSimilarity()
        elif loss_function=='Huber':
            loss=tf.keras.losses.Huber()
        elif loss_function=='LogCosh':
            loss=tf.keras.losses.LogCosh()
        elif loss_function=='Pearsonr':
            def loss_pearsonr(y_true,y_pred):
                import tensorflow as tf
                y_true_mean=tf.reduce_mean(y_true,axis=0)
                y_pred_mean=tf.reduce_mean(y_pred,axis=0)
                cov=tf.reduce_sum((y_true-y_true_mean)*(y_pred-y_pred_mean),axis=0)
                y_true_v=tf.reduce_sum(tf.square((y_true-y_true_mean)),axis=0)
                y_pred_v=tf.reduce_sum(tf.square((y_pred-y_pred_mean)),axis=0)
                y_true_v=tf.sqrt(y_true_v)
                y_pred_v=tf.sqrt(y_pred_v)
                pearson=cov/(y_true_v*y_pred_v)
                return (1-pearson)**1.5
            loss=loss_pearsonr
        if metrics=='default' or metrics=='MeanSquaredError':
            metric=tf.keras.metrics.MeanSquaredError()
        elif metrics=='MeanAbsoluteError':
            metric=tf.keras.metrics.MeanAbsoluteError()
        elif metrics=='MeanAbsolutePercentageError':
            metric=tf.keras.metrics.MeanAbsolutePercentageError()
        elif metrics=='MeanSquaredLogarithmicError':
            metric=tf.keras.metrics.MeanSquaredLogarithmicError()
        elif metrics=='CosineSimilarity':
            metric=tf.keras.metrics.CosineSimilarity()
        elif metrics=='LogCoshError':
            metric=tf.keras.metrics.LogCoshError()
        elif metrics=='Pearsonr':
            def metrics_pearsonr(y_true,y_pred):
                import tensorflow as tf
                y_true_mean=tf.reduce_mean(y_true,axis=0)
                y_pred_mean=tf.reduce_mean(y_pred,axis=0)
                cov=tf.reduce_sum((y_true-y_true_mean)*(y_pred-y_pred_mean),axis=0)
                y_true_v=tf.reduce_sum(tf.square((y_true-y_true_mean)),axis=0)
                y_pred_v=tf.reduce_sum(tf.square((y_pred-y_pred_mean)),axis=0)
                y_true_v=tf.sqrt(y_true_v)
                y_pred_v=tf.sqrt(y_pred_v)
                pearson=cov/(y_true_v*y_pred_v)
                return (1-pearson)**1.5
            metric=metrics_pearsonr
    elif task_mode=='binary_classify':
        if loss_function=='default' or loss_function=='BinaryCrossentropy':
            loss=tf.keras.losses.BinaryCrossentropy()
        elif loss_function=='CategoricalCrossentropy':
            loss=tf.keras.losses.CategoricalCrossentropy()
        elif loss_function=='SparseCategoricalCrossentropy':
            loss=tf.keras.losses.SparseCategoricalCrossentropy()
        elif loss_function=='Poisson':
            loss=tf.keras.losses.Poisson()
        elif loss_function=='KLDivergence':
            loss=tf.keras.losses.KLDivergence()
        elif loss_function=='f1':
            def loss_f1(y_true, y_pred):
                y_true = K.cast(y_true, 'float32')
                y_pred = K.cast(y_pred, 'float32')
                
                tp = K.sum(y_true * y_pred)
                fp = K.sum((1 - y_true) * y_pred)
                fn = K.sum(y_true * (1 - y_pred))
                
                precision = tp / (tp + fp + K.epsilon())
                recall = tp / (tp + fn + K.epsilon())
                
                f1 = 2 * precision * recall / (precision + recall + K.epsilon())
                
                return 1 - f1
            loss=loss_f1
        if metrics=='default' or metrics=='BinaryAccuracy':
            metric=tf.keras.metrics.BinaryAccuracy()
        elif metrics=='MeanAbsoluteError':
            metric=tf.keras.metrics.MeanAbsoluteError()
        elif metrics=='Accuracy':
            metric=tf.keras.metrics.Accuracy()
        elif metrics=='CategoricalAccuracy':
            metric=tf.keras.metrics.CategoricalAccuracy()
        elif metrics=='SparseCategoricalAccuracy':
            metric=tf.keras.metrics.SparseCategoricalAccuracy()
        elif metrics=='TopKCategoricalAccuracy':
            metric=tf.keras.metrics.TopKCategoricalAccuracy()
        elif metrics=='SparseTopKCategoricalAccuracy':
            metric=tf.keras.metrics.SparseTopKCategoricalAccuracy()
        elif metrics=='BinaryCrossentropy':
            metric=tf.keras.metrics.BinaryCrossentropy()
        elif metrics=='CategoricalCrossentropy':
            metric=tf.keras.metrics.CategoricalCrossentropy()
        elif metrics=='SparseCategoricalCrossentropy':
            metric=tf.keras.metrics.SparseCategoricalCrossentropy()
        elif metrics=='Accuracy':
            metric=tf.keras.metrics.Accuracy()
        elif metrics=='CategoricalAccuracy':
            metric=tf.keras.metrics.CategoricalAccuracy()
        elif metrics=='SparseCategoricalAccuracy':
            metric=tf.keras.metrics.SparseCategoricalAccuracy()
        elif metrics=='KLDivergence':
            metric=tf.keras.metrics.KLDivergence()
        elif metrics=='Poisson':
            metric=tf.keras.metrics.Poisson()
        elif metrics=='AUC':
            metric=tf.keras.metrics.AUC()
        elif metrics=='Precision':
            metric=tf.keras.metrics.Precision()
        elif metrics=='Recall':
            metric=tf.keras.metrics.Recall()
        elif metrics=='TruePositives':
            metric=tf.keras.metrics.TruePositives()
        elif metrics=='TrueNegatives':
            metric=tf.keras.metrics.TrueNegatives()
        elif metrics=='FalsePositives':
            metric=tf.keras.metrics.FalsePositives()
        elif metrics=='FalseNegatives':
            metric=tf.keras.metrics.FalseNegatives()
        elif metrics=='PrecisionAtRecall':
            metric=tf.keras.metrics.PrecisionAtRecall()
        elif metrics=='SensitivityAtSpecificity':
            metric=tf.keras.metrics.SensitivityAtSpecificity()
        elif metrics=='SpecificityAtSensitivity':
            metric=tf.keras.metrics.SpecificityAtSensitivity()
        elif metrics=='f1':
            def metric_f1(y_true, y_pred):
                y_true = K.cast(y_true, 'float32')
                y_pred = K.cast(y_pred, 'float32')
                
                tp = K.sum(y_true * y_pred)
                fp = K.sum((1 - y_true) * y_pred)
                fn = K.sum(y_true * (1 - y_pred))
                
                precision = tp / (tp + fp + K.epsilon())
                recall = tp / (tp + fn + K.epsilon())
                
                f1 = 2 * precision * recall / (precision + recall + K.epsilon())
                
                return f1
            metric=metric_f1
    elif task_mode=='multi_classify':
        if loss_function=='default' or loss_function=='CategoricalCrossentropy':
            loss=tf.keras.losses.CategoricalCrossentropy()
        elif loss_function=='SparseCategoricalCrossentropy':
            loss=tf.keras.losses.SparseCategoricalCrossentropy()
        elif loss_function=='Poisson':
            loss=tf.keras.losses.Poisson()
        elif loss_function=='KLDivergence':
            loss=tf.keras.losses.KLDivergence()
        if metrics=='default' or metrics=='Accuracy':
            metric=tf.keras.metrics.Accuracy()
        elif metrics=='MeanAbsoluteError':
            metric=tf.keras.metrics.MeanAbsoluteError()
        elif metrics=='CategoricalAccuracy':
            metric=tf.keras.metrics.CategoricalAccuracy()
        elif metrics=='SparseCategoricalAccuracy':
            metric=tf.keras.metrics.SparseCategoricalAccuracy()
        elif metrics=='TopKCategoricalAccuracy':
            metric=tf.keras.metrics.TopKCategoricalAccuracy()
        elif metrics=='SparseTopKCategoricalAccuracy':
            metric=tf.keras.metrics.SparseTopKCategoricalAccuracy()
        elif metrics=='CategoricalCrossentropy':
            metric=tf.keras.metrics.CategoricalCrossentropy()
        elif metrics=='SparseCategoricalCrossentropy':
            metric=tf.keras.metrics.SparseCategoricalCrossentropy()
        elif metrics=='Accuracy':
            metric=tf.keras.metrics.Accuracy()
        elif metrics=='CategoricalAccuracy':
            metric=tf.keras.metrics.CategoricalAccuracy()
        elif metrics=='SparseCategoricalAccuracy':
            metric=tf.keras.metrics.SparseCategoricalAccuracy()
        elif metrics=='KLDivergence':
            metric=tf.keras.metrics.KLDivergence()
        elif metrics=='Poisson':
            metric=tf.keras.metrics.Poisson()
    weights=0
    model=0
    if vy.ndim==1:
        vy=vy.reshape(vy.shape[0],1)
    if ifrandom_split=='yes':
        trainy,testy,trainx,testx = train_test_split(vy,vx,test_size=test_size,random_state=25)
    else:
        index=int((1-test_size)*vy.shape[0])
        trainy=vy[:index]
        testy=vy[index:]
        trainx=vx[:index,:,:]
        testx=vx[index:,:,:]
    train_position=np.zeros((trainx.shape[0],trainx.shape[1]))
    test_position=np.zeros((testx.shape[0],testx.shape[1]))
    for i in range(trainx.shape[0]):
        train_position[i,:]=np.arange(0,timestep,1)
    for i in range(testx.shape[0]):
        test_position[i,:]=np.arange(0,timestep,1)
    if task_mode!='regression':
        def create_sample_weights_for_batch_multitask(y_batch_multitask, list_of_task_weights_dicts):
            batch_size, num_tasks = y_batch_multitask.shape
            
            if len(list_of_task_weights_dicts) != num_tasks:
                raise ValueError(f"Number of tasks in y_batch_multitask ({num_tasks}) "
                                 f"must match length of list_of_task_weights_dicts ({len(list_of_task_weights_dicts)}).")
        
            sample_weight_batch = np.ones_like(y_batch_multitask, dtype=np.float32)
        
            for i in range(num_tasks):
                task_labels_current_channel = y_batch_multitask[:, i] 
                weights_dict_for_task_i = list_of_task_weights_dicts[i]
                
                weight_for_0 = weights_dict_for_task_i.get(0, 1.0)
                weight_for_1 = weights_dict_for_task_i.get(1, 1.0)
                
                current_task_weights = sample_weight_batch[:, i] 
                current_task_weights[task_labels_current_channel == 0] = weight_for_0
                current_task_weights[task_labels_current_channel == 1] = weight_for_1
                sample_weight_batch[:, i] = current_task_weights
                
            return sample_weight_batch
        def compute_unified_class_weights(y, task_mode=task_mode):
            if task_mode == 'binary_classify':
                if y.ndim == 2 and y.shape[-1] > 1:
                    num_tasks = y.shape[-1]
                    list_of_task_weights_dicts = []
                    possible_binary_classes = np.array([0, 1])
                    for i in range(num_tasks):
                        y_task_i_flat = y[:, i].ravel()
                        if len(y_task_i_flat) == 0:
                            weights_dict_task_i = {0: 1.0, 1: 1.0} 
                        else:
                            valid_labels_mask = np.isin(y_task_i_flat, possible_binary_classes)
                            if not np.all(valid_labels_mask) and np.any(valid_labels_mask): 
                                y_task_i_flat_filtered = y_task_i_flat[valid_labels_mask]
                                if len(y_task_i_flat_filtered) == 0 : y_task_i_flat_filtered = np.array([0]) 
                            elif not np.any(valid_labels_mask): 
                                 y_task_i_flat_filtered = np.array([0]) 
                            else:
                                y_task_i_flat_filtered = y_task_i_flat
                            class_weights_arr = compute_class_weight(
                                class_weight='balanced',
                                classes=possible_binary_classes, 
                                y=y_task_i_flat_filtered
                            )
                            weights_dict_task_i = dict(zip(possible_binary_classes, class_weights_arr))
                        list_of_task_weights_dicts.append(weights_dict_task_i)
                    return list_of_task_weights_dicts 
        
                else: 
                    y_flat = y.ravel()
                    possible_binary_classes = np.array([0, 1])
                    valid_labels_mask = np.isin(y_flat, possible_binary_classes)
                    if not np.all(valid_labels_mask) and np.any(valid_labels_mask):
                        y_flat_filtered = y_flat[valid_labels_mask]
                        if len(y_flat_filtered) == 0 : y_flat_filtered = np.array([0])
                    elif not np.any(valid_labels_mask):
                         y_flat_filtered = np.array([0])
                    else:
                        y_flat_filtered = y_flat
        
                    class_weights_arr = compute_class_weight(
                        class_weight='balanced',
                        classes=possible_binary_classes,
                        y=y_flat_filtered
                    )
                    return dict(zip(possible_binary_classes, class_weights_arr)) 
        
            elif task_mode == 'multi_classify':
                y_flat = y.ravel()
                possible_multiclass_classes = np.arange(int(np.max(y)+1))
                valid_labels_mask = np.isin(y_flat, possible_multiclass_classes)
                if not np.all(valid_labels_mask) and np.any(valid_labels_mask):
                    y_flat_filtered = y_flat[valid_labels_mask]
                    if len(y_flat_filtered) == 0 : y_flat_filtered = np.array([0]) 
                elif not np.any(valid_labels_mask):
                    y_flat_filtered = np.array([0]) 
                else:
                    y_flat_filtered = y_flat
                class_weights_arr = compute_class_weight(
                    class_weight='balanced',
                    classes=possible_multiclass_classes,
                    y=y_flat_filtered
                )
                return dict(zip(possible_multiclass_classes, class_weights_arr)) 
            else:
                raise ValueError(f"Unsupported task_mode: {task_mode}")
        def create_unified_sample_weights_for_batch(y_batch, unified_class_weights):
            if isinstance(unified_class_weights, list):
                if not (y_batch.ndim == 2 and y_batch.shape[-1] == len(unified_class_weights)):
                     raise ValueError(f"Shape mismatch for multi-task binary weights. "
                                      f"y_batch shape: {y_batch.shape}, num_weight_dicts: {len(unified_class_weights)}")
                return create_sample_weights_for_batch_multitask(y_batch, unified_class_weights)
            elif isinstance(unified_class_weights, dict):
                y_int_labels_for_weights = y_batch
                if y_batch.ndim == 2 and y_batch.shape[-1] == 1: 
                    y_int_labels_for_weights = np.squeeze(y_batch, axis=-1)
                sample_weight_for_batch = np.ones_like(y_int_labels_for_weights, dtype=np.float32)
                for class_label, weight in unified_class_weights.items():
                    sample_weight_for_batch[y_int_labels_for_weights == class_label] = weight
                
                return sample_weight_for_batch
            else:
                raise TypeError(f"unified_class_weights has unexpected type: {type(unified_class_weights)}. Expected dict or list.")
        def train_data_generator(x,position, y, batch_size, task_mode=task_mode):
            num_samples = x.shape[0]
            global_unified_weights = compute_unified_class_weights(y, task_mode)
            while True:
                indices = np.arange(num_samples)
                
                for start in range(0, num_samples, batch_size):
                    end = min(start + batch_size, num_samples)
                    batch_indices = indices[start:end]
                    
                    if len(batch_indices) == 0:
                        continue
        
                    x_batch = x[batch_indices]
                    position_batch = position[batch_indices]
                    y_batch = y[batch_indices] 
                    sample_weight_batch = create_unified_sample_weights_for_batch(
                        y_batch, 
                        global_unified_weights
                    )
                    yield {"input_1": x_batch, "input_2": position_batch}, y_batch, sample_weight_batch
    else:
        def train_data_generator(x, position, y, batch_size):
            num_samples = x.shape[0]
            while True:
                indices = np.arange(num_samples)
                
                for start in range(0, num_samples, batch_size):
                    end = min(start + batch_size, num_samples)
                    batch_indices = indices[start:end]
                    
                    x_batch = x[batch_indices]  
                    position_batch = position[batch_indices]   
                    y_batch = y[batch_indices]      
                    
                    yield ({"input_1": x_batch, "input_2": position_batch}, y_batch)
    def test_data_generator(x, position, batch_size):
        num_samples = x.shape[0]
        while True:
            indices = np.arange(num_samples)
            
            for start in range(0, num_samples, batch_size):
                end = min(start + batch_size, num_samples)
                batch_indices = indices[start:end]
                
                x_batch = x[batch_indices]  # 第一个输入特征
                position_batch = position[batch_indices]
                
                yield ({"input_1": x_batch, "input_2": position_batch})
    if if_best_mode=='no':
        inputshape1=(None,timestep,trainx.shape[2])
        inputshape2=(None,timestep)
        inputs1=Input(shape=(timestep,trainx.shape[2]))
        inputs2=Input(shape=(timestep))
        for i in range(len(model_list)):
            if model_list[i][0] == 'transformer':
                position_embedding=Embedding(embedding_num,trainx.shape[2],input_length=timestep,input_shape=inputshape2)(inputs2)
                add=Add(input_shape=inputshape1)([inputs1,position_embedding])
                for j in range(encoder_deep):
                    if j ==0:
                        exec('en_multihead'+str(j+1)+'=MultiHeadAttention(num_heads=num_heads,key_dim=key_dim,dropout=trans_dropout_rate,attention_axes=1)(add,add,add)')
                        exec('en_add'+str(j+1)+'=Add()([add,en_multihead'+str(j+1)+'])')
                    else:
                        exec('en_multihead'+str(j+1)+'=MultiHeadAttention(num_heads=num_heads,key_dim=key_dim,dropout=trans_dropout_rate,attention_axes=1)(en_layernormalization'+str(j)+',en_layernormalization'+str(j)+',en_layernormalization'+str(j)+')')
                        exec('en_add'+str(j+1)+'=Add()([en_layernormalization'+str(j)+',en_multihead'+str(j+1)+'])')
                    exec('en_layernormalization'+str(j+1)+'=LayerNormalization()(en_add'+str(j+1)+')')
                    if ifdropout=='yes':
                        exec('en_dropout'+str(j+1)+'=Dropout(trans_dropout_rate)(en_layernormalization'+str(j+1)+')')
                        exec('en_fc'+str(j+1)+'=Dense(trans_units,activation=trans_activation)(en_dropout'+str(j+1)+')')
                        exec('en_fc'+str(j+1)+'=Dense(trainx.shape[2],activation=trans_activation)(en_fc'+str(j+1)+')')
                    else:
                        exec('en_fc'+str(j+1)+'=Dense(trans_units,activation=trans_activation)(en_layernormalization'+str(j+1)+')')
                        exec('en_fc'+str(j+1)+'=Dense(trainx.shape[2],activation=trans_activation)(en_fc'+str(j+1)+')')
                    exec('en_add'+str(j+1)+'=Add()([en_fc'+str(j+1)+',en_layernormalization'+str(j+1)+'])')
                    exec('en_layernormalization'+str(j+1)+'=LayerNormalization()(en_add'+str(j+1)+')')
                exec('en_fla=Flatten()(en_layernormalization'+str(j+1)+')')
            elif model_list[i][0] == 'batchnormalization':
                if i==len(model_list)-1:
                    if model_list[i-1][0]=='transformer':
                        outputs=eval('BatchNormalization(axis=-1)(en_fla)')
                    elif model_list[i-1][0]=='batchnormalization' or model_list[i-1][0]=='layernormalization':
                        outputs=eval('BatchNormalization(axis=-1)(norm'+str(i)+')')
                    elif model_list[i-1][0]=='activation':
                        outputs=eval('BatchNormalization(axis=-1)(act'+str(i)+')')
                    elif model_list[i-1][0]=='dropout' :
                        outputs=eval('BatchNormalization(axis=-1)(drop'+str(i)+')')
                    elif model_list[i-1][0]=='fc':
                        outputs=eval('BatchNormalization(axis=-1)(fc'+str(i)+')')
                    elif model_list[i-1][0]=='flatten':
                        outputs=eval('BatchNormalization(axis=-1)(fla'+str(i)+')')
                else:
                    if model_list[i-1][0]=='transformer':
                        exec('norm'+str(i+1)+'=BatchNormalization(axis=-1)(en_fla)')
                    elif model_list[i-1][0]=='batchnormalization' or model_list[i-1][0]=='layernormalization':
                        exec('norm'+str(i+1)+'=BatchNormalization(axis=-1)(norm'+str(i)+')')
                    elif model_list[i-1][0]=='activation':
                        exec('norm'+str(i+1)+'=BatchNormalization(axis=-1)(act'+str(i)+')')
                    elif model_list[i-1][0]=='dropout' :
                        exec('norm'+str(i+1)+'=BatchNormalization(axis=-1)(drop'+str(i)+')')
                    elif model_list[i-1][0]=='fc':
                        exec('norm'+str(i+1)+'=BatchNormalization(axis=-1)(fc'+str(i)+')')
                    elif model_list[i-1][0]=='flatten':
                        exec('norm'+str(i+1)+'=BatchNormalization(axis=-1)(fla'+str(i)+')')
            elif model_list[i][0] == 'layernormalization':
                if i==len(model_list)-1:
                    if model_list[i-1][0]=='transformer':
                        outputs=eval('LayerNormalization(axis=-1)(en_fla)')
                    elif model_list[i-1][0]=='batchnormalization' or model_list[i-1][0]=='layernormalization':
                        outputs=eval('LayerNormalization(axis=-1)(norm'+str(i)+')')
                    elif model_list[i-1][0]=='activation':
                        outputs=eval('LayerNormalization(axis=-1)(act'+str(i)+')')
                    elif model_list[i-1][0]=='dropout' :
                        outputs=eval('LayerNormalization(axis=-1)(drop'+str(i)+')')
                    elif model_list[i-1][0]=='fc':
                        outputs=eval('LayerNormalization(axis=-1)(fc'+str(i)+')')
                    elif model_list[i-1][0]=='flatten':
                        outputs=eval('LayerNormalization(axis=-1)(fla'+str(i)+')')
                else:
                    if model_list[i-1][0]=='transformer':
                        exec('norm'+str(i+1)+'=LayerNormalization(axis=-1)(en_fla)')
                    elif model_list[i-1][0]=='batchnormalization' or model_list[i-1][0]=='layernormalization':
                        exec('norm'+str(i+1)+'=LayerNormalization(axis=-1)(norm'+str(i)+')')
                    elif model_list[i-1][0]=='activation':
                        exec('norm'+str(i+1)+'=LayerNormalization(axis=-1)(act'+str(i)+')')
                    elif model_list[i-1][0]=='dropout' :
                        exec('norm'+str(i+1)+'=LayerNormalization(axis=-1)(drop'+str(i)+')')
                    elif model_list[i-1][0]=='fc':
                        exec('norm'+str(i+1)+'=LayerNormalization(axis=-1)(fc'+str(i)+')')
                    elif model_list[i-1][0]=='flatten':
                        exec('norm'+str(i+1)+'=LayerNormalization(axis=-1)(fla'+str(i)+')')
            elif model_list[i][0] == 'activation':
                if i==len(model_list)-1:
                    if model_list[i-1][0]=='transformer':
                        outputs=eval('Activation(model_list[i][1])(en_fla)')
                    elif model_list[i-1][0]=='batchnormalization' or model_list[i-1][0]=='layernormalization':
                        outputs=eval('Activation(model_list[i][1])(norm'+str(i)+')')
                    elif model_list[i-1][0]=='activation':
                        outputs=eval('Activation(model_list[i][1])(act'+str(i)+')')
                    elif model_list[i-1][0]=='dropout' :
                        outputs=eval('Activation(model_list[i][1])(drop'+str(i)+')')
                    elif model_list[i-1][0]=='fc':
                        outputs=eval('Activation(model_list[i][1])(fc'+str(i)+')')
                    elif model_list[i-1][0]=='flatten':
                        outputs=eval('Activation(model_list[i][1])(fla'+str(i)+')')
                else:
                    if model_list[i-1][0]=='transformer':
                        exec('act'+str(i+1)+'=Activation(model_list[i][1])(en_fla)')
                    elif model_list[i-1][0]=='batchnormalization' or model_list[i-1][0]=='layernormalization':
                        exec('act'+str(i+1)+'=Activation(model_list[i][1])(norm'+str(i)+')')
                    elif model_list[i-1][0]=='activation':
                        exec('act'+str(i+1)+'=Activation(model_list[i][1])(act'+str(i)+')')
                    elif model_list[i-1][0]=='dropout' :
                        exec('act'+str(i+1)+'=Activation(model_list[i][1])(drop'+str(i)+')')
                    elif model_list[i-1][0]=='fc':
                        exec('act'+str(i+1)+'=Activation(model_list[i][1])(fc'+str(i)+')')
                    elif model_list[i-1][0]=='flatten':
                        exec('act'+str(i+1)+'=Activation(model_list[i][1])(fla'+str(i)+')')
            elif model_list[i][0] == 'flatten':
                if model_list[i-1][0]=='transformer':
                    exec('fla'+str(i+1)+'=Flatten()(en_fla)')
                elif model_list[i-1][0]=='batchnormalization' or model_list[i-1][0]=='layernormalization':
                    exec('fla'+str(i+1)+'=Flatten()(norm'+str(i)+')')
                elif model_list[i-1][0]=='activation':
                    exec('fla'+str(i+1)+'=Flatten()(act'+str(i)+')')
                elif model_list[i-1][0]=='dropout':
                    exec('fla'+str(i+1)+'=Flatten()(drop'+str(i)+')')
            elif model_list[i][0] =='fc':
                if if_weight_initialize=='no':
                    if i==len(model_list)-1:
                        if model_list[i-1][0]=='transformer':
                            outputs=eval('Dense(model_list[i][1])(en_fla)')
                        elif model_list[i-1][0]=='batchnormalization' or model_list[i-1][0]=='layernormalization':
                            outputs=eval('Dense(model_list[i][1])(norm'+str(i)+')')
                        elif model_list[i-1][0]=='activation':
                            outputs=eval('Dense(model_list[i][1])(act'+str(i)+')')
                        elif model_list[i-1][0]=='dropout':
                            outputs=eval('Dense(model_list[i][1])(drop'+str(i)+')')
                        elif model_list[i-1][0]=='fc':
                            outputs=eval('Dense(model_list[i][1])(fc'+str(i)+')')
                        elif model_list[i-1][0]=='flatten':
                            outputs=eval('Dense(model_list[i][1])(fla'+str(i)+')')
                    else:
                        if model_list[i-1][0]=='transformer':
                            exec('fc'+str(i+1)+'=Dense(model_list[i][1])(en_fla)')
                        elif model_list[i-1][0]=='batchnormalization' or model_list[i-1][0]=='layernormalization':
                            exec('fc'+str(i+1)+'=Dense(model_list[i][1])(norm'+str(i)+')')
                        elif model_list[i-1][0]=='activation':
                            exec('fc'+str(i+1)+'=Dense(model_list[i][1])(act'+str(i)+')')
                        elif model_list[i-1][0]=='dropout':
                            exec('fc'+str(i+1)+'=Dense(model_list[i][1])(drop'+str(i)+')')
                        elif model_list[i-1][0]=='fc':
                            exec('fc'+str(i+1)+'=Dense(model_list[i][1])(fc'+str(i)+')')
                        elif model_list[i-1][0]=='flatten':
                            exec('fc'+str(i+1)+'=Dense(model_list[i][1])(fla'+str(i)+')')
                else:
                    if i==len(model_list)-1:
                        if model_list[i-1][0]=='transformer':
                            if weight_initialize_method=='RandomNormal':
                                outputs=eval('Dense(model_list[i][1],kernel_initializer = RandomNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2))(en_fla)')
                            elif weight_initialize_method=='RandomUniform':
                                outputs=eval('Dense(model_list[i][1],kernel_initializer = RandomUniform(minval=weight_initialize_parameter1,maxval=weight_initialize_parameter2))(en_fla)')
                            elif weight_initialize_method=='TruncatedNormal':
                                outputs=eval('Dense(model_list[i][1],kernel_initializer = TruncatedNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2))(en_fla)')
                        elif model_list[i-1][0]=='batchnormalization' or model_list[i-1][0]=='layernormalization':
                            if weight_initialize_method=='RandomNormal':
                                outputs=eval('Dense(model_list[i][1],kernel_initializer = RandomNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2))(norm'+str(i)+')')
                            elif weight_initialize_method=='RandomUniform':
                                outputs=eval('Dense(model_list[i][1],kernel_initializer = RandomUniform(minval=weight_initialize_parameter1,maxval=weight_initialize_parameter2))(norm'+str(i)+')')
                            elif weight_initialize_method=='TruncatedNormal':
                                outputs=eval('Dense(model_list[i][1],kernel_initializer = TruncatedNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2))(norm'+str(i)+')')
                        elif model_list[i-1][0]=='activation':
                            if weight_initialize_method=='RandomNormal':
                                outputs=eval('Dense(model_list[i][1],kernel_initializer = RandomNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2))(act'+str(i)+')')
                            elif weight_initialize_method=='RandomUniform':
                                outputs=eval('Dense(model_list[i][1],kernel_initializer = RandomUniform(minval=weight_initialize_parameter1,maxval=weight_initialize_parameter2))(act'+str(i)+')')
                            elif weight_initialize_method=='TruncatedNormal':
                                outputs=eval('Dense(model_list[i][1],kernel_initializer = TruncatedNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2))(act'+str(i)+')')
                        elif model_list[i-1][0]=='dropout':
                            if weight_initialize_method=='RandomNormal':
                                outputs=eval('Dense(model_list[i][1],kernel_initializer = RandomNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2))(drop'+str(i)+')')
                            elif weight_initialize_method=='RandomUniform':
                                outputs=eval('Dense(model_list[i][1],kernel_initializer = RandomUniform(minval=weight_initialize_parameter1,maxval=weight_initialize_parameter2))(drop'+str(i)+')')
                            elif weight_initialize_method=='TruncatedNormal':
                                outputs=eval('Dense(model_list[i][1],kernel_initializer = TruncatedNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2))(drop'+str(i)+')')
                        elif model_list[i-1][0]=='fc':   
                            if weight_initialize_method=='RandomNormal':
                                outputs=eval('Dense(model_list[i][1],kernel_initializer = RandomNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2))(fc'+str(i)+')')
                            elif weight_initialize_method=='RandomUniform':
                                outputs=eval('Dense(model_list[i][1],kernel_initializer = RandomUniform(minval=weight_initialize_parameter1,maxval=weight_initialize_parameter2))(fc'+str(i)+')')
                            elif weight_initialize_method=='TruncatedNormal':
                                outputs=eval('Dense(model_list[i][1],kernel_initializer = TruncatedNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2))(fc'+str(i)+')')
                        elif model_list[i-1][0]=='flatten':
                            if weight_initialize_method=='RandomNormal':
                                outputs=eval('Dense(model_list[i][1],kernel_initializer = RandomNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2))(fla'+str(i)+')')
                            elif weight_initialize_method=='RandomUniform':
                                outputs=eval('Dense(model_list[i][1],kernel_initializer = RandomUniform(minval=weight_initialize_parameter1,maxval=weight_initialize_parameter2))(fla'+str(i)+')')
                            elif weight_initialize_method=='TruncatedNormal':
                                outputs=eval('Dense(model_list[i][1],kernel_initializer = TruncatedNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2))(fla'+str(i)+')')
                    else:
                        if model_list[i-1][0]=='transformer':
                            if weight_initialize_method=='RandomNormal':
                                exec('fc'+str(i+1)+'=Dense(model_list[i][1],kernel_initializer = RandomNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2))(en_fla)')
                            elif weight_initialize_method=='RandomUniform':
                                exec('fc'+str(i+1)+'=Dense(model_list[i][1],kernel_initializer = RandomUniform(minval=weight_initialize_parameter1,maxval=weight_initialize_parameter2))(en_fla)')
                            elif weight_initialize_method=='TruncatedNormal':
                                exec('fc'+str(i+1)+'=Dense(model_list[i][1],kernel_initializer = TruncatedNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2))(en_fla)')
                        elif model_list[i-1][0]=='batchnormalization' or model_list[i-1][0]=='layernormalization':
                            if weight_initialize_method=='RandomNormal':
                                exec('fc'+str(i+1)+'=Dense(model_list[i][1],kernel_initializer = RandomNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2))(norm'+str(i)+')')
                            elif weight_initialize_method=='RandomUniform':
                                exec('fc'+str(i+1)+'=Dense(model_list[i][1],kernel_initializer = RandomUniform(minval=weight_initialize_parameter1,maxval=weight_initialize_parameter2))(norm'+str(i)+')')
                            elif weight_initialize_method=='TruncatedNormal':
                                exec('fc'+str(i+1)+'=Dense(model_list[i][1],kernel_initializer = TruncatedNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2))(norm'+str(i)+')')
                        elif model_list[i-1][0]=='activation':
                            if weight_initialize_method=='RandomNormal':
                                exec('fc'+str(i+1)+'=Dense(model_list[i][1],kernel_initializer = RandomNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2))(act'+str(i)+')')
                            elif weight_initialize_method=='RandomUniform':
                                exec('fc'+str(i+1)+'=Dense(model_list[i][1],kernel_initializer = RandomUniform(minval=weight_initialize_parameter1,maxval=weight_initialize_parameter2))(act'+str(i)+')')
                            elif weight_initialize_method=='TruncatedNormal':
                                exec('fc'+str(i+1)+'=Dense(model_list[i][1],kernel_initializer = TruncatedNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2))(act'+str(i)+')')
                        elif model_list[i-1][0]=='dropout':
                            if weight_initialize_method=='RandomNormal':
                                exec('fc'+str(i+1)+'=Dense(model_list[i][1],kernel_initializer = RandomNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2))(drop'+str(i)+')')
                            elif weight_initialize_method=='RandomUniform':
                                exec('fc'+str(i+1)+'=Dense(model_list[i][1],kernel_initializer = RandomUniform(minval=weight_initialize_parameter1,maxval=weight_initialize_parameter2))(drop'+str(i)+')')
                            elif weight_initialize_method=='TruncatedNormal':
                                exec('fc'+str(i+1)+'=Dense(model_list[i][1],kernel_initializer = TruncatedNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2))(drop'+str(i)+')')
                        elif model_list[i-1][0]=='fc':   
                            if weight_initialize_method=='RandomNormal':
                                exec('fc'+str(i+1)+'=Dense(model_list[i][1],kernel_initializer = RandomNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2))(fc'+str(i)+')')
                            elif weight_initialize_method=='RandomUniform':
                                exec('fc'+str(i+1)+'=Dense(model_list[i][1],kernel_initializer = RandomUniform(minval=weight_initialize_parameter1,maxval=weight_initialize_parameter2))(fc'+str(i)+')')
                            elif weight_initialize_method=='TruncatedNormal':
                                exec('fc'+str(i+1)+'=Dense(model_list[i][1],kernel_initializer = TruncatedNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2))(fc'+str(i)+')')
                        elif model_list[i-1][0]=='flatten':
                            if weight_initialize_method=='RandomNormal':
                                exec('fc'+str(i+1)+'=Dense(model_list[i][1],kernel_initializer = RandomNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2))(fla'+str(i)+')')
                            elif weight_initialize_method=='RandomUniform':
                                exec('fc'+str(i+1)+'=Dense(model_list[i][1],kernel_initializer = RandomUniform(minval=weight_initialize_parameter1,maxval=weight_initialize_parameter2))(fla'+str(i)+')')
                            elif weight_initialize_method=='TruncatedNormal':
                                exec('fc'+str(i+1)+'=Dense(model_list[i][1],kernel_initializer = TruncatedNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2))(fla'+str(i)+')')
            elif model_list[i][0] == 'dropout':
                if i==len(model_list)-1:
                    if model_list[i-1][0]=='transformer':
                        outputs=eval('Dropout(model_list[i][1])(en_fla)')
                    elif model_list[i-1][0]=='batchnormalization' or model_list[i-1][0]=='layernormalization':
                        outputs=eval('Dropout(model_list[i][1])(norm'+str(i)+')')
                    elif model_list[i-1][0]=='activation':
                        outputs=eval('Dropout(model_list[i][1])(act'+str(i)+')')
                    elif model_list[i-1][0]=='dropout' :
                        outputs=eval('Dropout(model_list[i][1])(drop'+str(i)+')')
                    elif model_list[i-1][0]=='fc':
                        outputs=eval('Dropout(model_list[i][1])(fc'+str(i)+')')
                    elif model_list[i-1][0]=='flatten':
                        outputs=eval('Dropout(model_list[i][1])(fla'+str(i)+')')
                else:
                    if model_list[i-1][0]=='transformer':
                        exec('drop'+str(i+1)+'=Dropout(model_list[i][1])(en_fla)')
                    elif model_list[i-1][0]=='batchnormalization' or model_list[i-1][0]=='layernormalization':
                        exec('drop'+str(i+1)+'=Dropout(model_list[i][1])(norm'+str(i)+')')
                    elif model_list[i-1][0]=='activation':
                        exec('drop'+str(i+1)+'=Dropout(model_list[i][1])(act'+str(i)+')')
                    elif model_list[i-1][0]=='dropout' :
                        exec('drop'+str(i+1)+'=Dropout(model_list[i][1])(drop'+str(i)+')')
                    elif model_list[i-1][0]=='fc':
                        exec('drop'+str(i+1)+'=Dropout(model_list[i][1])(fc'+str(i)+')')
                    elif model_list[i-1][0]=='flatten':
                        exec('drop'+str(i+1)+'=Dropout(model_list[i][1])(fla'+str(i)+')')
        model=eval('Model(inputs=[inputs1,inputs2], outputs=outputs)')
        if optimizer == 'SGD':
            opt = SGD(lr = learning_rate)
        elif optimizer == 'Adam':
            opt = Adam(lr = learning_rate)
        model.compile(loss=loss,optimizer=opt,metrics=[metric])
    elif if_best_mode=='yes' or if_best_mode=='load':
        if k_fold!=None:
            models=[]
            for i in range(k_fold):
                models.append(load_model(modelpath+'_'+str(i+1)))
        else:
            model=load_model(modelpath)
    if if_print_model=='yes':
        if k_fold!=None:
            if if_best_mode=='yes' or if_best_mode=='load':
                print(models[0].summary())
            else:
                print(model.summary())
        else:
            print(model.summary())
    if epochs!=0:
        if valid_size!=None or k_fold !=None:
            if k_fold!=None:
                if if_best_mode=='no' :
                    models = []
                    if ifrandom_split=='yes':
                        kf = KFold(n_splits=k_fold, shuffle=True, random_state=25)
                    else:
                        kf = KFold(n_splits=k_fold, shuffle=False)
                    for fold_no, (train_idx, val_idx) in enumerate(kf.split(trainx, trainy)):
                        X_train_fold, y_train_fold, position_train_fold = trainx[train_idx], trainy[train_idx], train_position[train_idx]
                        X_val_fold, y_val_fold, position_val_fold = trainx[val_idx], trainy[val_idx], train_position[val_idx]
                        model=eval('Model(inputs=[inputs1,inputs2], outputs=outputs)')
                        model.compile(loss=loss,optimizer=opt,metrics=[metric])
                        if if_early_stopping!=None:
                            H = model.fit(train_data_generator(X_train_fold,position_train_fold,y_train_fold,batch_size),steps_per_epoch=(len(X_train_fold) // batch_size+(1 if len(X_train_fold) % batch_size != 0 else 0)),validation_data=train_data_generator(X_val_fold,position_val_fold,y_val_fold,batch_size),validation_steps=(len(X_val_fold) // batch_size+(1 if len(X_val_fold) % batch_size != 0 else 0)),epochs = epochs,callbacks=[tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience=if_early_stopping,restore_best_weights=True)])
                        else:
                            H = model.fit(train_data_generator(X_train_fold,position_train_fold,y_train_fold,batch_size),steps_per_epoch=(len(X_train_fold) // batch_size+(1 if len(X_train_fold) % batch_size != 0 else 0)),validation_data=train_data_generator(X_val_fold,position_val_fold,y_val_fold,batch_size),validation_steps=(len(X_val_fold) // batch_size+(1 if len(X_val_fold) % batch_size != 0 else 0)),epochs = epochs)
                        models.append(model)
                else:
                    models_new = []
                    if ifrandom_split=='yes':
                        kf = KFold(n_splits=k_fold, shuffle=True, random_state=25)
                    else:
                        kf = KFold(n_splits=k_fold, shuffle=False)
                    for fold_no, (train_idx, val_idx) in enumerate(kf.split(trainx, trainy)):
                        X_train_fold, y_train_fold, position_train_fold = trainx[train_idx], trainy[train_idx], train_position[train_idx]
                        X_val_fold, y_val_fold, position_val_fold = trainx[val_idx], trainy[val_idx], train_position[val_idx]
                        if if_early_stopping!=None:
                            H = models[fold_no].fit(train_data_generator(X_train_fold,position_train_fold,y_train_fold,batch_size),steps_per_epoch=(len(X_train_fold) // batch_size+(1 if len(X_train_fold) % batch_size != 0 else 0)),validation_data=train_data_generator(X_val_fold,position_val_fold,y_val_fold,batch_size),validation_steps=(len(X_val_fold) // batch_size+(1 if len(X_val_fold) % batch_size != 0 else 0)),epochs = epochs,callbacks=[tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience=if_early_stopping,restore_best_weights=True)])
                        else:
                            H = models[fold_no].fit(train_data_generator(X_train_fold,position_train_fold,y_train_fold,batch_size),steps_per_epoch=(len(X_train_fold) // batch_size+(1 if len(X_train_fold) % batch_size != 0 else 0)),validation_data=train_data_generator(X_val_fold,position_val_fold,y_val_fold,batch_size),validation_steps=(len(X_val_fold) // batch_size+(1 if len(X_val_fold) % batch_size != 0 else 0)),epochs = epochs)
                        models_new.append(models[fold_no])
                    models=models_new
            else:
                if ifrandom_split=='yes':
                    trainy,validy,trainx,validx,train_position,valid_position = train_test_split(trainy,trainx,train_position,test_size=valid_size/(1-test_size),random_state=25)
                else:
                    index=int((1-valid_size/(1-test_size))*trainy.shape[0])
                    validy=trainy[index:]
                    trainy=trainy[:index]
                    validx=trainx[index:]
                    trainx=trainx[:index]
                    valid_position=train_position[index:]
                    train_position=train_position[:index]
                if if_early_stopping!=None:
                    H = model.fit(train_data_generator(trainx,train_position,trainy,batch_size),steps_per_epoch=(len(trainx) // batch_size+(1 if len(trainx) % batch_size != 0 else 0)),validation_data=train_data_generator(validx,valid_position,validy,batch_size),validation_steps=(len(validx) // batch_size+(1 if len(validx) % batch_size != 0 else 0)),epochs = epochs,callbacks=[tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience=if_early_stopping,restore_best_weights=True)])
                else:
                    H = model.fit(train_data_generator(trainx,train_position,trainy,batch_size),steps_per_epoch=(len(trainx) // batch_size+(1 if len(trainx) % batch_size != 0 else 0)),validation_data=train_data_generator(validx,valid_position,validy,batch_size),validation_steps=(len(validx) // batch_size+(1 if len(validx) % batch_size != 0 else 0)),epochs = epochs)
        else:
            if if_early_stopping!=None:
                H = model.fit(train_data_generator(trainx,train_position,trainy,batch_size),steps_per_epoch=(len(trainx) // batch_size+(1 if len(trainx) % batch_size != 0 else 0)),validation_data=train_data_generator(testx,test_position,testy,batch_size),validation_steps=(len(testx) // batch_size+(1 if len(testx) % batch_size != 0 else 0)),epochs = epochs,callbacks=[tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience=if_early_stopping,restore_best_weights=True)])
            else:
                H = model.fit(train_data_generator(trainx,train_position,trainy,batch_size),steps_per_epoch=(len(trainx) // batch_size+(1 if len(trainx) % batch_size != 0 else 0)),validation_data=train_data_generator(testx,test_position,testy,batch_size),validation_steps=(len(testx) // batch_size+(1 if len(testx) % batch_size != 0 else 0)),epochs = epochs)
    if k_fold!=None:
        predicty = [model.predict(test_data_generator(testx,test_position,batch_size),steps=(len(testx) // batch_size+(1 if len(testx) % batch_size != 0 else 0))) for model in models]
        predicty=np.nanmean(predicty,axis=0)
    else:
        predicty = model.predict(test_data_generator(testx,test_position,batch_size),steps=(len(testx) // batch_size+(1 if len(testx) % batch_size != 0 else 0)))
    predicty = np.nan_to_num(predicty,nan=0)
    if task_mode=='regression':
        r=np.zeros((testy.shape[1]))
        p=np.zeros((testy.shape[1]))
        for i in range(testy.shape[1]):
            r[i],p[i] = pearsonr(predicty[:,i],testy[:,i])
            r=np.nan_to_num(r,nan=0)
    elif task_mode=='binary_classify':
        accuracy=np.zeros((testy.shape[1]))
        recall=np.zeros((testy.shape[1]))
        precision=np.zeros((testy.shape[1]))
        f1=np.zeros((testy.shape[1]))
        for i in range(predicty.shape[1]):
            predicty[:,i]=[int(round(predicty[j,i],0)) for j in range(predicty.shape[0])]
        r=np.zeros((testy.shape[1]))
        for i in range(testy.shape[1]):
            if metrics=='Recall':
                r[i]=recall_score(testy[:,i], predicty[:,i])
            elif metrics=='Precision':
                r[i]=precision_score(testy[:,i], predicty[:,i])
            else:
                r[i]=accuracy_score(testy[:,i], predicty[:,i])
            recall[i]=recall_score(testy[:,i], predicty[:,i])
            precision[i]=precision_score(testy[:,i], predicty[:,i])
            accuracy[i]=accuracy_score(testy[:,i], predicty[:,i])
            f1[i]=f1_score(testy[:,i], predicty[:,i])
        p=0
    elif task_mode=='multi_classify':
        r=np.zeros((testy.shape[1]))
        for i in range(testy.shape[1]):
            r[i]=accuracy_score(testy[:,i], np.argmax(predicty,axis=1))
        p=0
    if ifmute == 'no':
        if task_mode=='regression':
            print('相关系数',np.nanmean(r))
        elif task_mode=='binary_classify':
            print('召回率+精确率',np.nanmean(f1),'准确率',np.nanmean(accuracy),'召回率',np.nanmean(recall),'精确率',np.nanmean(precision))
        elif task_mode=='multi_classify':
            print('准确率',np.nanmean(r))
    if ifweight=='yes':
        weights=np.zeros((testy.shape[1],testx.shape[2]))
        weight_more=np.zeros((testy.shape[1],testx.shape[2]))
        for i in range(testy.shape[1]):
            for j in range(testx.shape[2]):
                testx_new=copy.deepcopy(testx)
                weight=[]
                for k in range(10):
                    per=np.random.permutation(testx.shape[0])
                    testx_shuffle=testx[per,:,j]
                    testx_new[:,:,j]=testx_shuffle
                    if k_fold!=None:
                        predicty_new = [model.predict(test_data_generator(testx_new,test_position,batch_size),steps=(len(testx_new) // batch_size+(1 if len(testx_new) % batch_size != 0 else 0))) for model in models]
                        predicty_new=np.nanmean(predicty_new,axis=0)
                    else:
                        predicty_new = model.predict(test_data_generator(testx_new,test_position,batch_size),steps=(len(testx_new) // batch_size+(1 if len(testx_new) % batch_size != 0 else 0)))
                    if task_mode=='regression':
                        weight.append(sklearn.metrics.mean_squared_error(testy[:,i],predicty_new[:,i])-sklearn.metrics.mean_squared_error(testy[:,i],predicty[:,i]))
                    elif task_mode=='multi_classify':
                        weight.append(sklearn.metrics.log_loss(testy[:,i],predicty_new[:,:])-sklearn.metrics.log_loss(testy[:,i],predicty[:,:]))
                    else:
                        weight.append(sklearn.metrics.log_loss(testy[:,i],predicty_new[:,i])-sklearn.metrics.log_loss(testy[:,i],predicty[:,i]))
                weight_more[i,j]=np.nanmean(weight)
        for i in range(testy.shape[1]):
            for j in range(testx.shape[2]):
                weights[i,j]=(weight_more[i,j]/np.nansum(weight_more[i,:]))*100
                print('预报因子',j+1,'对预报值',i+1,'的贡献：',np.array(weights[i,j]),'％')
            print('\n')
    if ifsave=='yes':
        if k_fold!=None:
            for i, model in enumerate(models):
                model.save(savepath+'_'+str(i+1))
        else:
            model.save(savepath)
    if k_fold!=None:
        return models,predicty,testy,r,p,weights
    else:
        return model,predicty,testy,r,p,weights

# %%
model,predicty,testy,r,p,weights=Auto_Transformer(vy,vx,6,[['transformer'],['fc',7]],test_size=0.2,valid_size=0.1,k_fold=5,task_mode='regression',if_best_mode='no',modelpath=None,encoder_deep=1,num_heads=1,key_dim=1,ifdropout='no',trans_dropout_rate=0.0,trans_units=256,trans_activation='tanh',embedding_num=None,if_weight_initialize='no',weight_initialize_method='TruncatedNormal',weight_initialize_parameter1=0.00,weight_initialize_parameter2=0.05,if_print_model='yes',loss_function='default',optimizer='Adam',metrics='Pearsonr',if_early_stopping=1000,learning_rate=0.0001,epochs=5000,batch_size=5000,ifrandom_split='yes',ifweight='no',ifmute='no',ifsave='yes',savepath='E:/huawei/huawei_gnss_wind_w_30min_press_k5_onestation_45',device='gpu')
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 6)]          0           []
#
#  input_1 (InputLayer)           [(None, 6, 45)]      0           []
#
#  embedding (Embedding)          (None, 6, 45)        315         ['input_2[0][0]']
#
#  add (Add)                      (None, 6, 45)        0           ['input_1[0][0]',
#                                                                   'embedding[0][0]']
#
#  multi_head_attention (MultiHea  (None, 6, 45)       228         ['add[0][0]',
#  dAttention)                                                      'add[0][0]',
#                                                                   'add[0][0]']
#
#  add_1 (Add)                    (None, 6, 45)        0           ['add[0][0]',
#                                                                   'multi_head_attention[0][0]']
#
#  layer_normalization (LayerNorm  (None, 6, 45)       90          ['add_1[0][0]']
#  alization)
#
#  dense (Dense)                  (None, 6, 256)       11776       ['layer_normalization[0][0]']
#
#  dense_1 (Dense)                (None, 6, 45)        11565       ['dense[0][0]']
#
#  add_2 (Add)                    (None, 6, 45)        0           ['dense_1[0][0]',
#                                                                   'layer_normalization[0][0]']
#
#  layer_normalization_1 (LayerNo  (None, 6, 45)       90          ['add_2[0][0]']
#  rmalization)
#
#  flatten (Flatten)              (None, 270)          0           ['layer_normalization_1[0][0]']
#
#  dense_2 (Dense)                (None, 7)            1897        ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 25,961
# Trainable params: 25,961
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Epoch 1/5000
# 3/3 [==============================] - 2s 201ms/step - loss: 4.1648 - metrics_pearsonr: 0.9795 - val_loss: 3.7115 - val_metrics_pearsonr: 1.0035
# Epoch 2/5000
# 3/3 [==============================] - 0s 52ms/step - loss: 3.6360 - metrics_pearsonr: 0.9800 - val_loss: 3.2434 - val_metrics_pearsonr: 1.0038
# Epoch 3/5000
# 3/3 [==============================] - 0s 56ms/step - loss: 3.1838 - metrics_pearsonr: 0.9805 - val_loss: 2.8539 - val_metrics_pearsonr: 1.0040
# Epoch 4/5000
# 3/3 [==============================] - 0s 50ms/step - loss: 2.8100 - metrics_pearsonr: 0.9809 - val_loss: 2.5409 - val_metrics_pearsonr: 1.0041
# Epoch 5/5000
# 3/3 [==============================] - 0s 55ms/step - loss: 2.5117 - metrics_pearsonr: 0.9812 - val_loss: 2.2987 - val_metrics_pearsonr: 1.0040
# Epoch 6/5000
# 3/3 [==============================] - 0s 51ms/step - loss: 2.2823 - metrics_pearsonr: 0.9811 - val_loss: 2.1190 - val_metrics_pearsonr: 1.0036
# Epoch 7/5000
# 3/3 [==============================] - 0s 47ms/step - loss: 2.1136 - metrics_pearsonr: 0.9808 - val_loss: 1.9924 - val_metrics_pearsonr: 1.0029
# Epoch 8/5000
# 3/3 [==============================] - 0s 45ms/step - loss: 1.9957 - metrics_pearsonr: 0.9802 - val_loss: 1.9088 - val_metrics_pearsonr: 1.0019
# Epoch 9/5000
# 3/3 [==============================] - 0s 47ms/step - loss: 1.9186 - metrics_pearsonr: 0.9793 - val_loss: 1.8579 - val_metrics_pearsonr: 1.0008
# Epoch 10/5000
# 3/3 [==============================] - 0s 52ms/step - loss: 1.8722 - metrics_pearsonr: 0.9782 - val_loss: 1.8303 - val_metrics_pearsonr: 0.9994
# Epoch 11/5000
# 3/3 [==============================] - 0s 50ms/step - loss: 1.8472 - metrics_pearsonr: 0.9768 - val_loss: 1.8178 - val_metrics_pearsonr: 0.9979
# Epoch 12/5000
# 3/3 [==============================] - 0s 51ms/step - loss: 1.8359 - metrics_pearsonr: 0.9753 - val_loss: 1.8139 - val_metrics_pearsonr: 0.9963
# Epoch 13/5000
# 3/3 [==============================] - 0s 46ms/step - loss: 1.8323 - metrics_pearsonr: 0.9738 - val_loss: 1.8142 - val_metrics_pearsonr: 0.9947
# Epoch 14/5000
# 3/3 [==============================] - 0s 43ms/step - loss: 1.8324 - metrics_pearsonr: 0.9722 - val_loss: 1.8158 - val_metrics_pearsonr: 0.9932
# Epoch 15/5000
# 3/3 [==============================] - 0s 44ms/step - loss: 1.8335 - metrics_pearsonr: 0.9706 - val_loss: 1.8170 - val_metrics_pearsonr: 0.9917
# Epoch 16/5000
# 3/3 [==============================] - 0s 45ms/step - loss: 1.8343 - metrics_pearsonr: 0.9691 - val_loss: 1.8171 - val_metrics_pearsonr: 0.9902
# Epoch 17/5000
# 3/3 [==============================] - 0s 48ms/step - loss: 1.8341 - metrics_pearsonr: 0.9676 - val_loss: 1.8160 - val_metrics_pearsonr: 0.9889
# Epoch 18/5000
# 3/3 [==============================] - 0s 49ms/step - loss: 1.8330 - metrics_pearsonr: 0.9661 - val_loss: 1.8142 - val_metrics_pearsonr: 0.9875
# Epoch 19/5000
# 3/3 [==============================] - 0s 52ms/step - loss: 1.8312 - metrics_pearsonr: 0.9647 - val_loss: 1.8120 - val_metrics_pearsonr: 0.9863
# Epoch 20/5000
# 3/3 [==============================] - 0s 58ms/step - loss: 1.8292 - metrics_pearsonr: 0.9633 - val_loss: 1.8098 - val_metrics_pearsonr: 0.9850
# Epoch 21/5000
# 3/3 [==============================] - 0s 52ms/step - loss: 1.8273 - metrics_pearsonr: 0.9620 - val_loss: 1.8078 - val_metrics_pearsonr: 0.9838
# Epoch 22/5000
# 3/3 [==============================] - 0s 55ms/step - loss: 1.8255 - metrics_pearsonr: 0.9607 - val_loss: 1.8061 - val_metrics_pearsonr: 0.9825
# Epoch 23/5000
# 3/3 [==============================] - 0s 52ms/step - loss: 1.8241 - metrics_pearsonr: 0.9594 - val_loss: 1.8048 - val_metrics_pearsonr: 0.9813
# Epoch 24/5000
# 3/3 [==============================] - 0s 49ms/step - loss: 1.8229 - metrics_pearsonr: 0.9580 - val_loss: 1.8038 - val_metrics_pearsonr: 0.9799
# Epoch 25/5000
# 3/3 [==============================] - 0s 45ms/step - loss: 1.8220 - metrics_pearsonr: 0.9566 - val_loss: 1.8030 - val_metrics_pearsonr: 0.9786
# Epoch 26/5000
# 3/3 [==============================] - 0s 51ms/step - loss: 1.8213 - metrics_pearsonr: 0.9552 - val_loss: 1.8025 - val_metrics_pearsonr: 0.9772
# Epoch 27/5000
# 3/3 [==============================] - 0s 51ms/step - loss: 1.8208 - metrics_pearsonr: 0.9537 - val_loss: 1.8020 - val_metrics_pearsonr: 0.9758
# Epoch 28/5000
# 3/3 [==============================] - 0s 56ms/step - loss: 1.8203 - metrics_pearsonr: 0.9522 - val_loss: 1.8016 - val_metrics_pearsonr: 0.9743
# Epoch 29/5000
# 3/3 [==============================] - 0s 49ms/step - loss: 1.8199 - metrics_pearsonr: 0.9507 - val_loss: 1.8011 - val_metrics_pearsonr: 0.9728
# Epoch 30/5000
# 3/3 [==============================] - 0s 51ms/step - loss: 1.8194 - metrics_pearsonr: 0.9491 - val_loss: 1.8007 - val_metrics_pearsonr: 0.9713
# Epoch 31/5000
# 3/3 [==============================] - 0s 52ms/step - loss: 1.8189 - metrics_pearsonr: 0.9475 - val_loss: 1.8002 - val_metrics_pearsonr: 0.9698
# Epoch 32/5000
# 3/3 [==============================] - 0s 51ms/step - loss: 1.8184 - metrics_pearsonr: 0.9459 - val_loss: 1.7997 - val_metrics_pearsonr: 0.9682
# Epoch 33/5000
# 3/3 [==============================] - 0s 51ms/step - loss: 1.8179 - metrics_pearsonr: 0.9443 - val_loss: 1.7992 - val_metrics_pearsonr: 0.9666
# Epoch 34/5000
# 3/3 [==============================] - 0s 54ms/step - loss: 1.8173 - metrics_pearsonr: 0.9427 - val_loss: 1.7988 - val_metrics_pearsonr: 0.9650
# Epoch 35/5000
# 3/3 [==============================] - 0s 57ms/step - loss: 1.8168 - metrics_pearsonr: 0.9410 - val_loss: 1.7983 - val_metrics_pearsonr: 0.9633
# Epoch 36/5000
# 3/3 [==============================] - 0s 54ms/step - loss: 1.8163 - metrics_pearsonr: 0.9393 - val_loss: 1.7978 - val_metrics_pearsonr: 0.9617
# Epoch 37/5000
# 3/3 [==============================] - 0s 52ms/step - loss: 1.8158 - metrics_pearsonr: 0.9376 - val_loss: 1.7974 - val_metrics_pearsonr: 0.9600
# Epoch 38/5000
# 3/3 [==============================] - 0s 52ms/step - loss: 1.8153 - metrics_pearsonr: 0.9359 - val_loss: 1.7970 - val_metrics_pearsonr: 0.9583
# Epoch 39/5000
# 3/3 [==============================] - 0s 52ms/step - loss: 1.8148 - metrics_pearsonr: 0.9342 - val_loss: 1.7965 - val_metrics_pearsonr: 0.9567
# Epoch 40/5000
# 3/3 [==============================] - 0s 50ms/step - loss: 1.8143 - metrics_pearsonr: 0.9324 - val_loss: 1.7961 - val_metrics_pearsonr: 0.9550
# Epoch 41/5000
# 3/3 [==============================] - 0s 50ms/step - loss: 1.8138 - metrics_pearsonr: 0.9307 - val_loss: 1.7956 - val_metrics_pearsonr: 0.9533
# Epoch 42/5000
# 3/3 [==============================] - 0s 49ms/step - loss: 1.8133 - metrics_pearsonr: 0.9290 - val_loss: 1.7952 - val_metrics_pearsonr: 0.9515
# Epoch 43/5000
# 3/3 [==============================] - 0s 55ms/step - loss: 1.8128 - metrics_pearsonr: 0.9272 - val_loss: 1.7947 - val_metrics_pearsonr: 0.9498
# Epoch 44/5000
# 3/3 [==============================] - 0s 49ms/step - loss: 1.8123 - metrics_pearsonr: 0.9254 - val_loss: 1.7942 - val_metrics_pearsonr: 0.9481
# Epoch 45/5000
# 3/3 [==============================] - 0s 52ms/step - loss: 1.8118 - metrics_pearsonr: 0.9237 - val_loss: 1.7938 - val_metrics_pearsonr: 0.9463
# Epoch 46/5000
# 3/3 [==============================] - 0s 49ms/step - loss: 1.8113 - metrics_pearsonr: 0.9219 - val_loss: 1.7933 - val_metrics_pearsonr: 0.9446
# Epoch 47/5000
# 3/3 [==============================] - 0s 48ms/step - loss: 1.8108 - metrics_pearsonr: 0.9201 - val_loss: 1.7928 - val_metrics_pearsonr: 0.9428
# Epoch 48/5000
# 3/3 [==============================] - 0s 45ms/step - loss: 1.8103 - metrics_pearsonr: 0.9183 - val_loss: 1.7924 - val_metrics_pearsonr: 0.9411
# Epoch 49/5000
# 3/3 [==============================] - 0s 49ms/step - loss: 1.8098 - metrics_pearsonr: 0.9165 - val_loss: 1.7919 - val_metrics_pearsonr: 0.9393
# Epoch 50/5000
# 3/3 [==============================] - 0s 46ms/step - loss: 1.8093 - metrics_pearsonr: 0.9147 - val_loss: 1.7914 - val_metrics_pearsonr: 0.9375
# Epoch 51/5000
# 3/3 [==============================] - 0s 51ms/step - loss: 1.8087 - metrics_pearsonr: 0.9129 - val_loss: 1.7909 - val_metrics_pearsonr: 0.9357
# Epoch 52/5000
# 3/3 [==============================] - 0s 51ms/step - loss: 1.8082 - metrics_pearsonr: 0.9110 - val_loss: 1.7905 - val_metrics_pearsonr: 0.9339
# Epoch 53/5000
# 3/3 [==============================] - 0s 50ms/step - loss: 1.8077 - metrics_pearsonr: 0.9092 - val_loss: 1.7900 - val_metrics_pearsonr: 0.9321
# Epoch 54/5000
# 3/3 [==============================] - 0s 48ms/step - loss: 1.8071 - metrics_pearsonr: 0.9074 - val_loss: 1.7895 - val_metrics_pearsonr: 0.9303
# Epoch 55/5000
# 3/3 [==============================] - 0s 47ms/step - loss: 1.8066 - metrics_pearsonr: 0.9056 - val_loss: 1.7890 - val_metrics_pearsonr: 0.9285
# Epoch 56/5000
# 3/3 [==============================] - 0s 45ms/step - loss: 1.8061 - metrics_pearsonr: 0.9037 - val_loss: 1.7885 - val_metrics_pearsonr: 0.9267
# Epoch 57/5000
# 3/3 [==============================] - 0s 56ms/step - loss: 1.8055 - metrics_pearsonr: 0.9019 - val_loss: 1.7880 - val_metrics_pearsonr: 0.9249
# Epoch 58/5000
# 3/3 [==============================] - 0s 56ms/step - loss: 1.8050 - metrics_pearsonr: 0.9001 - val_loss: 1.7875 - val_metrics_pearsonr: 0.9232
# Epoch 59/5000
# 3/3 [==============================] - 0s 50ms/step - loss: 1.8044 - metrics_pearsonr: 0.8983 - val_loss: 1.7870 - val_metrics_pearsonr: 0.9214
# Epoch 60/5000
# 3/3 [==============================] - 0s 50ms/step - loss: 1.8039 - metrics_pearsonr: 0.8964 - val_loss: 1.7865 - val_metrics_pearsonr: 0.9196
# Epoch 61/5000
# 3/3 [==============================] - 0s 48ms/step - loss: 1.8033 - metrics_pearsonr: 0.8946 - val_loss: 1.7860 - val_metrics_pearsonr: 0.9178
# Epoch 62/5000
# 3/3 [==============================] - 0s 48ms/step - loss: 1.8027 - metrics_pearsonr: 0.8928 - val_loss: 1.7855 - val_metrics_pearsonr: 0.9160
# Epoch 63/5000
# 3/3 [==============================] - 0s 50ms/step - loss: 1.8022 - metrics_pearsonr: 0.8910 - val_loss: 1.7850 - val_metrics_pearsonr: 0.9142
# Epoch 64/5000
# 3/3 [==============================] - 0s 50ms/step - loss: 1.8016 - metrics_pearsonr: 0.8892 - val_loss: 1.7845 - val_metrics_pearsonr: 0.9125
# Epoch 65/5000
# 3/3 [==============================] - 0s 48ms/step - loss: 1.8010 - metrics_pearsonr: 0.8874 - val_loss: 1.7840 - val_metrics_pearsonr: 0.9107
# Epoch 66/5000
# 3/3 [==============================] - 0s 51ms/step - loss: 1.8004 - metrics_pearsonr: 0.8856 - val_loss: 1.7834 - val_metrics_pearsonr: 0.9089
# Epoch 67/5000
# 3/3 [==============================] - 0s 48ms/step - loss: 1.7998 - metrics_pearsonr: 0.8838 - val_loss: 1.7829 - val_metrics_pearsonr: 0.9072
# Epoch 68/5000
# 3/3 [==============================] - 0s 50ms/step - loss: 1.7992 - metrics_pearsonr: 0.8821 - val_loss: 1.7823 - val_metrics_pearsonr: 0.9054
# Epoch 69/5000
# 3/3 [==============================] - 0s 54ms/step - loss: 1.7986 - metrics_pearsonr: 0.8803 - val_loss: 1.7818 - val_metrics_pearsonr: 0.9037
# Epoch 70/5000
# 3/3 [==============================] - 0s 48ms/step - loss: 1.7979 - metrics_pearsonr: 0.8785 - val_loss: 1.7812 - val_metrics_pearsonr: 0.9019
# Epoch 71/5000
# 3/3 [==============================] - 0s 47ms/step - loss: 1.7973 - metrics_pearsonr: 0.8768 - val_loss: 1.7807 - val_metrics_pearsonr: 0.9002
# Epoch 72/5000
# 3/3 [==============================] - 0s 47ms/step - loss: 1.7966 - metrics_pearsonr: 0.8750 - val_loss: 1.7801 - val_metrics_pearsonr: 0.8985
# Epoch 73/5000
# 3/3 [==============================] - 0s 47ms/step - loss: 1.7960 - metrics_pearsonr: 0.8733 - val_loss: 1.7795 - val_metrics_pearsonr: 0.8968
# Epoch 74/5000
# 3/3 [==============================] - 0s 46ms/step - loss: 1.7953 - metrics_pearsonr: 0.8715 - val_loss: 1.7789 - val_metrics_pearsonr: 0.8951
# Epoch 75/5000
# 3/3 [==============================] - 0s 49ms/step - loss: 1.7947 - metrics_pearsonr: 0.8698 - val_loss: 1.7783 - val_metrics_pearsonr: 0.8934
# Epoch 76/5000
# 3/3 [==============================] - 0s 47ms/step - loss: 1.7940 - metrics_pearsonr: 0.8681 - val_loss: 1.7777 - val_metrics_pearsonr: 0.8917
# Epoch 77/5000
# 3/3 [==============================] - 0s 49ms/step - loss: 1.7933 - metrics_pearsonr: 0.8664 - val_loss: 1.7771 - val_metrics_pearsonr: 0.8900
# Epoch 78/5000
# 3/3 [==============================] - 0s 50ms/step - loss: 1.7926 - metrics_pearsonr: 0.8647 - val_loss: 1.7765 - val_metrics_pearsonr: 0.8883
# Epoch 79/5000
# 3/3 [==============================] - 0s 49ms/step - loss: 1.7919 - metrics_pearsonr: 0.8630 - val_loss: 1.7759 - val_metrics_pearsonr: 0.8866
# Epoch 80/5000
# 3/3 [==============================] - 0s 46ms/step - loss: 1.7912 - metrics_pearsonr: 0.8613 - val_loss: 1.7752 - val_metrics_pearsonr: 0.8849
# Epoch 81/5000
# 3/3 [==============================] - 0s 45ms/step - loss: 1.7904 - metrics_pearsonr: 0.8596 - val_loss: 1.7746 - val_metrics_pearsonr: 0.8832
# Epoch 82/5000
# 3/3 [==============================] - 0s 47ms/step - loss: 1.7897 - metrics_pearsonr: 0.8579 - val_loss: 1.7739 - val_metrics_pearsonr: 0.8815
# Epoch 83/5000
# 3/3 [==============================] - 0s 48ms/step - loss: 1.7889 - metrics_pearsonr: 0.8562 - val_loss: 1.7733 - val_metrics_pearsonr: 0.8799
# Epoch 84/5000
# 3/3 [==============================] - 0s 49ms/step - loss: 1.7882 - metrics_pearsonr: 0.8545 - val_loss: 1.7726 - val_metrics_pearsonr: 0.8782
# Epoch 85/5000
# 3/3 [==============================] - 0s 49ms/step - loss: 1.7874 - metrics_pearsonr: 0.8529 - val_loss: 1.7719 - val_metrics_pearsonr: 0.8765
# Epoch 86/5000
# 3/3 [==============================] - 0s 53ms/step - loss: 1.7866 - metrics_pearsonr: 0.8512 - val_loss: 1.7712 - val_metrics_pearsonr: 0.8748
# Epoch 87/5000
# 3/3 [==============================] - 0s 54ms/step - loss: 1.7858 - metrics_pearsonr: 0.8495 - val_loss: 1.7705 - val_metrics_pearsonr: 0.8732
# Epoch 88/5000
# 3/3 [==============================] - 0s 48ms/step - loss: 1.7850 - metrics_pearsonr: 0.8478 - val_loss: 1.7697 - val_metrics_pearsonr: 0.8715
# Epoch 89/5000
# 3/3 [==============================] - 0s 52ms/step - loss: 1.7841 - metrics_pearsonr: 0.8462 - val_loss: 1.7690 - val_metrics_pearsonr: 0.8698
# Epoch 90/5000
# 3/3 [==============================] - 0s 54ms/step - loss: 1.7833 - metrics_pearsonr: 0.8445 - val_loss: 1.7682 - val_metrics_pearsonr: 0.8681
# Epoch 91/5000
# 3/3 [==============================] - 0s 49ms/step - loss: 1.7824 - metrics_pearsonr: 0.8428 - val_loss: 1.7675 - val_metrics_pearsonr: 0.8665
# Epoch 92/5000
# 3/3 [==============================] - 0s 49ms/step - loss: 1.7815 - metrics_pearsonr: 0.8412 - val_loss: 1.7667 - val_metrics_pearsonr: 0.8648
# Epoch 93/5000
# 3/3 [==============================] - 0s 50ms/step - loss: 1.7806 - metrics_pearsonr: 0.8395 - val_loss: 1.7659 - val_metrics_pearsonr: 0.8631
# Epoch 94/5000
# 3/3 [==============================] - 0s 56ms/step - loss: 1.7797 - metrics_pearsonr: 0.8378 - val_loss: 1.7651 - val_metrics_pearsonr: 0.8614
# Epoch 95/5000
# 3/3 [==============================] - 0s 46ms/step - loss: 1.7788 - metrics_pearsonr: 0.8362 - val_loss: 1.7643 - val_metrics_pearsonr: 0.8597
# Epoch 96/5000
# 3/3 [==============================] - 0s 48ms/step - loss: 1.7778 - metrics_pearsonr: 0.8345 - val_loss: 1.7634 - val_metrics_pearsonr: 0.8579
# Epoch 97/5000
# 3/3 [==============================] - 0s 51ms/step - loss: 1.7769 - metrics_pearsonr: 0.8328 - val_loss: 1.7626 - val_metrics_pearsonr: 0.8562
# Epoch 98/5000
# 3/3 [==============================] - 0s 47ms/step - loss: 1.7759 - metrics_pearsonr: 0.8311 - val_loss: 1.7617 - val_metrics_pearsonr: 0.8545
# Epoch 99/5000
# 3/3 [==============================] - 0s 53ms/step - loss: 1.7749 - metrics_pearsonr: 0.8294 - val_loss: 1.7608 - val_metrics_pearsonr: 0.8527
# Epoch 100/5000
# 3/3 [==============================] - 0s 51ms/step - loss: 1.7739 - metrics_pearsonr: 0.8277 - val_loss: 1.7599 - val_metrics_pearsonr: 0.8510
# Epoch 101/5000
# 3/3 [==============================] - 0s 52ms/step - loss: 1.7728 - metrics_pearsonr: 0.8260 - val_loss: 1.7590 - val_metrics_pearsonr: 0.8492
# Epoch 102/5000
# 3/3 [==============================] - 0s 52ms/step - loss: 1.7718 - metrics_pearsonr: 0.8243 - val_loss: 1.7581 - val_metrics_pearsonr: 0.8474
# Epoch 103/5000
# 3/3 [==============================] - 0s 53ms/step - loss: 1.7707 - metrics_pearsonr: 0.8225 - val_loss: 1.7571 - val_metrics_pearsonr: 0.8456
# Epoch 104/5000
# 3/3 [==============================] - 0s 46ms/step - loss: 1.7696 - metrics_pearsonr: 0.8208 - val_loss: 1.7561 - val_metrics_pearsonr: 0.8438
# Epoch 105/5000
# 3/3 [==============================] - 0s 48ms/step - loss: 1.7685 - metrics_pearsonr: 0.8190 - val_loss: 1.7551 - val_metrics_pearsonr: 0.8420
# Epoch 106/5000
# 3/3 [==============================] - 0s 53ms/step - loss: 1.7674 - metrics_pearsonr: 0.8173 - val_loss: 1.7541 - val_metrics_pearsonr: 0.8402
# Epoch 107/5000
# 3/3 [==============================] - 0s 50ms/step - loss: 1.7662 - metrics_pearsonr: 0.8155 - val_loss: 1.7531 - val_metrics_pearsonr: 0.8383
# Epoch 108/5000
# 3/3 [==============================] - 0s 47ms/step - loss: 1.7651 - metrics_pearsonr: 0.8137 - val_loss: 1.7521 - val_metrics_pearsonr: 0.8365
# Epoch 109/5000
# 3/3 [==============================] - 0s 45ms/step - loss: 1.7639 - metrics_pearsonr: 0.8119 - val_loss: 1.7510 - val_metrics_pearsonr: 0.8346
# Epoch 110/5000
# 3/3 [==============================] - 0s 47ms/step - loss: 1.7627 - metrics_pearsonr: 0.8101 - val_loss: 1.7500 - val_metrics_pearsonr: 0.8327
# Epoch 111/5000
# 3/3 [==============================] - 0s 51ms/step - loss: 1.7615 - metrics_pearsonr: 0.8083 - val_loss: 1.7489 - val_metrics_pearsonr: 0.8307
# Epoch 112/5000
# 3/3 [==============================] - 0s 50ms/step - loss: 1.7603 - metrics_pearsonr: 0.8065 - val_loss: 1.7478 - val_metrics_pearsonr: 0.8288
# Epoch 113/5000
# 3/3 [==============================] - 0s 50ms/step - loss: 1.7590 - metrics_pearsonr: 0.8046 - val_loss: 1.7466 - val_metrics_pearsonr: 0.8268
# Epoch 114/5000
# 3/3 [==============================] - 0s 46ms/step - loss: 1.7578 - metrics_pearsonr: 0.8027 - val_loss: 1.7455 - val_metrics_pearsonr: 0.8249
# Epoch 115/5000
# 3/3 [==============================] - 0s 45ms/step - loss: 1.7565 - metrics_pearsonr: 0.8009 - val_loss: 1.7444 - val_metrics_pearsonr: 0.8229
# Epoch 116/5000
# 3/3 [==============================] - 0s 47ms/step - loss: 1.7552 - metrics_pearsonr: 0.7990 - val_loss: 1.7432 - val_metrics_pearsonr: 0.8209
# Epoch 117/5000
# 3/3 [==============================] - 0s 49ms/step - loss: 1.7539 - metrics_pearsonr: 0.7971 - val_loss: 1.7420 - val_metrics_pearsonr: 0.8188
# Epoch 118/5000
# 3/3 [==============================] - 0s 48ms/step - loss: 1.7526 - metrics_pearsonr: 0.7952 - val_loss: 1.7408 - val_metrics_pearsonr: 0.8168
# Epoch 119/5000
# 3/3 [==============================] - 0s 51ms/step - loss: 1.7513 - metrics_pearsonr: 0.7932 - val_loss: 1.7396 - val_metrics_pearsonr: 0.8147
# Epoch 120/5000
# 3/3 [==============================] - 0s 46ms/step - loss: 1.7500 - metrics_pearsonr: 0.7913 - val_loss: 1.7384 - val_metrics_pearsonr: 0.8127
# Epoch 121/5000
# 3/3 [==============================] - 0s 45ms/step - loss: 1.7487 - metrics_pearsonr: 0.7894 - val_loss: 1.7372 - val_metrics_pearsonr: 0.8106
# Epoch 122/5000
# 3/3 [==============================] - 0s 45ms/step - loss: 1.7473 - metrics_pearsonr: 0.7874 - val_loss: 1.7359 - val_metrics_pearsonr: 0.8085
# Epoch 123/5000
# 3/3 [==============================] - 0s 48ms/step - loss: 1.7460 - metrics_pearsonr: 0.7854 - val_loss: 1.7347 - val_metrics_pearsonr: 0.8064
# Epoch 124/5000
# 3/3 [==============================] - 0s 48ms/step - loss: 1.7447 - metrics_pearsonr: 0.7835 - val_loss: 1.7334 - val_metrics_pearsonr: 0.8043
# Epoch 125/5000
# 3/3 [==============================] - 0s 47ms/step - loss: 1.7433 - metrics_pearsonr: 0.7815 - val_loss: 1.7321 - val_metrics_pearsonr: 0.8021
# Epoch 126/5000
# 3/3 [==============================] - 0s 47ms/step - loss: 1.7420 - metrics_pearsonr: 0.7795 - val_loss: 1.7308 - val_metrics_pearsonr: 0.8000
# Epoch 127/5000
# 3/3 [==============================] - 0s 47ms/step - loss: 1.7406 - metrics_pearsonr: 0.7776 - val_loss: 1.7295 - val_metrics_pearsonr: 0.7979
# Epoch 128/5000
# 3/3 [==============================] - 0s 48ms/step - loss: 1.7393 - metrics_pearsonr: 0.7756 - val_loss: 1.7282 - val_metrics_pearsonr: 0.7957
# Epoch 129/5000
# 3/3 [==============================] - 0s 49ms/step - loss: 1.7380 - metrics_pearsonr: 0.7736 - val_loss: 1.7269 - val_metrics_pearsonr: 0.7936
# Epoch 130/5000
# 3/3 [==============================] - 0s 49ms/step - loss: 1.7366 - metrics_pearsonr: 0.7716 - val_loss: 1.7256 - val_metrics_pearsonr: 0.7915
# Epoch 131/5000
# 3/3 [==============================] - 0s 48ms/step - loss: 1.7353 - metrics_pearsonr: 0.7697 - val_loss: 1.7243 - val_metrics_pearsonr: 0.7893
# Epoch 132/5000
# 3/3 [==============================] - 0s 51ms/step - loss: 1.7340 - metrics_pearsonr: 0.7677 - val_loss: 1.7230 - val_metrics_pearsonr: 0.7872
# Epoch 133/5000
# 3/3 [==============================] - 0s 48ms/step - loss: 1.7327 - metrics_pearsonr: 0.7658 - val_loss: 1.7217 - val_metrics_pearsonr: 0.7851
# Epoch 134/5000
# 3/3 [==============================] - 0s 50ms/step - loss: 1.7314 - metrics_pearsonr: 0.7638 - val_loss: 1.7204 - val_metrics_pearsonr: 0.7830
# Epoch 135/5000
# 3/3 [==============================] - 0s 50ms/step - loss: 1.7301 - metrics_pearsonr: 0.7619 - val_loss: 1.7190 - val_metrics_pearsonr: 0.7809
# Epoch 136/5000
# 3/3 [==============================] - 0s 50ms/step - loss: 1.7288 - metrics_pearsonr: 0.7600 - val_loss: 1.7177 - val_metrics_pearsonr: 0.7788
# Epoch 137/5000
# 3/3 [==============================] - 0s 50ms/step - loss: 1.7275 - metrics_pearsonr: 0.7581 - val_loss: 1.7164 - val_metrics_pearsonr: 0.7768
# Epoch 138/5000
# 3/3 [==============================] - 0s 50ms/step - loss: 1.7262 - metrics_pearsonr: 0.7562 - val_loss: 1.7151 - val_metrics_pearsonr: 0.7747
# Epoch 139/5000
# 3/3 [==============================] - 0s 45ms/step - loss: 1.7249 - metrics_pearsonr: 0.7543 - val_loss: 1.7137 - val_metrics_pearsonr: 0.7727
# Epoch 140/5000
# 3/3 [==============================] - 0s 51ms/step - loss: 1.7236 - metrics_pearsonr: 0.7525 - val_loss: 1.7124 - val_metrics_pearsonr: 0.7706
# Epoch 141/5000
# 3/3 [==============================] - 0s 48ms/step - loss: 1.7224 - metrics_pearsonr: 0.7506 - val_loss: 1.7111 - val_metrics_pearsonr: 0.7686
# Epoch 142/5000
# 3/3 [==============================] - 0s 53ms/step - loss: 1.7211 - metrics_pearsonr: 0.7488 - val_loss: 1.7098 - val_metrics_pearsonr: 0.7666
# Epoch 143/5000
# 3/3 [==============================] - 0s 52ms/step - loss: 1.7199 - metrics_pearsonr: 0.7470 - val_loss: 1.7085 - val_metrics_pearsonr: 0.7646
# Epoch 144/5000
# 3/3 [==============================] - 0s 55ms/step - loss: 1.7186 - metrics_pearsonr: 0.7451 - val_loss: 1.7072 - val_metrics_pearsonr: 0.7627
# Epoch 145/5000
# 3/3 [==============================] - 0s 51ms/step - loss: 1.7174 - metrics_pearsonr: 0.7433 - val_loss: 1.7059 - val_metrics_pearsonr: 0.7607
# Epoch 146/5000
# 3/3 [==============================] - 0s 49ms/step - loss: 1.7162 - metrics_pearsonr: 0.7416 - val_loss: 1.7046 - val_metrics_pearsonr: 0.7587
# Epoch 147/5000
# 3/3 [==============================] - 0s 51ms/step - loss: 1.7149 - metrics_pearsonr: 0.7398 - val_loss: 1.7033 - val_metrics_pearsonr: 0.7568
# Epoch 148/5000
# 3/3 [==============================] - 0s 49ms/step - loss: 1.7137 - metrics_pearsonr: 0.7380 - val_loss: 1.7020 - val_metrics_pearsonr: 0.7549
# Epoch 149/5000
# 3/3 [==============================] - 0s 48ms/step - loss: 1.7125 - metrics_pearsonr: 0.7363 - val_loss: 1.7007 - val_metrics_pearsonr: 0.7530
# Epoch 150/5000
# 3/3 [==============================] - 0s 45ms/step - loss: 1.7113 - metrics_pearsonr: 0.7345 - val_loss: 1.6995 - val_metrics_pearsonr: 0.7511
# Epoch 151/5000
# 3/3 [==============================] - 0s 43ms/step - loss: 1.7101 - metrics_pearsonr: 0.7328 - val_loss: 1.6982 - val_metrics_pearsonr: 0.7492
# Epoch 152/5000
# 3/3 [==============================] - 0s 50ms/step - loss: 1.7089 - metrics_pearsonr: 0.7310 - val_loss: 1.6969 - val_metrics_pearsonr: 0.7473
# Epoch 153/5000
# 3/3 [==============================] - 0s 51ms/step - loss: 1.7077 - metrics_pearsonr: 0.7293 - val_loss: 1.6957 - val_metrics_pearsonr: 0.7454
# Epoch 154/5000
# 3/3 [==============================] - 0s 50ms/step - loss: 1.7065 - metrics_pearsonr: 0.7276 - val_loss: 1.6944 - val_metrics_pearsonr: 0.7436
# Epoch 155/5000
# 3/3 [==============================] - 0s 47ms/step - loss: 1.7053 - metrics_pearsonr: 0.7259 - val_loss: 1.6932 - val_metrics_pearsonr: 0.7417
# Epoch 156/5000
# 3/3 [==============================] - 0s 47ms/step - loss: 1.7042 - metrics_pearsonr: 0.7242 - val_loss: 1.6919 - val_metrics_pearsonr: 0.7399
# Epoch 157/5000
# 3/3 [==============================] - 0s 47ms/step - loss: 1.7030 - metrics_pearsonr: 0.7225 - val_loss: 1.6907 - val_metrics_pearsonr: 0.7380
# Epoch 158/5000
# 3/3 [==============================] - 0s 51ms/step - loss: 1.7018 - metrics_pearsonr: 0.7208 - val_loss: 1.6895 - val_metrics_pearsonr: 0.7362
# Epoch 159/5000
# 3/3 [==============================] - 0s 54ms/step - loss: 1.7007 - metrics_pearsonr: 0.7191 - val_loss: 1.6882 - val_metrics_pearsonr: 0.7344
# Epoch 160/5000
# 3/3 [==============================] - 0s 51ms/step - loss: 1.6995 - metrics_pearsonr: 0.7174 - val_loss: 1.6870 - val_metrics_pearsonr: 0.7326
# Epoch 161/5000
# 3/3 [==============================] - 0s 55ms/step - loss: 1.6984 - metrics_pearsonr: 0.7158 - val_loss: 1.6858 - val_metrics_pearsonr: 0.7308
# Epoch 162/5000
# 3/3 [==============================] - 0s 52ms/step - loss: 1.6973 - metrics_pearsonr: 0.7141 - val_loss: 1.6846 - val_metrics_pearsonr: 0.7290
# Epoch 163/5000
# 3/3 [==============================] - 0s 50ms/step - loss: 1.6961 - metrics_pearsonr: 0.7124 - val_loss: 1.6834 - val_metrics_pearsonr: 0.7272
# Epoch 164/5000
# 3/3 [==============================] - 0s 50ms/step - loss: 1.6950 - metrics_pearsonr: 0.7108 - val_loss: 1.6822 - val_metrics_pearsonr: 0.7254
# Epoch 165/5000
# 3/3 [==============================] - 0s 51ms/step - loss: 1.6939 - metrics_pearsonr: 0.7092 - val_loss: 1.6810 - val_metrics_pearsonr: 0.7237
# Epoch 166/5000
# 3/3 [==============================] - 0s 51ms/step - loss: 1.6928 - metrics_pearsonr: 0.7075 - val_loss: 1.6798 - val_metrics_pearsonr: 0.7219
# Epoch 167/5000
# 3/3 [==============================] - 0s 46ms/step - loss: 1.6917 - metrics_pearsonr: 0.7059 - val_loss: 1.6787 - val_metrics_pearsonr: 0.7202
# Epoch 168/5000
# 3/3 [==============================] - 0s 48ms/step - loss: 1.6906 - metrics_pearsonr: 0.7043 - val_loss: 1.6775 - val_metrics_pearsonr: 0.7184
# Epoch 169/5000
# 3/3 [==============================] - 0s 46ms/step - loss: 1.6895 - metrics_pearsonr: 0.7027 - val_loss: 1.6763 - val_metrics_pearsonr: 0.7167
# Epoch 170/5000
# 3/3 [==============================] - 0s 52ms/step - loss: 1.6884 - metrics_pearsonr: 0.7011 - val_loss: 1.6752 - val_metrics_pearsonr: 0.7150
# Epoch 171/5000
# 3/3 [==============================] - 0s 55ms/step - loss: 1.6873 - metrics_pearsonr: 0.6996 - val_loss: 1.6740 - val_metrics_pearsonr: 0.7133
# Epoch 172/5000
# 3/3 [==============================] - 0s 50ms/step - loss: 1.6862 - metrics_pearsonr: 0.6980 - val_loss: 1.6729 - val_metrics_pearsonr: 0.7116
# Epoch 173/5000
# 3/3 [==============================] - 0s 49ms/step - loss: 1.6852 - metrics_pearsonr: 0.6965 - val_loss: 1.6718 - val_metrics_pearsonr: 0.7100
# Epoch 174/5000
# 3/3 [==============================] - 0s 47ms/step - loss: 1.6841 - metrics_pearsonr: 0.6949 - val_loss: 1.6706 - val_metrics_pearsonr: 0.7083
# Epoch 175/5000
# 3/3 [==============================] - 0s 44ms/step - loss: 1.6831 - metrics_pearsonr: 0.6934 - val_loss: 1.6695 - val_metrics_pearsonr: 0.7067
# Epoch 176/5000
# 3/3 [==============================] - 0s 47ms/step - loss: 1.6820 - metrics_pearsonr: 0.6919 - val_loss: 1.6684 - val_metrics_pearsonr: 0.7050
# Epoch 177/5000
# 3/3 [==============================] - 0s 48ms/step - loss: 1.6810 - metrics_pearsonr: 0.6904 - val_loss: 1.6673 - val_metrics_pearsonr: 0.7034
# Epoch 178/5000
# 3/3 [==============================] - 0s 51ms/step - loss: 1.6800 - metrics_pearsonr: 0.6889 - val_loss: 1.6662 - val_metrics_pearsonr: 0.7018
# Epoch 179/5000
# 3/3 [==============================] - 0s 49ms/step - loss: 1.6789 - metrics_pearsonr: 0.6874 - val_loss: 1.6651 - val_metrics_pearsonr: 0.7002
# Epoch 180/5000
# 3/3 [==============================] - 0s 52ms/step - loss: 1.6779 - metrics_pearsonr: 0.6860 - val_loss: 1.6640 - val_metrics_pearsonr: 0.6987
# Epoch 181/5000
# 3/3 [==============================] - 0s 49ms/step - loss: 1.6769 - metrics_pearsonr: 0.6845 - val_loss: 1.6630 - val_metrics_pearsonr: 0.6971
# Epoch 182/5000
# 3/3 [==============================] - 0s 50ms/step - loss: 1.6759 - metrics_pearsonr: 0.6831 - val_loss: 1.6619 - val_metrics_pearsonr: 0.6955
# Epoch 183/5000
# 3/3 [==============================] - 0s 48ms/step - loss: 1.6749 - metrics_pearsonr: 0.6817 - val_loss: 1.6608 - val_metrics_pearsonr: 0.6940
# Epoch 184/5000
# 3/3 [==============================] - 0s 47ms/step - loss: 1.6739 - metrics_pearsonr: 0.6803 - val_loss: 1.6598 - val_metrics_pearsonr: 0.6925
# Epoch 185/5000
# 3/3 [==============================] - 0s 49ms/step - loss: 1.6729 - metrics_pearsonr: 0.6789 - val_loss: 1.6588 - val_metrics_pearsonr: 0.6909
# Epoch 186/5000
# 3/3 [==============================] - 0s 49ms/step - loss: 1.6720 - metrics_pearsonr: 0.6775 - val_loss: 1.6577 - val_metrics_pearsonr: 0.6894
# Epoch 187/5000
# 3/3 [==============================] - 0s 50ms/step - loss: 1.6710 - metrics_pearsonr: 0.6761 - val_loss: 1.6567 - val_metrics_pearsonr: 0.6879
# Epoch 188/5000
# 3/3 [==============================] - 0s 50ms/step - loss: 1.6700 - metrics_pearsonr: 0.6747 - val_loss: 1.6557 - val_metrics_pearsonr: 0.6864
# Epoch 189/5000
# 3/3 [==============================] - 0s 50ms/step - loss: 1.6691 - metrics_pearsonr: 0.6734 - val_loss: 1.6547 - val_metrics_pearsonr: 0.6850
# Epoch 190/5000
# 3/3 [==============================] - 0s 50ms/step - loss: 1.6681 - metrics_pearsonr: 0.6720 - val_loss: 1.6536 - val_metrics_pearsonr: 0.6835
# Epoch 191/5000
# 3/3 [==============================] - 0s 47ms/step - loss: 1.6672 - metrics_pearsonr: 0.6707 - val_loss: 1.6526 - val_metrics_pearsonr: 0.6821
# Epoch 192/5000
# 3/3 [==============================] - 0s 47ms/step - loss: 1.6662 - metrics_pearsonr: 0.6693 - val_loss: 1.6517 - val_metrics_pearsonr: 0.6806
# Epoch 193/5000
# 3/3 [==============================] - 0s 48ms/step - loss: 1.6653 - metrics_pearsonr: 0.6680 - val_loss: 1.6507 - val_metrics_pearsonr: 0.6792
# Epoch 194/5000
# 3/3 [==============================] - 0s 48ms/step - loss: 1.6643 - metrics_pearsonr: 0.6667 - val_loss: 1.6497 - val_metrics_pearsonr: 0.6777
# Epoch 195/5000
# 3/3 [==============================] - 0s 54ms/step - loss: 1.6634 - metrics_pearsonr: 0.6654 - val_loss: 1.6487 - val_metrics_pearsonr: 0.6763
# Epoch 196/5000
# 3/3 [==============================] - 0s 54ms/step - loss: 1.6625 - metrics_pearsonr: 0.6641 - val_loss: 1.6477 - val_metrics_pearsonr: 0.6749
# Epoch 197/5000
# 3/3 [==============================] - 0s 49ms/step - loss: 1.6616 - metrics_pearsonr: 0.6628 - val_loss: 1.6468 - val_metrics_pearsonr: 0.6735
# Epoch 198/5000
# 3/3 [==============================] - 0s 53ms/step - loss: 1.6607 - metrics_pearsonr: 0.6615 - val_loss: 1.6458 - val_metrics_pearsonr: 0.6721
# Epoch 199/5000
# 3/3 [==============================] - 0s 53ms/step - loss: 1.6598 - metrics_pearsonr: 0.6602 - val_loss: 1.6449 - val_metrics_pearsonr: 0.6708
# Epoch 200/5000
# 3/3 [==============================] - 0s 55ms/step - loss: 1.6588 - metrics_pearsonr: 0.6589 - val_loss: 1.6439 - val_metrics_pearsonr: 0.6694
# Epoch 201/5000
# 3/3 [==============================] - 0s 56ms/step - loss: 1.6579 - metrics_pearsonr: 0.6577 - val_loss: 1.6430 - val_metrics_pearsonr: 0.6680
# Epoch 202/5000
# 3/3 [==============================] - 0s 52ms/step - loss: 1.6571 - metrics_pearsonr: 0.6564 - val_loss: 1.6421 - val_metrics_pearsonr: 0.6667
# Epoch 203/5000
# 3/3 [==============================] - 0s 54ms/step - loss: 1.6562 - metrics_pearsonr: 0.6552 - val_loss: 1.6412 - val_metrics_pearsonr: 0.6653
# Epoch 204/5000
# 3/3 [==============================] - 0s 53ms/step - loss: 1.6553 - metrics_pearsonr: 0.6539 - val_loss: 1.6402 - val_metrics_pearsonr: 0.6640
# Epoch 205/5000
# 3/3 [==============================] - 0s 55ms/step - loss: 1.6544 - metrics_pearsonr: 0.6527 - val_loss: 1.6393 - val_metrics_pearsonr: 0.6627
# Epoch 206/5000
# 3/3 [==============================] - 0s 55ms/step - loss: 1.6535 - metrics_pearsonr: 0.6515 - val_loss: 1.6384 - val_metrics_pearsonr: 0.6614
# Epoch 207/5000
# 3/3 [==============================] - 0s 51ms/step - loss: 1.6526 - metrics_pearsonr: 0.6502 - val_loss: 1.6375 - val_metrics_pearsonr: 0.6600
# Epoch 208/5000
# 3/3 [==============================] - 0s 52ms/step - loss: 1.6518 - metrics_pearsonr: 0.6490 - val_loss: 1.6366 - val_metrics_pearsonr: 0.6587
# Epoch 209/5000
# 3/3 [==============================] - 0s 50ms/step - loss: 1.6509 - metrics_pearsonr: 0.6478 - val_loss: 1.6358 - val_metrics_pearsonr: 0.6575
# Epoch 210/5000
# 3/3 [==============================] - 0s 47ms/step - loss: 1.6500 - metrics_pearsonr: 0.6466 - val_loss: 1.6349 - val_metrics_pearsonr: 0.6562
# Epoch 211/5000
# 3/3 [==============================] - 0s 51ms/step - loss: 1.6492 - metrics_pearsonr: 0.6454 - val_loss: 1.6340 - val_metrics_pearsonr: 0.6549
# Epoch 212/5000
# 3/3 [==============================] - 0s 52ms/step - loss: 1.6483 - metrics_pearsonr: 0.6442 - val_loss: 1.6331 - val_metrics_pearsonr: 0.6536
# Epoch 213/5000
# 3/3 [==============================] - 0s 48ms/step - loss: 1.6475 - metrics_pearsonr: 0.6430 - val_loss: 1.6323 - val_metrics_pearsonr: 0.6524
# Epoch 214/5000
# 3/3 [==============================] - 0s 49ms/step - loss: 1.6466 - metrics_pearsonr: 0.6419 - val_loss: 1.6314 - val_metrics_pearsonr: 0.6511
# Epoch 215/5000
# 3/3 [==============================] - 0s 45ms/step - loss: 1.6458 - metrics_pearsonr: 0.6407 - val_loss: 1.6306 - val_metrics_pearsonr: 0.6499
# Epoch 216/5000
# 3/3 [==============================] - 0s 48ms/step - loss: 1.6449 - metrics_pearsonr: 0.6395 - val_loss: 1.6297 - val_metrics_pearsonr: 0.6487
# Epoch 217/5000
# 3/3 [==============================] - 0s 54ms/step - loss: 1.6441 - metrics_pearsonr: 0.6384 - val_loss: 1.6289 - val_metrics_pearsonr: 0.6474
# Epoch 218/5000
# 3/3 [==============================] - 0s 52ms/step - loss: 1.6433 - metrics_pearsonr: 0.6372 - val_loss: 1.6280 - val_metrics_pearsonr: 0.6462
# Epoch 219/5000
# 3/3 [==============================] - 0s 50ms/step - loss: 1.6424 - metrics_pearsonr: 0.6361 - val_loss: 1.6272 - val_metrics_pearsonr: 0.6450
# Epoch 220/5000
# 3/3 [==============================] - 0s 51ms/step - loss: 1.6416 - metrics_pearsonr: 0.6349 - val_loss: 1.6264 - val_metrics_pearsonr: 0.6438
# Epoch 221/5000
# 3/3 [==============================] - 0s 49ms/step - loss: 1.6408 - metrics_pearsonr: 0.6338 - val_loss: 1.6256 - val_metrics_pearsonr: 0.6426
# Epoch 222/5000
# 3/3 [==============================] - 0s 46ms/step - loss: 1.6400 - metrics_pearsonr: 0.6327 - val_loss: 1.6247 - val_metrics_pearsonr: 0.6415
# Epoch 223/5000
# 3/3 [==============================] - 0s 49ms/step - loss: 1.6391 - metrics_pearsonr: 0.6316 - val_loss: 1.6239 - val_metrics_pearsonr: 0.6403
# Epoch 224/5000
# 3/3 [==============================] - 0s 47ms/step - loss: 1.6383 - metrics_pearsonr: 0.6305 - val_loss: 1.6231 - val_metrics_pearsonr: 0.6391
# Epoch 225/5000
# 3/3 [==============================] - 0s 47ms/step - loss: 1.6375 - metrics_pearsonr: 0.6293 - val_loss: 1.6223 - val_metrics_pearsonr: 0.6380
# Epoch 226/5000
# 3/3 [==============================] - 0s 51ms/step - loss: 1.6367 - metrics_pearsonr: 0.6282 - val_loss: 1.6215 - val_metrics_pearsonr: 0.6368
# Epoch 227/5000
# 3/3 [==============================] - 0s 50ms/step - loss: 1.6359 - metrics_pearsonr: 0.6272 - val_loss: 1.6207 - val_metrics_pearsonr: 0.6357
# Epoch 228/5000
# 3/3 [==============================] - 0s 55ms/step - loss: 1.6351 - metrics_pearsonr: 0.6261 - val_loss: 1.6199 - val_metrics_pearsonr: 0.6345
# Epoch 229/5000
# 3/3 [==============================] - 0s 52ms/step - loss: 1.6343 - metrics_pearsonr: 0.6250 - val_loss: 1.6192 - val_metrics_pearsonr: 0.6334
# Epoch 230/5000
# 3/3 [==============================] - 0s 51ms/step - loss: 1.6335 - metrics_pearsonr: 0.6239 - val_loss: 1.6184 - val_metrics_pearsonr: 0.6323
# Epoch 231/5000
# 3/3 [==============================] - 0s 51ms/step - loss: 1.6327 - metrics_pearsonr: 0.6228 - val_loss: 1.6176 - val_metrics_pearsonr: 0.6312
# Epoch 232/5000
# 3/3 [==============================] - 0s 45ms/step - loss: 1.6319 - metrics_pearsonr: 0.6218 - val_loss: 1.6168 - val_metrics_pearsonr: 0.6301
# Epoch 233/5000
# 3/3 [==============================] - 0s 50ms/step - loss: 1.6311 - metrics_pearsonr: 0.6207 - val_loss: 1.6161 - val_metrics_pearsonr: 0.6290
# Epoch 234/5000
# 3/3 [==============================] - 0s 50ms/step - loss: 1.6303 - metrics_pearsonr: 0.6197 - val_loss: 1.6153 - val_metrics_pearsonr: 0.6279
# Epoch 235/5000
# 3/3 [==============================] - 0s 48ms/step - loss: 1.6295 - metrics_pearsonr: 0.6186 - val_loss: 1.6145 - val_metrics_pearsonr: 0.6269
# Epoch 236/5000
# 3/3 [==============================] - 0s 52ms/step - loss: 1.6288 - metrics_pearsonr: 0.6176 - val_loss: 1.6138 - val_metrics_pearsonr: 0.6258
# Epoch 237/5000
# 3/3 [==============================] - 0s 50ms/step - loss: 1.6280 - metrics_pearsonr: 0.6166 - val_loss: 1.6130 - val_metrics_pearsonr: 0.6247
# Epoch 238/5000
# 3/3 [==============================] - 0s 49ms/step - loss: 1.6272 - metrics_pearsonr: 0.6155 - val_loss: 1.6123 - val_metrics_pearsonr: 0.6237
# Epoch 239/5000
# 3/3 [==============================] - 0s 46ms/step - loss: 1.6264 - metrics_pearsonr: 0.6145 - val_loss: 1.6115 - val_metrics_pearsonr: 0.6226
# Epoch 240/5000
# 3/3 [==============================] - 0s 47ms/step - loss: 1.6256 - metrics_pearsonr: 0.6135 - val_loss: 1.6108 - val_metrics_pearsonr: 0.6216
# Epoch 241/5000
# 3/3 [==============================] - 0s 53ms/step - loss: 1.6249 - metrics_pearsonr: 0.6125 - val_loss: 1.6101 - val_metrics_pearsonr: 0.6206
# Epoch 242/5000
# 3/3 [==============================] - 0s 49ms/step - loss: 1.6241 - metrics_pearsonr: 0.6115 - val_loss: 1.6093 - val_metrics_pearsonr: 0.6195
# Epoch 243/5000
# 3/3 [==============================] - 0s 51ms/step - loss: 1.6233 - metrics_pearsonr: 0.6105 - val_loss: 1.6086 - val_metrics_pearsonr: 0.6185
# Epoch 244/5000
# 3/3 [==============================] - 0s 52ms/step - loss: 1.6225 - metrics_pearsonr: 0.6095 - val_loss: 1.6079 - val_metrics_pearsonr: 0.6175
# Epoch 245/5000
# 3/3 [==============================] - 0s 48ms/step - loss: 1.6218 - metrics_pearsonr: 0.6085 - val_loss: 1.6071 - val_metrics_pearsonr: 0.6165
# Epoch 246/5000
# 3/3 [==============================] - 0s 51ms/step - loss: 1.6210 - metrics_pearsonr: 0.6075 - val_loss: 1.6064 - val_metrics_pearsonr: 0.6155
# Epoch 247/5000
# 3/3 [==============================] - 0s 51ms/step - loss: 1.6203 - metrics_pearsonr: 0.6065 - val_loss: 1.6057 - val_metrics_pearsonr: 0.6145
# Epoch 248/5000
# 3/3 [==============================] - 0s 51ms/step - loss: 1.6195 - metrics_pearsonr: 0.6056 - val_loss: 1.6050 - val_metrics_pearsonr: 0.6135
# Epoch 249/5000
# 3/3 [==============================] - 0s 50ms/step - loss: 1.6187 - metrics_pearsonr: 0.6046 - val_loss: 1.6043 - val_metrics_pearsonr: 0.6125
# Epoch 250/5000
# 3/3 [==============================] - 0s 50ms/step - loss: 1.6180 - metrics_pearsonr: 0.6036 - val_loss: 1.6035 - val_metrics_pearsonr: 0.6116
# Epoch 251/5000
# 3/3 [==============================] - 0s 51ms/step - loss: 1.6172 - metrics_pearsonr: 0.6027 - val_loss: 1.6028 - val_metrics_pearsonr: 0.6106
# Epoch 252/5000
# 3/3 [==============================] - 0s 50ms/step - loss: 1.6164 - metrics_pearsonr: 0.6017 - val_loss: 1.6021 - val_metrics_pearsonr: 0.6096
# Epoch 253/5000
# 3/3 [==============================] - 0s 49ms/step - loss: 1.6157 - metrics_pearsonr: 0.6008 - val_loss: 1.6014 - val_metrics_pearsonr: 0.6087
# Epoch 254/5000
# 3/3 [==============================] - 0s 48ms/step - loss: 1.6149 - metrics_pearsonr: 0.5998 - val_loss: 1.6007 - val_metrics_pearsonr: 0.6077
# Epoch 255/5000
# 3/3 [==============================] - 0s 53ms/step - loss: 1.6142 - metrics_pearsonr: 0.5989 - val_loss: 1.6000 - val_metrics_pearsonr: 0.6068
# Epoch 256/5000
# 3/3 [==============================] - 0s 50ms/step - loss: 1.6134 - metrics_pearsonr: 0.5980 - val_loss: 1.5993 - val_metrics_pearsonr: 0.6059
# Epoch 257/5000
# 3/3 [==============================] - 0s 49ms/step - loss: 1.6127 - metrics_pearsonr: 0.5970 - val_loss: 1.5986 - val_metrics_pearsonr: 0.6049
# Epoch 258/5000
# 3/3 [==============================] - 0s 48ms/step - loss: 1.6119 - metrics_pearsonr: 0.5961 - val_loss: 1.5979 - val_metrics_pearsonr: 0.6040
# Epoch 259/5000
# 3/3 [==============================] - 0s 51ms/step - loss: 1.6112 - metrics_pearsonr: 0.5952 - val_loss: 1.5973 - val_metrics_pearsonr: 0.6031
# Epoch 260/5000
# 3/3 [==============================] - 0s 58ms/step - loss: 1.6104 - metrics_pearsonr: 0.5943 - val_loss: 1.5966 - val_metrics_pearsonr: 0.6022
# Epoch 261/5000
# 3/3 [==============================] - 0s 59ms/step - loss: 1.6097 - metrics_pearsonr: 0.5934 - val_loss: 1.5959 - val_metrics_pearsonr: 0.6013
# Epoch 262/5000
# 3/3 [==============================] - 0s 57ms/step - loss: 1.6089 - metrics_pearsonr: 0.5925 - val_loss: 1.5952 - val_metrics_pearsonr: 0.6004
# Epoch 263/5000
# 3/3 [==============================] - 0s 57ms/step - loss: 1.6082 - metrics_pearsonr: 0.5916 - val_loss: 1.5945 - val_metrics_pearsonr: 0.5995
# Epoch 264/5000
# 3/3 [==============================] - 0s 61ms/step - loss: 1.6074 - metrics_pearsonr: 0.5907 - val_loss: 1.5938 - val_metrics_pearsonr: 0.5986
# Epoch 265/5000
# 3/3 [==============================] - 0s 54ms/step - loss: 1.6067 - metrics_pearsonr: 0.5898 - val_loss: 1.5932 - val_metrics_pearsonr: 0.5977
# Epoch 266/5000
# 3/3 [==============================] - 0s 63ms/step - loss: 1.6060 - metrics_pearsonr: 0.5889 - val_loss: 1.5925 - val_metrics_pearsonr: 0.5968
# Epoch 267/5000
# 3/3 [==============================] - 0s 59ms/step - loss: 1.6052 - metrics_pearsonr: 0.5880 - val_loss: 1.5918 - val_metrics_pearsonr: 0.5959
# Epoch 268/5000
# 3/3 [==============================] - 0s 59ms/step - loss: 1.6045 - metrics_pearsonr: 0.5871 - val_loss: 1.5911 - val_metrics_pearsonr: 0.5951
# Epoch 269/5000
# 3/3 [==============================] - 0s 60ms/step - loss: 1.6037 - metrics_pearsonr: 0.5862 - val_loss: 1.5905 - val_metrics_pearsonr: 0.5942
# Epoch 270/5000
# 3/3 [==============================] - 0s 63ms/step - loss: 1.6030 - metrics_pearsonr: 0.5853 - val_loss: 1.5898 - val_metrics_pearsonr: 0.5933
# Epoch 271/5000
# 3/3 [==============================] - 0s 63ms/step - loss: 1.6023 - metrics_pearsonr: 0.5845 - val_loss: 1.5891 - val_metrics_pearsonr: 0.5925
# Epoch 272/5000
# 3/3 [==============================] - 0s 59ms/step - loss: 1.6015 - metrics_pearsonr: 0.5836 - val_loss: 1.5884 - val_metrics_pearsonr: 0.5916
# Epoch 273/5000
# 3/3 [==============================] - 0s 59ms/step - loss: 1.6008 - metrics_pearsonr: 0.5827 - val_loss: 1.5878 - val_metrics_pearsonr: 0.5908
# Epoch 274/5000
# 3/3 [==============================] - 0s 56ms/step - loss: 1.6000 - metrics_pearsonr: 0.5819 - val_loss: 1.5871 - val_metrics_pearsonr: 0.5899
# Epoch 275/5000
# 3/3 [==============================] - 0s 63ms/step - loss: 1.5993 - metrics_pearsonr: 0.5810 - val_loss: 1.5864 - val_metrics_pearsonr: 0.5891
# Epoch 276/5000
# 3/3 [==============================] - 0s 53ms/step - loss: 1.5986 - metrics_pearsonr: 0.5802 - val_loss: 1.5858 - val_metrics_pearsonr: 0.5882
# Epoch 277/5000
# 3/3 [==============================] - 0s 54ms/step - loss: 1.5978 - metrics_pearsonr: 0.5793 - val_loss: 1.5851 - val_metrics_pearsonr: 0.5874
# Epoch 278/5000
# 3/3 [==============================] - 0s 50ms/step - loss: 1.5971 - metrics_pearsonr: 0.5785 - val_loss: 1.5845 - val_metrics_pearsonr: 0.5866
# Epoch 279/5000
# ...
# Epoch 821/5000
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0944 - metrics_pearsonr: 0.0098 - val_loss: 0.1235 - val_metrics_pearsonr: 0.0122
# Epoch 822/5000
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0943 - metrics_pearsonr: 0.0098 - val_loss: 0.1235 - val_metrics_pearsonr: 0.0122
# Epoch 823/5000
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0943 - metrics_pearsonr: 0.0098 - val_loss: 0.1235 - val_metrics_pearsonr: 0.0122
# Epoch 824/5000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0943 - metrics_pearsonr: 0.0098 - val_loss: 0.1235 - val_metrics_pearsonr: 0.0122
# Epoch 825/5000
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0943 - metrics_pearsonr: 0.0098 - val_loss: 0.1235 - val_metrics_pearsonr: 0.0122
# Epoch 826/5000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0943 - metrics_pearsonr: 0.0098 - val_loss: 0.1235 - val_metrics_pearsonr: 0.0122
# Epoch 827/5000
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0943 - metrics_pearsonr: 0.0098 - val_loss: 0.1235 - val_metrics_pearsonr: 0.0122
# Epoch 828/5000
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0943 - metrics_pearsonr: 0.0098 - val_loss: 0.1235 - val_metrics_pearsonr: 0.0122
# Epoch 829/5000
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0943 - metrics_pearsonr: 0.0098 - val_loss: 0.1235 - val_metrics_pearsonr: 0.0122
# Epoch 830/5000
# 3/3 [==============================] - 0s 70ms/step - loss: 0.0943 - metrics_pearsonr: 0.0098 - val_loss: 0.1235 - val_metrics_pearsonr: 0.0122
# Epoch 831/5000
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0943 - metrics_pearsonr: 0.0097 - val_loss: 0.1235 - val_metrics_pearsonr: 0.0122
# Epoch 832/5000
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0943 - metrics_pearsonr: 0.0097 - val_loss: 0.1235 - val_metrics_pearsonr: 0.0122
# Epoch 833/5000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0943 - metrics_pearsonr: 0.0097 - val_loss: 0.1235 - val_metrics_pearsonr: 0.0122
# Epoch 834/5000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0943 - metrics_pearsonr: 0.0097 - val_loss: 0.1235 - val_metrics_pearsonr: 0.0122
# Epoch 835/5000
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0942 - metrics_pearsonr: 0.0097 - val_loss: 0.1235 - val_metrics_pearsonr: 0.0122
# Epoch 836/5000
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0942 - metrics_pearsonr: 0.0097 - val_loss: 0.1235 - val_metrics_pearsonr: 0.0122
# Epoch 837/5000
# 3/3 [==============================] - 0s 50ms/step - loss: 0.0942 - metrics_pearsonr: 0.0097 - val_loss: 0.1235 - val_metrics_pearsonr: 0.0122
# Epoch 838/5000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0942 - metrics_pearsonr: 0.0097 - val_loss: 0.1235 - val_metrics_pearsonr: 0.0122
# Epoch 839/5000
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0942 - metrics_pearsonr: 0.0097 - val_loss: 0.1235 - val_metrics_pearsonr: 0.0122
# Epoch 840/5000
# 3/3 [==============================] - 0s 53ms/step - loss: 0.0942 - metrics_pearsonr: 0.0097 - val_loss: 0.1235 - val_metrics_pearsonr: 0.0122
# Epoch 841/5000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0942 - metrics_pearsonr: 0.0097 - val_loss: 0.1235 - val_metrics_pearsonr: 0.0122
# Epoch 842/5000
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0942 - metrics_pearsonr: 0.0097 - val_loss: 0.1235 - val_metrics_pearsonr: 0.0122
# Epoch 843/5000
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0942 - metrics_pearsonr: 0.0097 - val_loss: 0.1235 - val_metrics_pearsonr: 0.0122
# Epoch 844/5000
# 3/3 [==============================] - 0s 53ms/step - loss: 0.0942 - metrics_pearsonr: 0.0097 - val_loss: 0.1235 - val_metrics_pearsonr: 0.0122
# Epoch 845/5000
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0942 - metrics_pearsonr: 0.0097 - val_loss: 0.1235 - val_metrics_pearsonr: 0.0122
# Epoch 846/5000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0942 - metrics_pearsonr: 0.0097 - val_loss: 0.1235 - val_metrics_pearsonr: 0.0122
# Epoch 847/5000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0941 - metrics_pearsonr: 0.0097 - val_loss: 0.1235 - val_metrics_pearsonr: 0.0122
# Epoch 848/5000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0941 - metrics_pearsonr: 0.0097 - val_loss: 0.1235 - val_metrics_pearsonr: 0.0122
# Epoch 849/5000
# 3/3 [==============================] - 0s 51ms/step - loss: 0.0941 - metrics_pearsonr: 0.0097 - val_loss: 0.1235 - val_metrics_pearsonr: 0.0122
# Epoch 850/5000
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0941 - metrics_pearsonr: 0.0097 - val_loss: 0.1235 - val_metrics_pearsonr: 0.0122
# Epoch 851/5000
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0941 - metrics_pearsonr: 0.0097 - val_loss: 0.1235 - val_metrics_pearsonr: 0.0122
# Epoch 852/5000
# 3/3 [==============================] - 0s 51ms/step - loss: 0.0941 - metrics_pearsonr: 0.0097 - val_loss: 0.1235 - val_metrics_pearsonr: 0.0122
# Epoch 853/5000
# 3/3 [==============================] - 0s 53ms/step - loss: 0.0941 - metrics_pearsonr: 0.0097 - val_loss: 0.1235 - val_metrics_pearsonr: 0.0122
# Epoch 854/5000
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0941 - metrics_pearsonr: 0.0097 - val_loss: 0.1235 - val_metrics_pearsonr: 0.0122
# Epoch 855/5000
# 3/3 [==============================] - 0s 51ms/step - loss: 0.0941 - metrics_pearsonr: 0.0097 - val_loss: 0.1235 - val_metrics_pearsonr: 0.0122
# Epoch 856/5000
# 3/3 [==============================] - 0s 52ms/step - loss: 0.0941 - metrics_pearsonr: 0.0097 - val_loss: 0.1235 - val_metrics_pearsonr: 0.0122
# Epoch 857/5000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0941 - metrics_pearsonr: 0.0097 - val_loss: 0.1235 - val_metrics_pearsonr: 0.0122
# Epoch 858/5000
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0941 - metrics_pearsonr: 0.0097 - val_loss: 0.1235 - val_metrics_pearsonr: 0.0122
# Epoch 859/5000
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0941 - metrics_pearsonr: 0.0097 - val_loss: 0.1235 - val_metrics_pearsonr: 0.0122
# Epoch 860/5000
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0940 - metrics_pearsonr: 0.0097 - val_loss: 0.1234 - val_metrics_pearsonr: 0.0122
# Epoch 861/5000
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0940 - metrics_pearsonr: 0.0097 - val_loss: 0.1234 - val_metrics_pearsonr: 0.0122
# Epoch 862/5000
# 3/3 [==============================] - 0s 53ms/step - loss: 0.0940 - metrics_pearsonr: 0.0097 - val_loss: 0.1234 - val_metrics_pearsonr: 0.0122
# Epoch 863/5000
# 3/3 [==============================] - 0s 51ms/step - loss: 0.0940 - metrics_pearsonr: 0.0097 - val_loss: 0.1234 - val_metrics_pearsonr: 0.0122
# Epoch 864/5000
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0940 - metrics_pearsonr: 0.0097 - val_loss: 0.1234 - val_metrics_pearsonr: 0.0122
# Epoch 865/5000
# 3/3 [==============================] - 0s 49ms/step - loss: 0.0940 - metrics_pearsonr: 0.0097 - val_loss: 0.1234 - val_metrics_pearsonr: 0.0122
# Epoch 866/5000
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0940 - metrics_pearsonr: 0.0097 - val_loss: 0.1234 - val_metrics_pearsonr: 0.0122
# Epoch 867/5000
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0940 - metrics_pearsonr: 0.0097 - val_loss: 0.1234 - val_metrics_pearsonr: 0.0122
# Epoch 868/5000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0940 - metrics_pearsonr: 0.0097 - val_loss: 0.1234 - val_metrics_pearsonr: 0.0122
# Epoch 869/5000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0940 - metrics_pearsonr: 0.0097 - val_loss: 0.1234 - val_metrics_pearsonr: 0.0122
# Epoch 870/5000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0940 - metrics_pearsonr: 0.0097 - val_loss: 0.1234 - val_metrics_pearsonr: 0.0122
# Epoch 871/5000
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0940 - metrics_pearsonr: 0.0097 - val_loss: 0.1234 - val_metrics_pearsonr: 0.0122
# Epoch 872/5000
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0940 - metrics_pearsonr: 0.0097 - val_loss: 0.1234 - val_metrics_pearsonr: 0.0122
# Epoch 873/5000
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0939 - metrics_pearsonr: 0.0097 - val_loss: 0.1234 - val_metrics_pearsonr: 0.0122
# Epoch 874/5000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0939 - metrics_pearsonr: 0.0097 - val_loss: 0.1234 - val_metrics_pearsonr: 0.0122
# Epoch 875/5000
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0939 - metrics_pearsonr: 0.0097 - val_loss: 0.1234 - val_metrics_pearsonr: 0.0122
# Epoch 876/5000
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0939 - metrics_pearsonr: 0.0097 - val_loss: 0.1234 - val_metrics_pearsonr: 0.0122
# Epoch 877/5000
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0939 - metrics_pearsonr: 0.0097 - val_loss: 0.1234 - val_metrics_pearsonr: 0.0122
# Epoch 878/5000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0939 - metrics_pearsonr: 0.0097 - val_loss: 0.1234 - val_metrics_pearsonr: 0.0122
# Epoch 879/5000
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0939 - metrics_pearsonr: 0.0097 - val_loss: 0.1234 - val_metrics_pearsonr: 0.0122
# Epoch 880/5000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0939 - metrics_pearsonr: 0.0097 - val_loss: 0.1234 - val_metrics_pearsonr: 0.0122
# Epoch 881/5000
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0939 - metrics_pearsonr: 0.0097 - val_loss: 0.1234 - val_metrics_pearsonr: 0.0122
# Epoch 882/5000
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0939 - metrics_pearsonr: 0.0097 - val_loss: 0.1234 - val_metrics_pearsonr: 0.0122
# Epoch 883/5000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0939 - metrics_pearsonr: 0.0097 - val_loss: 0.1234 - val_metrics_pearsonr: 0.0122
# Epoch 884/5000
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0939 - metrics_pearsonr: 0.0097 - val_loss: 0.1234 - val_metrics_pearsonr: 0.0122
# Epoch 885/5000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0938 - metrics_pearsonr: 0.0097 - val_loss: 0.1234 - val_metrics_pearsonr: 0.0122
# Epoch 886/5000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0938 - metrics_pearsonr: 0.0097 - val_loss: 0.1234 - val_metrics_pearsonr: 0.0122
# Epoch 887/5000
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0938 - metrics_pearsonr: 0.0097 - val_loss: 0.1234 - val_metrics_pearsonr: 0.0122
# Epoch 888/5000
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0938 - metrics_pearsonr: 0.0097 - val_loss: 0.1234 - val_metrics_pearsonr: 0.0122
# Epoch 889/5000
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0938 - metrics_pearsonr: 0.0097 - val_loss: 0.1234 - val_metrics_pearsonr: 0.0122
# Epoch 890/5000
# 3/3 [==============================] - 0s 50ms/step - loss: 0.0938 - metrics_pearsonr: 0.0097 - val_loss: 0.1234 - val_metrics_pearsonr: 0.0122
# Epoch 891/5000
# 3/3 [==============================] - 0s 53ms/step - loss: 0.0938 - metrics_pearsonr: 0.0097 - val_loss: 0.1234 - val_metrics_pearsonr: 0.0122
# Epoch 892/5000
# 3/3 [==============================] - 0s 53ms/step - loss: 0.0938 - metrics_pearsonr: 0.0097 - val_loss: 0.1234 - val_metrics_pearsonr: 0.0122
# Epoch 893/5000
# 3/3 [==============================] - 0s 53ms/step - loss: 0.0938 - metrics_pearsonr: 0.0097 - val_loss: 0.1234 - val_metrics_pearsonr: 0.0122
# Epoch 894/5000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0938 - metrics_pearsonr: 0.0097 - val_loss: 0.1234 - val_metrics_pearsonr: 0.0122
# Epoch 895/5000
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0938 - metrics_pearsonr: 0.0097 - val_loss: 0.1234 - val_metrics_pearsonr: 0.0122
# Epoch 896/5000
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0938 - metrics_pearsonr: 0.0097 - val_loss: 0.1234 - val_metrics_pearsonr: 0.0122
# Epoch 897/5000
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0938 - metrics_pearsonr: 0.0097 - val_loss: 0.1233 - val_metrics_pearsonr: 0.0122
# Epoch 898/5000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0937 - metrics_pearsonr: 0.0097 - val_loss: 0.1233 - val_metrics_pearsonr: 0.0122
# Epoch 899/5000
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0937 - metrics_pearsonr: 0.0096 - val_loss: 0.1233 - val_metrics_pearsonr: 0.0122
# Epoch 900/5000
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0937 - metrics_pearsonr: 0.0096 - val_loss: 0.1233 - val_metrics_pearsonr: 0.0122
# Epoch 901/5000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0937 - metrics_pearsonr: 0.0096 - val_loss: 0.1233 - val_metrics_pearsonr: 0.0122
# Epoch 902/5000
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0937 - metrics_pearsonr: 0.0096 - val_loss: 0.1233 - val_metrics_pearsonr: 0.0122
# Epoch 903/5000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0937 - metrics_pearsonr: 0.0096 - val_loss: 0.1233 - val_metrics_pearsonr: 0.0122
# Epoch 904/5000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0937 - metrics_pearsonr: 0.0096 - val_loss: 0.1233 - val_metrics_pearsonr: 0.0122
# Epoch 905/5000
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0937 - metrics_pearsonr: 0.0096 - val_loss: 0.1233 - val_metrics_pearsonr: 0.0122
# Epoch 906/5000
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0937 - metrics_pearsonr: 0.0096 - val_loss: 0.1233 - val_metrics_pearsonr: 0.0122
# Epoch 907/5000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0937 - metrics_pearsonr: 0.0096 - val_loss: 0.1233 - val_metrics_pearsonr: 0.0122
# Epoch 908/5000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0937 - metrics_pearsonr: 0.0096 - val_loss: 0.1233 - val_metrics_pearsonr: 0.0122
# Epoch 909/5000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0937 - metrics_pearsonr: 0.0096 - val_loss: 0.1233 - val_metrics_pearsonr: 0.0122
# Epoch 910/5000
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0937 - metrics_pearsonr: 0.0096 - val_loss: 0.1233 - val_metrics_pearsonr: 0.0122
# Epoch 911/5000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0936 - metrics_pearsonr: 0.0096 - val_loss: 0.1233 - val_metrics_pearsonr: 0.0122
# Epoch 912/5000
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0936 - metrics_pearsonr: 0.0096 - val_loss: 0.1233 - val_metrics_pearsonr: 0.0122
# Epoch 913/5000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0936 - metrics_pearsonr: 0.0096 - val_loss: 0.1233 - val_metrics_pearsonr: 0.0122
# Epoch 914/5000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0936 - metrics_pearsonr: 0.0096 - val_loss: 0.1233 - val_metrics_pearsonr: 0.0122
# Epoch 915/5000
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0936 - metrics_pearsonr: 0.0096 - val_loss: 0.1233 - val_metrics_pearsonr: 0.0122
# Epoch 916/5000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0936 - metrics_pearsonr: 0.0096 - val_loss: 0.1233 - val_metrics_pearsonr: 0.0122
# Epoch 917/5000
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0936 - metrics_pearsonr: 0.0096 - val_loss: 0.1233 - val_metrics_pearsonr: 0.0122
# Epoch 918/5000
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0936 - metrics_pearsonr: 0.0096 - val_loss: 0.1233 - val_metrics_pearsonr: 0.0122
# Epoch 919/5000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0936 - metrics_pearsonr: 0.0096 - val_loss: 0.1233 - val_metrics_pearsonr: 0.0122
# Epoch 920/5000
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0936 - metrics_pearsonr: 0.0096 - val_loss: 0.1233 - val_metrics_pearsonr: 0.0122
# Epoch 921/5000

# %%
print(np.nanmean(np.abs(testy-predicty)))

# %%
print(testy.shape,predicty.shape)

# %%
times=np.arange(3519)
testy_w=testy
predicty_w=predicty
levels=[1000,925,850,700,600,500,400]

# %%
import numpy as np
import xarray as xr
import os



dim_names = ('times',  'levels')


testy_w_da = xr.DataArray(
    data=testy_w,
    coords={
        'times': times,
        'levels': levels
    },
    dims=dim_names,
    name='testy_w' 
)


predicty_w_da = xr.DataArray(
    data=predicty_w,
    coords={
        'times': times,
        'levels': levels
    },
    dims=dim_names,
    name='predicty_w'
)

testy_w_da.to_netcdf('E:/huawei/result/huawei_Transformer_30min_k5_gnss_to_wind_testy_w_onestation_45.nc')
predicty_w_da.to_netcdf('E:/huawei/result/huawei_Transformer_30min_k5_gnss_to_wind_predicty_w_onestation_45.nc')

# %%
import numpy as np
import xarray as xr
testy_w_file=xr.open_dataset('E:/huawei/result/huawei_Transformer_30min_k5_gnss_to_wind_testy_w_onestation_45.nc')
predicty_w_file=xr.open_dataset('E:/huawei/result/huawei_Transformer_30min_k5_gnss_to_wind_predicty_w_onestation_45.nc')
testy_w=np.array(testy_w_file['testy_w'])
predicty_w=np.array(predicty_w_file['predicty_w'])

# %%
#CDF匹配
def Auto_cdf_matching(vx,vy):
    import numpy as np
    from scipy.interpolate import InterpolatedUnivariateSpline
    from scipy.optimize import curve_fit

    if np.array(vx).ndim==1:
        vx_cdf = (np.arange(len(vx)) +  1) / (len(vx))
        vy_cdf = (np.arange(len(vy)) +  1) / (len(vy))
        
        spl = InterpolatedUnivariateSpline(vx_cdf, np.sort(vx))
        vx_interp = spl(vy_cdf)
        
        def func(x, a, b, c, d):
            return a*x + b*x**2 + c*x**3 + d
        
        popt = curve_fit(func, vx_interp, np.sort(vy))[0]
        
        matched_vx = func(vx, *popt)
    elif np.array(vx).ndim==2:
        matched_vx=np.zeros((vx.shape[0],vx.shape[1]))
        for i in range(vx.shape[1]):
            vx_cdf = (np.arange(len(vx[:,i])) +  1) / (len(vx[:,i]))
            vy_cdf = (np.arange(len(vy[:,i])) +  1) / (len(vy[:,i]))
            
            spl = InterpolatedUnivariateSpline(vx_cdf, np.sort(vx[:,i]))
            vx_interp = spl(vy_cdf)
            
            def func(x, a, b, c, d):
                return a*x + b*x**2 + c*x**3 + d
            
            popt = curve_fit(func, vx_interp, np.sort(vy[:,i]))[0]
            
            matched_vx[:,i] = func(vx[:,i], *popt)
    elif np.array(vx).ndim==3:
        matched_vx=np.zeros((vx.shape[0],vx.shape[1],vx.shape[2]))
        for i in range(vx.shape[1]):
            for j in range(vx.shape[2]):
                vx_cdf = (np.arange(len(vx[:,i,j])) +  1) / (len(vx[:,i,j]))
                vy_cdf = (np.arange(len(vy[:,i,j])) +  1) / (len(vy[:,i,j]))
                
                spl = InterpolatedUnivariateSpline(vx_cdf, np.sort(vx[:,i,j]))
                vx_interp = spl(vy_cdf)
                
                def func(x, a, b, c, d):
                    return a*x + b*x**2 + c*x**3 + d
                
                popt = curve_fit(func, vx_interp, np.sort(vy[:,i,j]))[0]
                
                matched_vx[:,i,j] = func(vx[:,i,j], *popt)
    elif np.array(vx).ndim==4:
        matched_vx=np.zeros((vx.shape[0],vx.shape[1],vx.shape[2],vx.shape[3]))
        for i in range(vx.shape[1]):
            for j in range(vx.shape[2]):
                for k in range(vx.shape[3]):
                    vx_cdf = (np.arange(len(vx[:,i,j,k])) +  1) / (len(vx[:,i,j,k]))
                    vy_cdf = (np.arange(len(vy[:,i,j,k])) +  1) / (len(vy[:,i,j,k]))
                    
                    spl = InterpolatedUnivariateSpline(vx_cdf, np.sort(vx[:,i,j,k]))
                    vx_interp = spl(vy_cdf)
                    
                    def func(x, a, b, c, d):
                        return a*x + b*x**2 + c*x**3 + d
                    
                    popt = curve_fit(func, vx_interp, np.sort(vy[:,i,j,k]))[0]
                    
                    matched_vx[:,i,j,k] = func(vx[:,i,j,k], *popt)

    return matched_vx

# %%
from sklearn.model_selection import train_test_split
import Auto_paint_self
np.random.seed(25)
trainy,testy,trainx,testx = train_test_split(np.array(vy),vx,test_size=0.2,random_state=25)
predicty_w=Auto_cdf_matching(np.array(predicty_w),trainy[np.random.randint(0,trainy.shape[0], predicty_w.shape[0]),:])

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,mean_absolute_percentage_error
from scipy.stats import pearsonr
import numpy as np
import math
from tqdm import tqdm
from metpy.calc import wind_direction,wind_speed
from metpy.units import units
u_rmse=np.zeros((predicty_w.shape[1]))
u_mae=np.zeros((predicty_w.shape[1]))
u_pearson=np.zeros((predicty_w.shape[1]))
u_mape=np.zeros((predicty_w.shape[1]))
for i in tqdm(range(predicty_w.shape[1])):
    u_rmse[i]=mean_squared_error(testy_w[:,i],predicty_w[:,i])
    u_pearson[i],_=pearsonr(testy_w[:,i],predicty_w[:,i])
    u_mae[i]=mean_absolute_error(testy_w[:,i],predicty_w[:,i])
    u_mape[i]=mean_absolute_percentage_error(testy_w[:,i],predicty_w[:,i])

# %%
print(u_mae)
print(np.nanmean(u_mae))
# Out:
# [0.26212736 0.25347935 0.25259449 0.2504057  0.10520037 0.18845806
#  0.18952211]
# 0.21454106194178543

# %%
print(u_rmse)
print(np.nanmean(u_rmse))
# Out:
# [0.20570476 0.18758424 0.18049292 0.17780147 0.02538498 0.06226063
#  0.06187716]
# 0.1287294506315829

# %%
u_p=np.sqrt(u_rmse)/(np.nanmax(testy_w,axis=0)-np.nanmin(testy_w,axis=0))
#v_p=np.sqrt(v_rmse)/(np.nanmax(testy_w,axis=0)-np.nanmin(testy_w,axis=0))
#wind_p=np.sqrt(wind_rmse)/(np.nanmax(np.sqrt(testy_w**2+testy_w**2),axis=0)-np.nanmin(np.sqrt(testy_w**2+testy_w**2),axis=0))
print(u_p)
print(np.nanmean(u_p))
# Out:
# [0.05335845 0.04866404 0.04632116 0.04690328 0.05727608 0.04253487
#  0.07078215]
# 0.0522628626882183

# %%
import numpy as np
import xarray as xr
import os



dim_names = ('times',  'levels')

predicty_w_da_cdf = xr.DataArray(
    data=predicty_w,
    coords={
        'times': times,
        'levels': levels
    },
    dims=dim_names,
    name='predicty_w'
)

predicty_w_da.to_netcdf('E:/huawei/result/huawei_Transformer_30min_k5_gnss_to_wind_predicty_w_cdf_onestation_45.nc')

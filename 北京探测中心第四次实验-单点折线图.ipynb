# %%
import Auto_paint_self

# %%
import xarray as xr
testy_u_file=xr.open_dataset('E:/huawei/result/huawei_Transformer_30min_k5_gnss_to_wind_testy_u_morestation.nc')
predicty_u_file=xr.open_dataset('E:/huawei/result/huawei_Transformer_30min_k5_gnss_to_wind_predicty_u_cdf_morestation.nc')
testy_v_file=xr.open_dataset('E:/huawei/result/huawei_Transformer_30min_k5_gnss_to_wind_testy_v_morestation.nc')
predicty_v_file=xr.open_dataset('E:/huawei/result/huawei_Transformer_30min_k5_gnss_to_wind_predicty_v_cdf_morestation.nc')
testy_w_file=xr.open_dataset('E:/huawei/result/huawei_Transformer_30min_k5_gnss_to_wind_testy_w_morestation.nc')
predicty_w_file=xr.open_dataset('E:/huawei/result/huawei_Transformer_30min_k5_gnss_to_wind_predicty_w_cdf_morestation.nc')

# %%
import numpy as np
testy_u_0=np.array(testy_u_file['testy_u'])
testy_v_0=np.array(testy_v_file['testy_v'])
testy_w_0=np.array(testy_w_file['testy_w'])
predicty_u_0=np.array(predicty_u_file['predicty_u'])
predicty_v_0=np.array(predicty_v_file['predicty_v'])
predicty_w_0=np.array(predicty_w_file['predicty_w'])

# %%
import numpy as np
print(np.nanmax(testy_u_0),np.nanmin(testy_u_0))
print(np.nanmax(testy_v_0),np.nanmin(testy_v_0))
print(np.nanmax(testy_w_0),np.nanmin(testy_w_0))
print(np.nanmax(predicty_u_0),np.nanmin(predicty_u_0))
print(np.nanmax(predicty_v_0),np.nanmin(predicty_v_0))
print(np.nanmax(predicty_w_0),np.nanmin(predicty_w_0))
# Out:
# 54.836826 -48.028748
# 48.24479 -47.002983
# 12.3 -4.0
# 48.89511 -51.638817
# 47.49828 -51.302166
# 13.527603 -4.569709

# %%
print(testy_u_0.shape[0])
# Out:
# 3519

# %%
import numpy as np
regressline,ym,yf,yd=Auto_paint_self.Autobar_or_line([np.nanmean(testy_u_0[:100,:,0],axis=1),np.nanmean(predicty_u_0[:100,:,0],axis=1)],np.arange(100),'Time','no',None,None,'no',None,None,'no',None,None,'line',vs=None,ifself_vmax_vmin='no',selfvmax=0.08,selfvmin=0.04,linenum=2,xlabelname='Time',ylabelname='Wind Speed(m/s)',bar_line_title='U_30min_1000hPa',label=['test','predict'],linewidth=4,selfcolor=['r','b'],iftend='no',ifmultitend='no',iffilter='no',filtermode=None,extent=None,rangement=None,ifdetend='no',detendtype=None,ifstdline='no',ifmean='no',xspace=20,labelsize=40,xlabelformat='self',valuemodel='+')

# %%
import numpy as np
regressline,ym,yf,yd=Auto_paint_self.Autobar_or_line([np.nanmean(testy_u_0[:100,:,3],axis=1),np.nanmean(predicty_u_0[:100,:,3],axis=1)],np.arange(100),'Time','no',None,None,'no',None,None,'no',None,None,'line',vs=None,ifself_vmax_vmin='no',selfvmax=0.08,selfvmin=0.04,linenum=2,xlabelname='Time',ylabelname='Wind Speed(m/s)',bar_line_title='U_30min_700hPa',label=['test','predict'],linewidth=4,selfcolor=['r','b'],iftend='no',ifmultitend='no',iffilter='no',filtermode=None,extent=None,rangement=None,ifdetend='no',detendtype=None,ifstdline='no',ifmean='no',xspace=20,labelsize=40,xlabelformat='self',valuemodel='+')

# %%
import numpy as np
regressline,ym,yf,yd=Auto_paint_self.Autobar_or_line([np.nanmean(testy_u_0[:100,:,6],axis=1),np.nanmean(predicty_u_0[:100,:,6],axis=1)],np.arange(100),'Time','no',None,None,'no',None,None,'no',None,None,'line',vs=None,ifself_vmax_vmin='no',selfvmax=0.08,selfvmin=0.04,linenum=2,xlabelname='Time',ylabelname='Wind Speed(m/s)',bar_line_title='U_30min_400hPa',label=['test','predict'],linewidth=4,selfcolor=['r','b'],iftend='no',ifmultitend='no',iffilter='no',filtermode=None,extent=None,rangement=None,ifdetend='no',detendtype=None,ifstdline='no',ifmean='no',xspace=20,labelsize=40,xlabelformat='self',valuemodel='+')

# %%
import numpy as np
regressline,ym,yf,yd=Auto_paint_self.Autobar_or_line([np.nanmean(testy_v_0[:100,:,0],axis=1),np.nanmean(predicty_v_0[:100,:,0],axis=1)],np.arange(100),'Time','no',None,None,'no',None,None,'no',None,None,'line',vs=None,ifself_vmax_vmin='no',selfvmax=0.08,selfvmin=0.04,linenum=2,xlabelname='Time',ylabelname='Wind Speed(m/s)',bar_line_title='V_30min_1000hPa',label=['test','predict'],linewidth=4,selfcolor=['r','b'],iftend='no',ifmultitend='no',iffilter='no',filtermode=None,extent=None,rangement=None,ifdetend='no',detendtype=None,ifstdline='no',ifmean='no',xspace=20,labelsize=40,xlabelformat='self',valuemodel='+')

# %%
import numpy as np
regressline,ym,yf,yd=Auto_paint_self.Autobar_or_line([np.nanmean(testy_v_0[:100,:,3],axis=1),np.nanmean(predicty_v_0[:100,:,3],axis=1)],np.arange(100),'Time','no',None,None,'no',None,None,'no',None,None,'line',vs=None,ifself_vmax_vmin='no',selfvmax=0.08,selfvmin=0.04,linenum=2,xlabelname='Time',ylabelname='Wind Speed(m/s)',bar_line_title='V_30min_700hPa',label=['test','predict'],linewidth=4,selfcolor=['r','b'],iftend='no',ifmultitend='no',iffilter='no',filtermode=None,extent=None,rangement=None,ifdetend='no',detendtype=None,ifstdline='no',ifmean='no',xspace=20,labelsize=40,xlabelformat='self',valuemodel='+')

# %%
import numpy as np
regressline,ym,yf,yd=Auto_paint_self.Autobar_or_line([np.nanmean(testy_v_0[:100,:,6],axis=1),np.nanmean(predicty_v_0[:100,:,6],axis=1)],np.arange(100),'Time','no',None,None,'no',None,None,'no',None,None,'line',vs=None,ifself_vmax_vmin='no',selfvmax=0.08,selfvmin=0.04,linenum=2,xlabelname='Time',ylabelname='Wind Speed(m/s)',bar_line_title='V_30min_400hPa',label=['test','predict'],linewidth=4,selfcolor=['r','b'],iftend='no',ifmultitend='no',iffilter='no',filtermode=None,extent=None,rangement=None,ifdetend='no',detendtype=None,ifstdline='no',ifmean='no',xspace=20,labelsize=40,xlabelformat='self',valuemodel='+')

# %%
import numpy as np
regressline,ym,yf,yd=Auto_paint_self.Autobar_or_line([np.nanmean(testy_w_0[:100,:,0],axis=1),np.nanmean(predicty_w_0[:100,:,0],axis=1)],np.arange(100),'Time','no',None,None,'no',None,None,'no',None,None,'line',vs=None,ifself_vmax_vmin='no',selfvmax=0.08,selfvmin=0.04,linenum=2,xlabelname='Time',ylabelname='Wind Speed(Pa/s)',bar_line_title='W_30min_1000hPa',label=['test','predict'],linewidth=4,selfcolor=['r','b'],iftend='no',ifmultitend='no',iffilter='no',filtermode=None,extent=None,rangement=None,ifdetend='no',detendtype=None,ifstdline='no',ifmean='no',xspace=20,labelsize=40,xlabelformat='self',valuemodel='+')

# %%
import numpy as np
regressline,ym,yf,yd=Auto_paint_self.Autobar_or_line([np.nanmean(testy_w_0[:100,:,3],axis=1),np.nanmean(predicty_w_0[:100,:,3],axis=1)],np.arange(100),'Time','no',None,None,'no',None,None,'no',None,None,'line',vs=None,ifself_vmax_vmin='no',selfvmax=0.08,selfvmin=0.04,linenum=2,xlabelname='Time',ylabelname='Wind Speed(Pa/s)',bar_line_title='W_30min_700hPa',label=['test','predict'],linewidth=4,selfcolor=['r','b'],iftend='no',ifmultitend='no',iffilter='no',filtermode=None,extent=None,rangement=None,ifdetend='no',detendtype=None,ifstdline='no',ifmean='no',xspace=20,labelsize=40,xlabelformat='self',valuemodel='+')

# %%
import numpy as np
regressline,ym,yf,yd=Auto_paint_self.Autobar_or_line([np.nanmean(testy_w_0[:100,:,6],axis=1),np.nanmean(predicty_w_0[:100,:,6],axis=1)],np.arange(100),'Time','no',None,None,'no',None,None,'no',None,None,'line',vs=None,ifself_vmax_vmin='yes',selfvmax=1.0,selfvmin=-0.2,linenum=2,xlabelname='Time',ylabelname='Wind Speed(Pa/s)',bar_line_title='W_30min_400hPa',label=['test','predict'],linewidth=4,selfcolor=['r','b'],iftend='no',ifmultitend='no',iffilter='no',filtermode=None,extent=None,rangement=None,ifdetend='no',detendtype=None,ifstdline='no',ifmean='no',xspace=20,labelsize=40,xlabelformat='self',valuemodel='+')

# %%
import xarray as xr

# %%
gnss_file=xr.open_dataset(r'E:/gnss_ztd_combined_robust.nc')
wind_file=xr.open_dataset(r'E:/merged_stations_6min_common_period_float32_target_height.nc')

# %%
import pandas as pd
wind_new_time = pd.date_range(wind_file.Datetime.values[0], wind_file.Datetime.values[-1], freq='5T')
wind_file = wind_file.interp(Datetime=wind_new_time)
# Out:
# C:\Users\TBYC\AppData\Local\Temp\ipykernel_420128\3977475666.py:2: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   wind_new_time = pd.date_range(wind_file.Datetime.values[0], wind_file.Datetime.values[-1], freq='5T')

# %%
import numpy as np
print(np.array(gnss_file['time']))
print(np.array(wind_file['Datetime']))
# Out:
# ['2025-05-06T07:10:00.000000000' '2025-05-06T07:15:00.000000000'
#  '2025-05-06T07:20:00.000000000' ... '2025-07-21T00:45:00.000000000'
#  '2025-07-21T00:50:00.000000000' '2025-07-21T00:55:00.000000000']
# ['2024-07-29T09:30:00.000000000' '2024-07-29T09:35:00.000000000'
#  '2024-07-29T09:40:00.000000000' ... '2025-07-21T23:40:00.000000000'
#  '2025-07-21T23:45:00.000000000' '2025-07-21T23:50:00.000000000']

# %%
# 先插值填充内部 NaN
gnss_file = gnss_file.interpolate_na(dim='time')

# 再前向填充和后向填充
gnss_file = gnss_file.ffill(dim='time').bfill(dim='time')

# %%
print(np.isnan(gnss_file['ztd']).any())
print(np.isnan(wind_file['U']).any())
print(np.isnan(wind_file['V']).any())
print(np.isnan(wind_file['W']).any())
# Out:
# <xarray.DataArray 'ztd' ()> Size: 1B
# array(False)
# <xarray.DataArray 'U' ()> Size: 1B
# array(False)
# <xarray.DataArray 'V' ()> Size: 1B
# array(False)
# <xarray.DataArray 'W' ()> Size: 1B
# array(False)

# %%
import xarray as xr
import numpy as np
import pandas as pd
import time # 用于性能比较


def prepare_transformer_inputs_mem_efficient_robust(gnss_ds: xr.Dataset, wind_ds: xr.Dataset):
    """
    更稳健的版本，处理时间戳 dtype 不匹配的问题。
    """
    start_time = time.time()
    
    gnss_ztd = gnss_ds['ztd']
    wind_u = wind_ds['U']
    
    sequence_length = 6
    time_step = pd.to_timedelta('5min')
    expected_duration = time_step * (sequence_length - 1)

    num_gnss_times = len(gnss_ztd.time)
    
    # --- Pass 1: 扫描并找到所有有效样本的起始索引 ---
    print("Pass 1: 正在扫描有效的连续序列 (稳健模式)...")
    
    # 打印 dtype 以供参考
    gnss_dtype = gnss_ztd.time.dtype
    wind_dtype = wind_u.Datetime.dtype
    print(f"GNSS 时间 dtype: {gnss_dtype}, Wind 时间 dtype: {wind_dtype}")
    # 获取 wind_dtype 的单位，如 'ns', 'us'
    wind_dtype_unit = np.datetime_data(wind_dtype)[0]

    valid_start_indices = []
    wind_times_set = set(wind_u.Datetime.values)

    for i in range(num_gnss_times - sequence_length + 1):
        window_times = gnss_ztd.time[i : i + sequence_length]
        
        # 稳健地比较时长，避免微小浮点误差
        actual_duration = window_times[-1].values - window_times[0].values
        if np.abs(actual_duration - expected_duration) < pd.to_timedelta('1s'):
            
            # 计算目标时间
            target_wind_time_raw = window_times[-1].values + time_step
            
            # 【关键修复】: 将计算出的时间强制转换为与风场数据相同的时间类型/精度
            target_wind_time_converted = np.datetime64(target_wind_time_raw, wind_dtype_unit)

            if target_wind_time_converted in wind_times_set:
                valid_start_indices.append(i)
    
    num_samples = len(valid_start_indices)
    print(f"Pass 1 完成. 共找到 {num_samples} 个有效样本。耗时: {time.time() - start_time:.2f} 秒。")

    if num_samples == 0:
        print("在稳健模式下仍然未找到任何有效序列。请检查数据本身，例如风场数据是否覆盖了GNSS数据的时间范围。")
        return None, None

    # --- 内存分配 (Pass 2) ---
    # ... (这部分代码与之前相同，无需更改) ...
    # 为了完整性，我将其余代码也附上
    print("正在预分配内存...")
    num_stations_gnss = len(gnss_ztd.station)
    num_stations_wind = len(wind_u.station)
    num_press_levels = len(wind_u.HEIGHT)
    
    vx_data = np.empty((num_samples, sequence_length, num_stations_gnss), dtype=np.float32)
    vy_data = np.empty((num_samples, num_stations_wind * num_press_levels), dtype=np.float32)

    print("Pass 2: 正在填充数据...")
    fill_start_time = time.time()
    gnss_ztd_values = gnss_ztd.values
    
    for k, start_idx in enumerate(valid_start_indices):
        end_idx = start_idx + sequence_length
        vx_data[k, :, :] = gnss_ztd_values[start_idx:end_idx, :]
        
        last_gnss_time = gnss_ztd.time[end_idx - 1]
        target_wind_time = last_gnss_time.values + time_step
        
        # 在这里也需要使用转换后的时间来索引
        target_wind_time_converted = np.datetime64(target_wind_time, wind_dtype_unit)
        vy_slice_values = wind_u.sel(Datetime=target_wind_time_converted).values
        vy_data[k, :] = vy_slice_values.flatten()
        
    print(f"Pass 2 完成. 数据填充完毕。耗时: {time.time() - fill_start_time:.2f} 秒。")

    print("正在创建最终的 xarray.DataArray...")
    sample_coords = gnss_ztd.time.values[valid_start_indices]
    vx = xr.DataArray(
        vx_data,
        dims=('sample', 'timesteps', 'station'),
        coords={'sample': sample_coords, 'timesteps': np.arange(sequence_length), 'station': gnss_ztd.station.values}
    )

    vy_flat_coords = wind_u.stack(station_HEIGHT_flat=('station', 'HEIGHT')).coords['station_HEIGHT_flat']
    vy = xr.DataArray(
        vy_data,
        dims=('sample', 'station_HEIGHT_flat'),
        coords={'sample': sample_coords, 'station_HEIGHT_flat': vy_flat_coords}
    )
    
    total_time = time.time() - start_time
    print(f"所有处理完成！总耗时: {total_time:.2f} 秒。")
    return vx, vy

# --- 主程序 ---
if __name__ == '__main__':
    

    # 调用内存优化后的函数
    vx, vy = prepare_transformer_inputs_mem_efficient_robust(gnss_file, wind_file)

    if vx is not None and vy is not None:
        print("\n--- 处理后结果 ---")
        print("输入变量 vx:")
        print(f"  - 形状: {vx.shape}")
        print(f"  - 维度: {vx.dims}")
        print(f"  - 内存占用: {vx.nbytes / 1e6:.2f} MB")
        
        print("\n目标变量 vy:")
        print(f"  - 形状: {vy.shape}")
        print(f"  - 维度: {vy.dims}")
        print(f"  - 内存占用: {vy.nbytes / 1e6:.2f} MB")
# Out:
# Pass 1: 正在扫描有效的连续序列 (稳健模式)...
# GNSS 时间 dtype: datetime64[ns], Wind 时间 dtype: datetime64[ns]
# Pass 1 完成. 共找到 21701 个有效样本。耗时: 23.57 秒。
# 正在预分配内存...
# Pass 2: 正在填充数据...
# Pass 2 完成. 数据填充完毕。耗时: 13.00 秒。
# 正在创建最终的 xarray.DataArray...
# 所有处理完成！总耗时: 36.59 秒。
#
# --- 处理后结果 ---
# 输入变量 vx:
#   - 形状: (21701, 6, 566)
#   - 维度: ('sample', 'timesteps', 'station')
#   - 内存占用: 294.79 MB
#
# 目标变量 vy:
#   - 形状: (21701, 126)
#   - 维度: ('sample', 'station_HEIGHT_flat')
#   - 内存占用: 10.94 MB

# %%
print(vx,vy)
# Out:
# <xarray.DataArray (sample: 21701, timesteps: 6, station: 566)> Size: 295MB
# array([[[2.443    , 2.3116667, 2.313    , ..., 2.557333 , 2.4726152,
#          2.461167 ],
#         [2.443    , 2.3116667, 2.313    , ..., 2.557333 , 2.4726152,
#          2.461167 ],
#         [2.443    , 2.3116667, 2.313    , ..., 2.557333 , 2.4726152,
#          2.461167 ],
#         [2.443    , 2.3116667, 2.313    , ..., 2.557333 , 2.4726152,
#          2.461167 ],
#         [2.443    , 2.3116667, 2.313    , ..., 2.557333 , 2.4726152,
#          2.461167 ],
#         [2.443    , 2.3116667, 2.313    , ..., 2.557333 , 2.4726152,
#          2.461167 ]],
#
#        [[2.443    , 2.3116667, 2.313    , ..., 2.557333 , 2.4726152,
#          2.461167 ],
#         [2.443    , 2.3116667, 2.313    , ..., 2.557333 , 2.4726152,
#          2.461167 ],
#         [2.443    , 2.3116667, 2.313    , ..., 2.557333 , 2.4726152,
#          2.461167 ],
#         [2.443    , 2.3116667, 2.313    , ..., 2.557333 , 2.4726152,
# ...
#          2.6803334],
#         [3.1784878, 2.6205418, 2.6423497, ..., 2.6727898, 2.6653574,
#          2.681    ],
#         [3.1784878, 2.6205418, 2.6423497, ..., 2.6720002, 2.6676466,
#          2.681    ],
#         [3.1784878, 2.6205418, 2.6423497, ..., 2.6720002, 2.6676466,
#          2.681    ]],
#
#        [[3.1784878, 2.6205418, 2.6423497, ..., 2.674    , 2.66575  ,
#          2.6765835],
#         [3.1784878, 2.6205418, 2.6423497, ..., 2.674    , 2.6651337,
#          2.6803334],
#         [3.1784878, 2.6205418, 2.6423497, ..., 2.6727898, 2.6653574,
#          2.681    ],
#         [3.1784878, 2.6205418, 2.6423497, ..., 2.6720002, 2.6676466,
#          2.681    ],
#         [3.1784878, 2.6205418, 2.6423497, ..., 2.6720002, 2.6676466,
#          2.681    ],
#         [3.1784878, 2.6205418, 2.6423497, ..., 2.6720002, 2.6676466,
#          2.681    ]]], dtype=float32)
# Coordinates:
#   * sample     (sample) datetime64[ns] 174kB 2025-05-06T07:10:00 ... 2025-07-...
#   * timesteps  (timesteps) int32 24B 0 1 2 3 4 5
#   * station    (station) <U9 20kB 'H11548254' 'H11558032' ... 'H999941' <xarray.DataArray (sample: 21701, station_HEIGHT_flat: 126)> Size: 11MB
# array([[  7.7478147 ,   7.0394907 ,  -1.3876826 , ...,  13.111865  ,
#          19.096012  ,  22.109     ],
#        [  7.596307  ,   7.008233  ,  -0.6011833 , ...,  13.013256  ,
#          19.00613   ,  22.851686  ],
#        [  7.3797507 ,   6.9515295 ,   0.23502637, ...,  12.946916  ,
#          18.921799  ,  23.398497  ],
#        ...,
#        [ -4.979111  ,  -8.0465555 ,  -9.425159  , ..., -18.83729   ,
#         -22.136707  , -16.003502  ],
#        [ -5.0013747 ,  -8.096504  ,  -9.610194  , ..., -18.70027   ,
#         -22.107334  , -16.013554  ],
#        [ -4.9975247 ,  -8.086926  ,  -9.8997965 , ..., -18.592031  ,
#         -22.052372  , -16.064676  ]], dtype=float32)
# Coordinates:
#   * sample               (sample) datetime64[ns] 174kB 2025-05-06T07:10:00 .....
#   * station_HEIGHT_flat  (station_HEIGHT_flat) object 1kB MultiIndex
#   * station              (station_HEIGHT_flat) int32 504B 58448 58448 ... 58755
#   * HEIGHT               (station_HEIGHT_flat) int32 504B 110 760 ... 5570 7160

# %%
#Transformer网络
def Auto_Transformer(vy,vx,timestep,model_list,test_size=0.2,valid_size=0.1,k_fold=None,task_mode='regression',if_best_mode='no',modelpath=None,encoder_deep=1,num_heads=2,key_dim=2,ifdropout='no',trans_dropout_rate=0.0,trans_units=64,trans_activation='sigmoid',embedding_num=None,if_weight_initialize='no',weight_initialize_method='TruncatedNormal',weight_initialize_parameter1=0.00,weight_initialize_parameter2=0.05,if_print_model='yes',loss_function='default',optimizer='SGD',metrics='default',if_early_stopping=None,learning_rate=0.01,epochs=2000,batch_size=20,ifrandom_split='yes',ifweight='yes',ifmute='no',ifsave='no',savepath=None,device='cpu'):
    import tensorflow as tf
    if device=='gpu':
        gpus = tf.config.list_physical_devices('GPU')
        if gpus:
            try:
                # 设置只使用 GPU 0
                tf.config.set_visible_devices(gpus[0], 'GPU')
                # 设置 GPU 0 的内存动态增长
                tf.config.experimental.set_memory_growth(gpus[0], True)
            except RuntimeError as e:
                print(e)
    else:
        os.environ["CUDA_VISIBLE_DEVICES"] = "-1"
    from keras.models import Sequential,Model
    from keras.layers.core import Activation,Dropout,Dense
    from keras.layers import Input,BatchNormalization,LayerNormalization,Embedding,Add,MultiHeadAttention,Flatten
    from keras.initializers import TruncatedNormal,RandomNormal,RandomUniform
    from sklearn.model_selection import train_test_split
    from sklearn.model_selection import KFold
    import numpy as np
    from tensorflow.keras.optimizers import SGD,Adam
    import keras
    from scipy.stats import pearsonr
    import os
    from sklearn.metrics import accuracy_score,recall_score,precision_score,f1_score
    from keras.models import load_model
    import sklearn
    import copy
    from sklearn.utils.class_weight import compute_class_weight
    from tensorflow.keras import backend as K
    import warnings
    warnings.filterwarnings("ignore")
    
    if embedding_num==None:
        embedding_num=timestep+1
    if task_mode=='regression':
        if loss_function=='default' or loss_function=='MeanSquaredError':
            loss=tf.keras.losses.MeanSquaredError()
        elif loss_function=='MeanSquaredError':
            loss=tf.keras.losses.MeanSquaredError()
        elif loss_function=='MeanAbsoluteError':
            loss=tf.keras.losses.MeanAbsoluteError()
        elif loss_function=='MeanAbsolutePercentageError':
            loss=tf.keras.losses.MeanAbsolutePercentageError()
        elif loss_function=='MeanSquaredLogarithmicError':
            loss=tf.keras.losses.MeanSquaredLogarithmicError()
        elif loss_function=='CosineSimilarity':
            loss=tf.keras.losses.CosineSimilarity()
        elif loss_function=='Huber':
            loss=tf.keras.losses.Huber()
        elif loss_function=='LogCosh':
            loss=tf.keras.losses.LogCosh()
        elif loss_function=='Pearsonr':
            def loss_pearsonr(y_true,y_pred):
                import tensorflow as tf
                y_true_mean=tf.reduce_mean(y_true,axis=0)
                y_pred_mean=tf.reduce_mean(y_pred,axis=0)
                cov=tf.reduce_sum((y_true-y_true_mean)*(y_pred-y_pred_mean),axis=0)
                y_true_v=tf.reduce_sum(tf.square((y_true-y_true_mean)),axis=0)
                y_pred_v=tf.reduce_sum(tf.square((y_pred-y_pred_mean)),axis=0)
                y_true_v=tf.sqrt(y_true_v)
                y_pred_v=tf.sqrt(y_pred_v)
                pearson=cov/(y_true_v*y_pred_v)
                return (1-pearson)**1.5
            loss=loss_pearsonr
        if metrics=='default' or metrics=='MeanSquaredError':
            metric=tf.keras.metrics.MeanSquaredError()
        elif metrics=='MeanAbsoluteError':
            metric=tf.keras.metrics.MeanAbsoluteError()
        elif metrics=='MeanAbsolutePercentageError':
            metric=tf.keras.metrics.MeanAbsolutePercentageError()
        elif metrics=='MeanSquaredLogarithmicError':
            metric=tf.keras.metrics.MeanSquaredLogarithmicError()
        elif metrics=='CosineSimilarity':
            metric=tf.keras.metrics.CosineSimilarity()
        elif metrics=='LogCoshError':
            metric=tf.keras.metrics.LogCoshError()
        elif metrics=='Pearsonr':
            def metrics_pearsonr(y_true,y_pred):
                import tensorflow as tf
                y_true_mean=tf.reduce_mean(y_true,axis=0)
                y_pred_mean=tf.reduce_mean(y_pred,axis=0)
                cov=tf.reduce_sum((y_true-y_true_mean)*(y_pred-y_pred_mean),axis=0)
                y_true_v=tf.reduce_sum(tf.square((y_true-y_true_mean)),axis=0)
                y_pred_v=tf.reduce_sum(tf.square((y_pred-y_pred_mean)),axis=0)
                y_true_v=tf.sqrt(y_true_v)
                y_pred_v=tf.sqrt(y_pred_v)
                pearson=cov/(y_true_v*y_pred_v)
                return (1-pearson)**1.5
            metric=metrics_pearsonr
    elif task_mode=='binary_classify':
        if loss_function=='default' or loss_function=='BinaryCrossentropy':
            loss=tf.keras.losses.BinaryCrossentropy()
        elif loss_function=='CategoricalCrossentropy':
            loss=tf.keras.losses.CategoricalCrossentropy()
        elif loss_function=='SparseCategoricalCrossentropy':
            loss=tf.keras.losses.SparseCategoricalCrossentropy()
        elif loss_function=='Poisson':
            loss=tf.keras.losses.Poisson()
        elif loss_function=='KLDivergence':
            loss=tf.keras.losses.KLDivergence()
        elif loss_function=='f1':
            def loss_f1(y_true, y_pred):
                y_true = K.cast(y_true, 'float32')
                y_pred = K.cast(y_pred, 'float32')
                
                tp = K.sum(y_true * y_pred)
                fp = K.sum((1 - y_true) * y_pred)
                fn = K.sum(y_true * (1 - y_pred))
                
                precision = tp / (tp + fp + K.epsilon())
                recall = tp / (tp + fn + K.epsilon())
                
                f1 = 2 * precision * recall / (precision + recall + K.epsilon())
                
                return 1 - f1
            loss=loss_f1
        if metrics=='default' or metrics=='BinaryAccuracy':
            metric=tf.keras.metrics.BinaryAccuracy()
        elif metrics=='MeanAbsoluteError':
            metric=tf.keras.metrics.MeanAbsoluteError()
        elif metrics=='Accuracy':
            metric=tf.keras.metrics.Accuracy()
        elif metrics=='CategoricalAccuracy':
            metric=tf.keras.metrics.CategoricalAccuracy()
        elif metrics=='SparseCategoricalAccuracy':
            metric=tf.keras.metrics.SparseCategoricalAccuracy()
        elif metrics=='TopKCategoricalAccuracy':
            metric=tf.keras.metrics.TopKCategoricalAccuracy()
        elif metrics=='SparseTopKCategoricalAccuracy':
            metric=tf.keras.metrics.SparseTopKCategoricalAccuracy()
        elif metrics=='BinaryCrossentropy':
            metric=tf.keras.metrics.BinaryCrossentropy()
        elif metrics=='CategoricalCrossentropy':
            metric=tf.keras.metrics.CategoricalCrossentropy()
        elif metrics=='SparseCategoricalCrossentropy':
            metric=tf.keras.metrics.SparseCategoricalCrossentropy()
        elif metrics=='Accuracy':
            metric=tf.keras.metrics.Accuracy()
        elif metrics=='CategoricalAccuracy':
            metric=tf.keras.metrics.CategoricalAccuracy()
        elif metrics=='SparseCategoricalAccuracy':
            metric=tf.keras.metrics.SparseCategoricalAccuracy()
        elif metrics=='KLDivergence':
            metric=tf.keras.metrics.KLDivergence()
        elif metrics=='Poisson':
            metric=tf.keras.metrics.Poisson()
        elif metrics=='AUC':
            metric=tf.keras.metrics.AUC()
        elif metrics=='Precision':
            metric=tf.keras.metrics.Precision()
        elif metrics=='Recall':
            metric=tf.keras.metrics.Recall()
        elif metrics=='TruePositives':
            metric=tf.keras.metrics.TruePositives()
        elif metrics=='TrueNegatives':
            metric=tf.keras.metrics.TrueNegatives()
        elif metrics=='FalsePositives':
            metric=tf.keras.metrics.FalsePositives()
        elif metrics=='FalseNegatives':
            metric=tf.keras.metrics.FalseNegatives()
        elif metrics=='PrecisionAtRecall':
            metric=tf.keras.metrics.PrecisionAtRecall()
        elif metrics=='SensitivityAtSpecificity':
            metric=tf.keras.metrics.SensitivityAtSpecificity()
        elif metrics=='SpecificityAtSensitivity':
            metric=tf.keras.metrics.SpecificityAtSensitivity()
        elif metrics=='f1':
            def metric_f1(y_true, y_pred):
                y_true = K.cast(y_true, 'float32')
                y_pred = K.cast(y_pred, 'float32')
                
                tp = K.sum(y_true * y_pred)
                fp = K.sum((1 - y_true) * y_pred)
                fn = K.sum(y_true * (1 - y_pred))
                
                precision = tp / (tp + fp + K.epsilon())
                recall = tp / (tp + fn + K.epsilon())
                
                f1 = 2 * precision * recall / (precision + recall + K.epsilon())
                
                return f1
            metric=metric_f1
    elif task_mode=='multi_classify':
        if loss_function=='default' or loss_function=='CategoricalCrossentropy':
            loss=tf.keras.losses.CategoricalCrossentropy()
        elif loss_function=='SparseCategoricalCrossentropy':
            loss=tf.keras.losses.SparseCategoricalCrossentropy()
        elif loss_function=='Poisson':
            loss=tf.keras.losses.Poisson()
        elif loss_function=='KLDivergence':
            loss=tf.keras.losses.KLDivergence()
        if metrics=='default' or metrics=='Accuracy':
            metric=tf.keras.metrics.Accuracy()
        elif metrics=='MeanAbsoluteError':
            metric=tf.keras.metrics.MeanAbsoluteError()
        elif metrics=='CategoricalAccuracy':
            metric=tf.keras.metrics.CategoricalAccuracy()
        elif metrics=='SparseCategoricalAccuracy':
            metric=tf.keras.metrics.SparseCategoricalAccuracy()
        elif metrics=='TopKCategoricalAccuracy':
            metric=tf.keras.metrics.TopKCategoricalAccuracy()
        elif metrics=='SparseTopKCategoricalAccuracy':
            metric=tf.keras.metrics.SparseTopKCategoricalAccuracy()
        elif metrics=='CategoricalCrossentropy':
            metric=tf.keras.metrics.CategoricalCrossentropy()
        elif metrics=='SparseCategoricalCrossentropy':
            metric=tf.keras.metrics.SparseCategoricalCrossentropy()
        elif metrics=='Accuracy':
            metric=tf.keras.metrics.Accuracy()
        elif metrics=='CategoricalAccuracy':
            metric=tf.keras.metrics.CategoricalAccuracy()
        elif metrics=='SparseCategoricalAccuracy':
            metric=tf.keras.metrics.SparseCategoricalAccuracy()
        elif metrics=='KLDivergence':
            metric=tf.keras.metrics.KLDivergence()
        elif metrics=='Poisson':
            metric=tf.keras.metrics.Poisson()
    weights=0
    model=0
    if vy.ndim==1:
        vy=vy.reshape(vy.shape[0],1)
    if ifrandom_split=='yes':
        trainy,testy,trainx,testx = train_test_split(vy,vx,test_size=test_size,random_state=25)
    else:
        index=int((1-test_size)*vy.shape[0])
        trainy=vy[:index]
        testy=vy[index:]
        trainx=vx[:index,:,:]
        testx=vx[index:,:,:]
    train_position=np.zeros((trainx.shape[0],trainx.shape[1]))
    test_position=np.zeros((testx.shape[0],testx.shape[1]))
    for i in range(trainx.shape[0]):
        train_position[i,:]=np.arange(0,timestep,1)
    for i in range(testx.shape[0]):
        test_position[i,:]=np.arange(0,timestep,1)
    if task_mode!='regression':
        def create_sample_weights_for_batch_multitask(y_batch_multitask, list_of_task_weights_dicts):
            batch_size, num_tasks = y_batch_multitask.shape
            
            if len(list_of_task_weights_dicts) != num_tasks:
                raise ValueError(f"Number of tasks in y_batch_multitask ({num_tasks}) "
                                 f"must match length of list_of_task_weights_dicts ({len(list_of_task_weights_dicts)}).")
        
            sample_weight_batch = np.ones_like(y_batch_multitask, dtype=np.float32)
        
            for i in range(num_tasks):
                task_labels_current_channel = y_batch_multitask[:, i] 
                weights_dict_for_task_i = list_of_task_weights_dicts[i]
                
                weight_for_0 = weights_dict_for_task_i.get(0, 1.0)
                weight_for_1 = weights_dict_for_task_i.get(1, 1.0)
                
                current_task_weights = sample_weight_batch[:, i] 
                current_task_weights[task_labels_current_channel == 0] = weight_for_0
                current_task_weights[task_labels_current_channel == 1] = weight_for_1
                sample_weight_batch[:, i] = current_task_weights
                
            return sample_weight_batch
        def compute_unified_class_weights(y, task_mode=task_mode):
            if task_mode == 'binary_classify':
                if y.ndim == 2 and y.shape[-1] > 1:
                    num_tasks = y.shape[-1]
                    list_of_task_weights_dicts = []
                    possible_binary_classes = np.array([0, 1])
                    for i in range(num_tasks):
                        y_task_i_flat = y[:, i].ravel()
                        if len(y_task_i_flat) == 0:
                            weights_dict_task_i = {0: 1.0, 1: 1.0} 
                        else:
                            valid_labels_mask = np.isin(y_task_i_flat, possible_binary_classes)
                            if not np.all(valid_labels_mask) and np.any(valid_labels_mask): 
                                y_task_i_flat_filtered = y_task_i_flat[valid_labels_mask]
                                if len(y_task_i_flat_filtered) == 0 : y_task_i_flat_filtered = np.array([0]) 
                            elif not np.any(valid_labels_mask): 
                                 y_task_i_flat_filtered = np.array([0]) 
                            else:
                                y_task_i_flat_filtered = y_task_i_flat
                            class_weights_arr = compute_class_weight(
                                class_weight='balanced',
                                classes=possible_binary_classes, 
                                y=y_task_i_flat_filtered
                            )
                            weights_dict_task_i = dict(zip(possible_binary_classes, class_weights_arr))
                        list_of_task_weights_dicts.append(weights_dict_task_i)
                    return list_of_task_weights_dicts 
        
                else: 
                    y_flat = y.ravel()
                    possible_binary_classes = np.array([0, 1])
                    valid_labels_mask = np.isin(y_flat, possible_binary_classes)
                    if not np.all(valid_labels_mask) and np.any(valid_labels_mask):
                        y_flat_filtered = y_flat[valid_labels_mask]
                        if len(y_flat_filtered) == 0 : y_flat_filtered = np.array([0])
                    elif not np.any(valid_labels_mask):
                         y_flat_filtered = np.array([0])
                    else:
                        y_flat_filtered = y_flat
        
                    class_weights_arr = compute_class_weight(
                        class_weight='balanced',
                        classes=possible_binary_classes,
                        y=y_flat_filtered
                    )
                    return dict(zip(possible_binary_classes, class_weights_arr)) 
        
            elif task_mode == 'multi_classify':
                y_flat = y.ravel()
                possible_multiclass_classes = np.arange(int(np.max(y)+1))
                valid_labels_mask = np.isin(y_flat, possible_multiclass_classes)
                if not np.all(valid_labels_mask) and np.any(valid_labels_mask):
                    y_flat_filtered = y_flat[valid_labels_mask]
                    if len(y_flat_filtered) == 0 : y_flat_filtered = np.array([0]) 
                elif not np.any(valid_labels_mask):
                    y_flat_filtered = np.array([0]) 
                else:
                    y_flat_filtered = y_flat
                class_weights_arr = compute_class_weight(
                    class_weight='balanced',
                    classes=possible_multiclass_classes,
                    y=y_flat_filtered
                )
                return dict(zip(possible_multiclass_classes, class_weights_arr)) 
            else:
                raise ValueError(f"Unsupported task_mode: {task_mode}")
        def create_unified_sample_weights_for_batch(y_batch, unified_class_weights):
            if isinstance(unified_class_weights, list):
                if not (y_batch.ndim == 2 and y_batch.shape[-1] == len(unified_class_weights)):
                     raise ValueError(f"Shape mismatch for multi-task binary weights. "
                                      f"y_batch shape: {y_batch.shape}, num_weight_dicts: {len(unified_class_weights)}")
                return create_sample_weights_for_batch_multitask(y_batch, unified_class_weights)
            elif isinstance(unified_class_weights, dict):
                y_int_labels_for_weights = y_batch
                if y_batch.ndim == 2 and y_batch.shape[-1] == 1: 
                    y_int_labels_for_weights = np.squeeze(y_batch, axis=-1)
                sample_weight_for_batch = np.ones_like(y_int_labels_for_weights, dtype=np.float32)
                for class_label, weight in unified_class_weights.items():
                    sample_weight_for_batch[y_int_labels_for_weights == class_label] = weight
                
                return sample_weight_for_batch
            else:
                raise TypeError(f"unified_class_weights has unexpected type: {type(unified_class_weights)}. Expected dict or list.")
        def train_data_generator(x,position, y, batch_size, task_mode=task_mode):
            num_samples = x.shape[0]
            global_unified_weights = compute_unified_class_weights(y, task_mode)
            while True:
                indices = np.arange(num_samples)
                
                for start in range(0, num_samples, batch_size):
                    end = min(start + batch_size, num_samples)
                    batch_indices = indices[start:end]
                    
                    if len(batch_indices) == 0:
                        continue
        
                    x_batch = x[batch_indices]
                    position_batch = position[batch_indices]
                    y_batch = y[batch_indices] 
                    sample_weight_batch = create_unified_sample_weights_for_batch(
                        y_batch, 
                        global_unified_weights
                    )
                    yield {"input_1": x_batch, "input_2": position_batch}, y_batch, sample_weight_batch
    else:
        def train_data_generator(x, position, y, batch_size):
            num_samples = x.shape[0]
            while True:
                indices = np.arange(num_samples)
                
                for start in range(0, num_samples, batch_size):
                    end = min(start + batch_size, num_samples)
                    batch_indices = indices[start:end]
                    
                    x_batch = x[batch_indices]  
                    position_batch = position[batch_indices]   
                    y_batch = y[batch_indices]      
                    
                    yield ({"input_1": x_batch, "input_2": position_batch}, y_batch)
    def test_data_generator(x, position, batch_size):
        num_samples = x.shape[0]
        while True:
            indices = np.arange(num_samples)
            
            for start in range(0, num_samples, batch_size):
                end = min(start + batch_size, num_samples)
                batch_indices = indices[start:end]
                
                x_batch = x[batch_indices]  # 第一个输入特征
                position_batch = position[batch_indices]
                
                yield ({"input_1": x_batch, "input_2": position_batch})
    if if_best_mode=='no':
        inputshape1=(None,timestep,trainx.shape[2])
        inputshape2=(None,timestep)
        inputs1=Input(shape=(timestep,trainx.shape[2]))
        inputs2=Input(shape=(timestep))
        for i in range(len(model_list)):
            if model_list[i][0] == 'transformer':
                position_embedding=Embedding(embedding_num,trainx.shape[2],input_length=timestep,input_shape=inputshape2)(inputs2)
                add=Add(input_shape=inputshape1)([inputs1,position_embedding])
                for j in range(encoder_deep):
                    if j ==0:
                        exec('en_multihead'+str(j+1)+'=MultiHeadAttention(num_heads=num_heads,key_dim=key_dim,dropout=trans_dropout_rate,attention_axes=1)(add,add,add)')
                        exec('en_add'+str(j+1)+'=Add()([add,en_multihead'+str(j+1)+'])')
                    else:
                        exec('en_multihead'+str(j+1)+'=MultiHeadAttention(num_heads=num_heads,key_dim=key_dim,dropout=trans_dropout_rate,attention_axes=1)(en_layernormalization'+str(j)+',en_layernormalization'+str(j)+',en_layernormalization'+str(j)+')')
                        exec('en_add'+str(j+1)+'=Add()([en_layernormalization'+str(j)+',en_multihead'+str(j+1)+'])')
                    exec('en_layernormalization'+str(j+1)+'=LayerNormalization()(en_add'+str(j+1)+')')
                    if ifdropout=='yes':
                        exec('en_dropout'+str(j+1)+'=Dropout(trans_dropout_rate)(en_layernormalization'+str(j+1)+')')
                        exec('en_fc'+str(j+1)+'=Dense(trans_units,activation=trans_activation)(en_dropout'+str(j+1)+')')
                        exec('en_fc'+str(j+1)+'=Dense(trainx.shape[2],activation=trans_activation)(en_fc'+str(j+1)+')')
                    else:
                        exec('en_fc'+str(j+1)+'=Dense(trans_units,activation=trans_activation)(en_layernormalization'+str(j+1)+')')
                        exec('en_fc'+str(j+1)+'=Dense(trainx.shape[2],activation=trans_activation)(en_fc'+str(j+1)+')')
                    exec('en_add'+str(j+1)+'=Add()([en_fc'+str(j+1)+',en_layernormalization'+str(j+1)+'])')
                    exec('en_layernormalization'+str(j+1)+'=LayerNormalization()(en_add'+str(j+1)+')')
                exec('en_fla=Flatten()(en_layernormalization'+str(j+1)+')')
            elif model_list[i][0] == 'batchnormalization':
                if i==len(model_list)-1:
                    if model_list[i-1][0]=='transformer':
                        outputs=eval('BatchNormalization(axis=-1)(en_fla)')
                    elif model_list[i-1][0]=='batchnormalization' or model_list[i-1][0]=='layernormalization':
                        outputs=eval('BatchNormalization(axis=-1)(norm'+str(i)+')')
                    elif model_list[i-1][0]=='activation':
                        outputs=eval('BatchNormalization(axis=-1)(act'+str(i)+')')
                    elif model_list[i-1][0]=='dropout' :
                        outputs=eval('BatchNormalization(axis=-1)(drop'+str(i)+')')
                    elif model_list[i-1][0]=='fc':
                        outputs=eval('BatchNormalization(axis=-1)(fc'+str(i)+')')
                    elif model_list[i-1][0]=='flatten':
                        outputs=eval('BatchNormalization(axis=-1)(fla'+str(i)+')')
                else:
                    if model_list[i-1][0]=='transformer':
                        exec('norm'+str(i+1)+'=BatchNormalization(axis=-1)(en_fla)')
                    elif model_list[i-1][0]=='batchnormalization' or model_list[i-1][0]=='layernormalization':
                        exec('norm'+str(i+1)+'=BatchNormalization(axis=-1)(norm'+str(i)+')')
                    elif model_list[i-1][0]=='activation':
                        exec('norm'+str(i+1)+'=BatchNormalization(axis=-1)(act'+str(i)+')')
                    elif model_list[i-1][0]=='dropout' :
                        exec('norm'+str(i+1)+'=BatchNormalization(axis=-1)(drop'+str(i)+')')
                    elif model_list[i-1][0]=='fc':
                        exec('norm'+str(i+1)+'=BatchNormalization(axis=-1)(fc'+str(i)+')')
                    elif model_list[i-1][0]=='flatten':
                        exec('norm'+str(i+1)+'=BatchNormalization(axis=-1)(fla'+str(i)+')')
            elif model_list[i][0] == 'layernormalization':
                if i==len(model_list)-1:
                    if model_list[i-1][0]=='transformer':
                        outputs=eval('LayerNormalization(axis=-1)(en_fla)')
                    elif model_list[i-1][0]=='batchnormalization' or model_list[i-1][0]=='layernormalization':
                        outputs=eval('LayerNormalization(axis=-1)(norm'+str(i)+')')
                    elif model_list[i-1][0]=='activation':
                        outputs=eval('LayerNormalization(axis=-1)(act'+str(i)+')')
                    elif model_list[i-1][0]=='dropout' :
                        outputs=eval('LayerNormalization(axis=-1)(drop'+str(i)+')')
                    elif model_list[i-1][0]=='fc':
                        outputs=eval('LayerNormalization(axis=-1)(fc'+str(i)+')')
                    elif model_list[i-1][0]=='flatten':
                        outputs=eval('LayerNormalization(axis=-1)(fla'+str(i)+')')
                else:
                    if model_list[i-1][0]=='transformer':
                        exec('norm'+str(i+1)+'=LayerNormalization(axis=-1)(en_fla)')
                    elif model_list[i-1][0]=='batchnormalization' or model_list[i-1][0]=='layernormalization':
                        exec('norm'+str(i+1)+'=LayerNormalization(axis=-1)(norm'+str(i)+')')
                    elif model_list[i-1][0]=='activation':
                        exec('norm'+str(i+1)+'=LayerNormalization(axis=-1)(act'+str(i)+')')
                    elif model_list[i-1][0]=='dropout' :
                        exec('norm'+str(i+1)+'=LayerNormalization(axis=-1)(drop'+str(i)+')')
                    elif model_list[i-1][0]=='fc':
                        exec('norm'+str(i+1)+'=LayerNormalization(axis=-1)(fc'+str(i)+')')
                    elif model_list[i-1][0]=='flatten':
                        exec('norm'+str(i+1)+'=LayerNormalization(axis=-1)(fla'+str(i)+')')
            elif model_list[i][0] == 'activation':
                if i==len(model_list)-1:
                    if model_list[i-1][0]=='transformer':
                        outputs=eval('Activation(model_list[i][1])(en_fla)')
                    elif model_list[i-1][0]=='batchnormalization' or model_list[i-1][0]=='layernormalization':
                        outputs=eval('Activation(model_list[i][1])(norm'+str(i)+')')
                    elif model_list[i-1][0]=='activation':
                        outputs=eval('Activation(model_list[i][1])(act'+str(i)+')')
                    elif model_list[i-1][0]=='dropout' :
                        outputs=eval('Activation(model_list[i][1])(drop'+str(i)+')')
                    elif model_list[i-1][0]=='fc':
                        outputs=eval('Activation(model_list[i][1])(fc'+str(i)+')')
                    elif model_list[i-1][0]=='flatten':
                        outputs=eval('Activation(model_list[i][1])(fla'+str(i)+')')
                else:
                    if model_list[i-1][0]=='transformer':
                        exec('act'+str(i+1)+'=Activation(model_list[i][1])(en_fla)')
                    elif model_list[i-1][0]=='batchnormalization' or model_list[i-1][0]=='layernormalization':
                        exec('act'+str(i+1)+'=Activation(model_list[i][1])(norm'+str(i)+')')
                    elif model_list[i-1][0]=='activation':
                        exec('act'+str(i+1)+'=Activation(model_list[i][1])(act'+str(i)+')')
                    elif model_list[i-1][0]=='dropout' :
                        exec('act'+str(i+1)+'=Activation(model_list[i][1])(drop'+str(i)+')')
                    elif model_list[i-1][0]=='fc':
                        exec('act'+str(i+1)+'=Activation(model_list[i][1])(fc'+str(i)+')')
                    elif model_list[i-1][0]=='flatten':
                        exec('act'+str(i+1)+'=Activation(model_list[i][1])(fla'+str(i)+')')
            elif model_list[i][0] == 'flatten':
                if model_list[i-1][0]=='transformer':
                    exec('fla'+str(i+1)+'=Flatten()(en_fla)')
                elif model_list[i-1][0]=='batchnormalization' or model_list[i-1][0]=='layernormalization':
                    exec('fla'+str(i+1)+'=Flatten()(norm'+str(i)+')')
                elif model_list[i-1][0]=='activation':
                    exec('fla'+str(i+1)+'=Flatten()(act'+str(i)+')')
                elif model_list[i-1][0]=='dropout':
                    exec('fla'+str(i+1)+'=Flatten()(drop'+str(i)+')')
            elif model_list[i][0] =='fc':
                if if_weight_initialize=='no':
                    if i==len(model_list)-1:
                        if model_list[i-1][0]=='transformer':
                            outputs=eval('Dense(model_list[i][1])(en_fla)')
                        elif model_list[i-1][0]=='batchnormalization' or model_list[i-1][0]=='layernormalization':
                            outputs=eval('Dense(model_list[i][1])(norm'+str(i)+')')
                        elif model_list[i-1][0]=='activation':
                            outputs=eval('Dense(model_list[i][1])(act'+str(i)+')')
                        elif model_list[i-1][0]=='dropout':
                            outputs=eval('Dense(model_list[i][1])(drop'+str(i)+')')
                        elif model_list[i-1][0]=='fc':
                            outputs=eval('Dense(model_list[i][1])(fc'+str(i)+')')
                        elif model_list[i-1][0]=='flatten':
                            outputs=eval('Dense(model_list[i][1])(fla'+str(i)+')')
                    else:
                        if model_list[i-1][0]=='transformer':
                            exec('fc'+str(i+1)+'=Dense(model_list[i][1])(en_fla)')
                        elif model_list[i-1][0]=='batchnormalization' or model_list[i-1][0]=='layernormalization':
                            exec('fc'+str(i+1)+'=Dense(model_list[i][1])(norm'+str(i)+')')
                        elif model_list[i-1][0]=='activation':
                            exec('fc'+str(i+1)+'=Dense(model_list[i][1])(act'+str(i)+')')
                        elif model_list[i-1][0]=='dropout':
                            exec('fc'+str(i+1)+'=Dense(model_list[i][1])(drop'+str(i)+')')
                        elif model_list[i-1][0]=='fc':
                            exec('fc'+str(i+1)+'=Dense(model_list[i][1])(fc'+str(i)+')')
                        elif model_list[i-1][0]=='flatten':
                            exec('fc'+str(i+1)+'=Dense(model_list[i][1])(fla'+str(i)+')')
                else:
                    if i==len(model_list)-1:
                        if model_list[i-1][0]=='transformer':
                            if weight_initialize_method=='RandomNormal':
                                outputs=eval('Dense(model_list[i][1],kernel_initializer = RandomNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2))(en_fla)')
                            elif weight_initialize_method=='RandomUniform':
                                outputs=eval('Dense(model_list[i][1],kernel_initializer = RandomUniform(minval=weight_initialize_parameter1,maxval=weight_initialize_parameter2))(en_fla)')
                            elif weight_initialize_method=='TruncatedNormal':
                                outputs=eval('Dense(model_list[i][1],kernel_initializer = TruncatedNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2))(en_fla)')
                        elif model_list[i-1][0]=='batchnormalization' or model_list[i-1][0]=='layernormalization':
                            if weight_initialize_method=='RandomNormal':
                                outputs=eval('Dense(model_list[i][1],kernel_initializer = RandomNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2))(norm'+str(i)+')')
                            elif weight_initialize_method=='RandomUniform':
                                outputs=eval('Dense(model_list[i][1],kernel_initializer = RandomUniform(minval=weight_initialize_parameter1,maxval=weight_initialize_parameter2))(norm'+str(i)+')')
                            elif weight_initialize_method=='TruncatedNormal':
                                outputs=eval('Dense(model_list[i][1],kernel_initializer = TruncatedNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2))(norm'+str(i)+')')
                        elif model_list[i-1][0]=='activation':
                            if weight_initialize_method=='RandomNormal':
                                outputs=eval('Dense(model_list[i][1],kernel_initializer = RandomNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2))(act'+str(i)+')')
                            elif weight_initialize_method=='RandomUniform':
                                outputs=eval('Dense(model_list[i][1],kernel_initializer = RandomUniform(minval=weight_initialize_parameter1,maxval=weight_initialize_parameter2))(act'+str(i)+')')
                            elif weight_initialize_method=='TruncatedNormal':
                                outputs=eval('Dense(model_list[i][1],kernel_initializer = TruncatedNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2))(act'+str(i)+')')
                        elif model_list[i-1][0]=='dropout':
                            if weight_initialize_method=='RandomNormal':
                                outputs=eval('Dense(model_list[i][1],kernel_initializer = RandomNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2))(drop'+str(i)+')')
                            elif weight_initialize_method=='RandomUniform':
                                outputs=eval('Dense(model_list[i][1],kernel_initializer = RandomUniform(minval=weight_initialize_parameter1,maxval=weight_initialize_parameter2))(drop'+str(i)+')')
                            elif weight_initialize_method=='TruncatedNormal':
                                outputs=eval('Dense(model_list[i][1],kernel_initializer = TruncatedNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2))(drop'+str(i)+')')
                        elif model_list[i-1][0]=='fc':   
                            if weight_initialize_method=='RandomNormal':
                                outputs=eval('Dense(model_list[i][1],kernel_initializer = RandomNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2))(fc'+str(i)+')')
                            elif weight_initialize_method=='RandomUniform':
                                outputs=eval('Dense(model_list[i][1],kernel_initializer = RandomUniform(minval=weight_initialize_parameter1,maxval=weight_initialize_parameter2))(fc'+str(i)+')')
                            elif weight_initialize_method=='TruncatedNormal':
                                outputs=eval('Dense(model_list[i][1],kernel_initializer = TruncatedNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2))(fc'+str(i)+')')
                        elif model_list[i-1][0]=='flatten':
                            if weight_initialize_method=='RandomNormal':
                                outputs=eval('Dense(model_list[i][1],kernel_initializer = RandomNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2))(fla'+str(i)+')')
                            elif weight_initialize_method=='RandomUniform':
                                outputs=eval('Dense(model_list[i][1],kernel_initializer = RandomUniform(minval=weight_initialize_parameter1,maxval=weight_initialize_parameter2))(fla'+str(i)+')')
                            elif weight_initialize_method=='TruncatedNormal':
                                outputs=eval('Dense(model_list[i][1],kernel_initializer = TruncatedNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2))(fla'+str(i)+')')
                    else:
                        if model_list[i-1][0]=='transformer':
                            if weight_initialize_method=='RandomNormal':
                                exec('fc'+str(i+1)+'=Dense(model_list[i][1],kernel_initializer = RandomNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2))(en_fla)')
                            elif weight_initialize_method=='RandomUniform':
                                exec('fc'+str(i+1)+'=Dense(model_list[i][1],kernel_initializer = RandomUniform(minval=weight_initialize_parameter1,maxval=weight_initialize_parameter2))(en_fla)')
                            elif weight_initialize_method=='TruncatedNormal':
                                exec('fc'+str(i+1)+'=Dense(model_list[i][1],kernel_initializer = TruncatedNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2))(en_fla)')
                        elif model_list[i-1][0]=='batchnormalization' or model_list[i-1][0]=='layernormalization':
                            if weight_initialize_method=='RandomNormal':
                                exec('fc'+str(i+1)+'=Dense(model_list[i][1],kernel_initializer = RandomNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2))(norm'+str(i)+')')
                            elif weight_initialize_method=='RandomUniform':
                                exec('fc'+str(i+1)+'=Dense(model_list[i][1],kernel_initializer = RandomUniform(minval=weight_initialize_parameter1,maxval=weight_initialize_parameter2))(norm'+str(i)+')')
                            elif weight_initialize_method=='TruncatedNormal':
                                exec('fc'+str(i+1)+'=Dense(model_list[i][1],kernel_initializer = TruncatedNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2))(norm'+str(i)+')')
                        elif model_list[i-1][0]=='activation':
                            if weight_initialize_method=='RandomNormal':
                                exec('fc'+str(i+1)+'=Dense(model_list[i][1],kernel_initializer = RandomNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2))(act'+str(i)+')')
                            elif weight_initialize_method=='RandomUniform':
                                exec('fc'+str(i+1)+'=Dense(model_list[i][1],kernel_initializer = RandomUniform(minval=weight_initialize_parameter1,maxval=weight_initialize_parameter2))(act'+str(i)+')')
                            elif weight_initialize_method=='TruncatedNormal':
                                exec('fc'+str(i+1)+'=Dense(model_list[i][1],kernel_initializer = TruncatedNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2))(act'+str(i)+')')
                        elif model_list[i-1][0]=='dropout':
                            if weight_initialize_method=='RandomNormal':
                                exec('fc'+str(i+1)+'=Dense(model_list[i][1],kernel_initializer = RandomNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2))(drop'+str(i)+')')
                            elif weight_initialize_method=='RandomUniform':
                                exec('fc'+str(i+1)+'=Dense(model_list[i][1],kernel_initializer = RandomUniform(minval=weight_initialize_parameter1,maxval=weight_initialize_parameter2))(drop'+str(i)+')')
                            elif weight_initialize_method=='TruncatedNormal':
                                exec('fc'+str(i+1)+'=Dense(model_list[i][1],kernel_initializer = TruncatedNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2))(drop'+str(i)+')')
                        elif model_list[i-1][0]=='fc':   
                            if weight_initialize_method=='RandomNormal':
                                exec('fc'+str(i+1)+'=Dense(model_list[i][1],kernel_initializer = RandomNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2))(fc'+str(i)+')')
                            elif weight_initialize_method=='RandomUniform':
                                exec('fc'+str(i+1)+'=Dense(model_list[i][1],kernel_initializer = RandomUniform(minval=weight_initialize_parameter1,maxval=weight_initialize_parameter2))(fc'+str(i)+')')
                            elif weight_initialize_method=='TruncatedNormal':
                                exec('fc'+str(i+1)+'=Dense(model_list[i][1],kernel_initializer = TruncatedNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2))(fc'+str(i)+')')
                        elif model_list[i-1][0]=='flatten':
                            if weight_initialize_method=='RandomNormal':
                                exec('fc'+str(i+1)+'=Dense(model_list[i][1],kernel_initializer = RandomNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2))(fla'+str(i)+')')
                            elif weight_initialize_method=='RandomUniform':
                                exec('fc'+str(i+1)+'=Dense(model_list[i][1],kernel_initializer = RandomUniform(minval=weight_initialize_parameter1,maxval=weight_initialize_parameter2))(fla'+str(i)+')')
                            elif weight_initialize_method=='TruncatedNormal':
                                exec('fc'+str(i+1)+'=Dense(model_list[i][1],kernel_initializer = TruncatedNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2))(fla'+str(i)+')')
            elif model_list[i][0] == 'dropout':
                if i==len(model_list)-1:
                    if model_list[i-1][0]=='transformer':
                        outputs=eval('Dropout(model_list[i][1])(en_fla)')
                    elif model_list[i-1][0]=='batchnormalization' or model_list[i-1][0]=='layernormalization':
                        outputs=eval('Dropout(model_list[i][1])(norm'+str(i)+')')
                    elif model_list[i-1][0]=='activation':
                        outputs=eval('Dropout(model_list[i][1])(act'+str(i)+')')
                    elif model_list[i-1][0]=='dropout' :
                        outputs=eval('Dropout(model_list[i][1])(drop'+str(i)+')')
                    elif model_list[i-1][0]=='fc':
                        outputs=eval('Dropout(model_list[i][1])(fc'+str(i)+')')
                    elif model_list[i-1][0]=='flatten':
                        outputs=eval('Dropout(model_list[i][1])(fla'+str(i)+')')
                else:
                    if model_list[i-1][0]=='transformer':
                        exec('drop'+str(i+1)+'=Dropout(model_list[i][1])(en_fla)')
                    elif model_list[i-1][0]=='batchnormalization' or model_list[i-1][0]=='layernormalization':
                        exec('drop'+str(i+1)+'=Dropout(model_list[i][1])(norm'+str(i)+')')
                    elif model_list[i-1][0]=='activation':
                        exec('drop'+str(i+1)+'=Dropout(model_list[i][1])(act'+str(i)+')')
                    elif model_list[i-1][0]=='dropout' :
                        exec('drop'+str(i+1)+'=Dropout(model_list[i][1])(drop'+str(i)+')')
                    elif model_list[i-1][0]=='fc':
                        exec('drop'+str(i+1)+'=Dropout(model_list[i][1])(fc'+str(i)+')')
                    elif model_list[i-1][0]=='flatten':
                        exec('drop'+str(i+1)+'=Dropout(model_list[i][1])(fla'+str(i)+')')
        model=eval('Model(inputs=[inputs1,inputs2], outputs=outputs)')
        if optimizer == 'SGD':
            opt = SGD(lr = learning_rate)
        elif optimizer == 'Adam':
            opt = Adam(lr = learning_rate)
        model.compile(loss=loss,optimizer=opt,metrics=[metric])
    elif if_best_mode=='yes' or if_best_mode=='load':
        if k_fold!=None:
            models=[]
            for i in range(k_fold):
                models.append(load_model(modelpath+'_'+str(i+1)))
        else:
            model=load_model(modelpath)
    if if_print_model=='yes':
        if k_fold!=None:
            if if_best_mode=='yes' or if_best_mode=='load':
                print(models[0].summary())
            else:
                print(model.summary())
        else:
            print(model.summary())
    if epochs!=0:
        if valid_size!=None or k_fold !=None:
            if k_fold!=None:
                if if_best_mode=='no' :
                    models = []
                    if ifrandom_split=='yes':
                        kf = KFold(n_splits=k_fold, shuffle=True, random_state=25)
                    else:
                        kf = KFold(n_splits=k_fold, shuffle=False)
                    for fold_no, (train_idx, val_idx) in enumerate(kf.split(trainx, trainy)):
                        X_train_fold, y_train_fold, position_train_fold = trainx[train_idx], trainy[train_idx], train_position[train_idx]
                        X_val_fold, y_val_fold, position_val_fold = trainx[val_idx], trainy[val_idx], train_position[val_idx]
                        model=eval('Model(inputs=[inputs1,inputs2], outputs=outputs)')
                        model.compile(loss=loss,optimizer=opt,metrics=[metric])
                        if if_early_stopping!=None:
                            H = model.fit(train_data_generator(X_train_fold,position_train_fold,y_train_fold,batch_size),steps_per_epoch=(len(X_train_fold) // batch_size+(1 if len(X_train_fold) % batch_size != 0 else 0)),validation_data=train_data_generator(X_val_fold,position_val_fold,y_val_fold,batch_size),validation_steps=(len(X_val_fold) // batch_size+(1 if len(X_val_fold) % batch_size != 0 else 0)),epochs = epochs,callbacks=[tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience=if_early_stopping,restore_best_weights=True)])
                        else:
                            H = model.fit(train_data_generator(X_train_fold,position_train_fold,y_train_fold,batch_size),steps_per_epoch=(len(X_train_fold) // batch_size+(1 if len(X_train_fold) % batch_size != 0 else 0)),validation_data=train_data_generator(X_val_fold,position_val_fold,y_val_fold,batch_size),validation_steps=(len(X_val_fold) // batch_size+(1 if len(X_val_fold) % batch_size != 0 else 0)),epochs = epochs)
                        models.append(model)
                else:
                    models_new = []
                    if ifrandom_split=='yes':
                        kf = KFold(n_splits=k_fold, shuffle=True, random_state=25)
                    else:
                        kf = KFold(n_splits=k_fold, shuffle=False)
                    for fold_no, (train_idx, val_idx) in enumerate(kf.split(trainx, trainy)):
                        X_train_fold, y_train_fold, position_train_fold = trainx[train_idx], trainy[train_idx], train_position[train_idx]
                        X_val_fold, y_val_fold, position_val_fold = trainx[val_idx], trainy[val_idx], train_position[val_idx]
                        if if_early_stopping!=None:
                            H = models[fold_no].fit(train_data_generator(X_train_fold,position_train_fold,y_train_fold,batch_size),steps_per_epoch=(len(X_train_fold) // batch_size+(1 if len(X_train_fold) % batch_size != 0 else 0)),validation_data=train_data_generator(X_val_fold,position_val_fold,y_val_fold,batch_size),validation_steps=(len(X_val_fold) // batch_size+(1 if len(X_val_fold) % batch_size != 0 else 0)),epochs = epochs,callbacks=[tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience=if_early_stopping,restore_best_weights=True)])
                        else:
                            H = models[fold_no].fit(train_data_generator(X_train_fold,position_train_fold,y_train_fold,batch_size),steps_per_epoch=(len(X_train_fold) // batch_size+(1 if len(X_train_fold) % batch_size != 0 else 0)),validation_data=train_data_generator(X_val_fold,position_val_fold,y_val_fold,batch_size),validation_steps=(len(X_val_fold) // batch_size+(1 if len(X_val_fold) % batch_size != 0 else 0)),epochs = epochs)
                        models_new.append(models[fold_no])
                    models=models_new
            else:
                if ifrandom_split=='yes':
                    trainy,validy,trainx,validx,train_position,valid_position = train_test_split(trainy,trainx,train_position,test_size=valid_size/(1-test_size),random_state=25)
                else:
                    index=int((1-valid_size/(1-test_size))*trainy.shape[0])
                    validy=trainy[index:]
                    trainy=trainy[:index]
                    validx=trainx[index:]
                    trainx=trainx[:index]
                    valid_position=train_position[index:]
                    train_position=train_position[:index]
                if if_early_stopping!=None:
                    H = model.fit(train_data_generator(trainx,train_position,trainy,batch_size),steps_per_epoch=(len(trainx) // batch_size+(1 if len(trainx) % batch_size != 0 else 0)),validation_data=train_data_generator(validx,valid_position,validy,batch_size),validation_steps=(len(validx) // batch_size+(1 if len(validx) % batch_size != 0 else 0)),epochs = epochs,callbacks=[tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience=if_early_stopping,restore_best_weights=True)])
                else:
                    H = model.fit(train_data_generator(trainx,train_position,trainy,batch_size),steps_per_epoch=(len(trainx) // batch_size+(1 if len(trainx) % batch_size != 0 else 0)),validation_data=train_data_generator(validx,valid_position,validy,batch_size),validation_steps=(len(validx) // batch_size+(1 if len(validx) % batch_size != 0 else 0)),epochs = epochs)
        else:
            if if_early_stopping!=None:
                H = model.fit(train_data_generator(trainx,train_position,trainy,batch_size),steps_per_epoch=(len(trainx) // batch_size+(1 if len(trainx) % batch_size != 0 else 0)),validation_data=train_data_generator(testx,test_position,testy,batch_size),validation_steps=(len(testx) // batch_size+(1 if len(testx) % batch_size != 0 else 0)),epochs = epochs,callbacks=[tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience=if_early_stopping,restore_best_weights=True)])
            else:
                H = model.fit(train_data_generator(trainx,train_position,trainy,batch_size),steps_per_epoch=(len(trainx) // batch_size+(1 if len(trainx) % batch_size != 0 else 0)),validation_data=train_data_generator(testx,test_position,testy,batch_size),validation_steps=(len(testx) // batch_size+(1 if len(testx) % batch_size != 0 else 0)),epochs = epochs)
    if k_fold!=None:
        predicty = [model.predict(test_data_generator(testx,test_position,batch_size),steps=(len(testx) // batch_size+(1 if len(testx) % batch_size != 0 else 0))) for model in models]
        predicty=np.nanmean(predicty,axis=0)
    else:
        predicty = model.predict(test_data_generator(testx,test_position,batch_size),steps=(len(testx) // batch_size+(1 if len(testx) % batch_size != 0 else 0)))
    predicty = np.nan_to_num(predicty,nan=0)
    if task_mode=='regression':
        r=np.zeros((testy.shape[1]))
        p=np.zeros((testy.shape[1]))
        for i in range(testy.shape[1]):
            r[i],p[i] = pearsonr(predicty[:,i],testy[:,i])
            r=np.nan_to_num(r,nan=0)
    elif task_mode=='binary_classify':
        accuracy=np.zeros((testy.shape[1]))
        recall=np.zeros((testy.shape[1]))
        precision=np.zeros((testy.shape[1]))
        f1=np.zeros((testy.shape[1]))
        for i in range(predicty.shape[1]):
            predicty[:,i]=[int(round(predicty[j,i],0)) for j in range(predicty.shape[0])]
        r=np.zeros((testy.shape[1]))
        for i in range(testy.shape[1]):
            if metrics=='Recall':
                r[i]=recall_score(testy[:,i], predicty[:,i])
            elif metrics=='Precision':
                r[i]=precision_score(testy[:,i], predicty[:,i])
            else:
                r[i]=accuracy_score(testy[:,i], predicty[:,i])
            recall[i]=recall_score(testy[:,i], predicty[:,i])
            precision[i]=precision_score(testy[:,i], predicty[:,i])
            accuracy[i]=accuracy_score(testy[:,i], predicty[:,i])
            f1[i]=f1_score(testy[:,i], predicty[:,i])
        p=0
    elif task_mode=='multi_classify':
        r=np.zeros((testy.shape[1]))
        for i in range(testy.shape[1]):
            r[i]=accuracy_score(testy[:,i], np.argmax(predicty,axis=1))
        p=0
    if ifmute == 'no':
        if task_mode=='regression':
            print('相关系数',np.nanmean(r))
        elif task_mode=='binary_classify':
            print('召回率+精确率',np.nanmean(f1),'准确率',np.nanmean(accuracy),'召回率',np.nanmean(recall),'精确率',np.nanmean(precision))
        elif task_mode=='multi_classify':
            print('准确率',np.nanmean(r))
    if ifweight=='yes':
        weights=np.zeros((testy.shape[1],testx.shape[2]))
        weight_more=np.zeros((testy.shape[1],testx.shape[2]))
        for i in range(testy.shape[1]):
            for j in range(testx.shape[2]):
                testx_new=copy.deepcopy(testx)
                weight=[]
                for k in range(10):
                    per=np.random.permutation(testx.shape[0])
                    testx_shuffle=testx[per,:,j]
                    testx_new[:,:,j]=testx_shuffle
                    if k_fold!=None:
                        predicty_new = [model.predict(test_data_generator(testx_new,test_position,batch_size),steps=(len(testx_new) // batch_size+(1 if len(testx_new) % batch_size != 0 else 0))) for model in models]
                        predicty_new=np.nanmean(predicty_new,axis=0)
                    else:
                        predicty_new = model.predict(test_data_generator(testx_new,test_position,batch_size),steps=(len(testx_new) // batch_size+(1 if len(testx_new) % batch_size != 0 else 0)))
                    if task_mode=='regression':
                        weight.append(sklearn.metrics.mean_squared_error(testy[:,i],predicty_new[:,i])-sklearn.metrics.mean_squared_error(testy[:,i],predicty[:,i]))
                    elif task_mode=='multi_classify':
                        weight.append(sklearn.metrics.log_loss(testy[:,i],predicty_new[:,:])-sklearn.metrics.log_loss(testy[:,i],predicty[:,:]))
                    else:
                        weight.append(sklearn.metrics.log_loss(testy[:,i],predicty_new[:,i])-sklearn.metrics.log_loss(testy[:,i],predicty[:,i]))
                weight_more[i,j]=np.nanmean(weight)
        for i in range(testy.shape[1]):
            for j in range(testx.shape[2]):
                weights[i,j]=(weight_more[i,j]/np.nansum(weight_more[i,:]))*100
                print('预报因子',j+1,'对预报值',i+1,'的贡献：',np.array(weights[i,j]),'％')
            print('\n')
    if ifsave=='yes':
        if k_fold!=None:
            for i, model in enumerate(models):
                model.save(savepath+'_'+str(i+1))
        else:
            model.save(savepath)
    if k_fold!=None:
        return models,predicty,testy,r,p,weights
    else:
        return model,predicty,testy,r,p,weights

# %%
model,predicty,testy,r,p,weights=Auto_Transformer(vy,vx,6,[['transformer'],['fc',126]],test_size=0.2,valid_size=0.1,k_fold=5,task_mode='regression',if_best_mode='no',modelpath=None,encoder_deep=1,num_heads=1,key_dim=1,ifdropout='no',trans_dropout_rate=0.0,trans_units=566,trans_activation='tanh',embedding_num=None,if_weight_initialize='no',weight_initialize_method='TruncatedNormal',weight_initialize_parameter1=0.00,weight_initialize_parameter2=0.05,if_print_model='yes',loss_function='default',optimizer='Adam',metrics='Pearsonr',if_early_stopping=None,learning_rate=0.0001,epochs=500,batch_size=5000,ifrandom_split='yes',ifweight='no',ifmute='no',ifsave='yes',savepath='E:/huawei/huawei_gnss_wind_u_5min_hight_k5',device='gpu')
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 6)]          0           []
#
#  input_1 (InputLayer)           [(None, 6, 566)]     0           []
#
#  embedding (Embedding)          (None, 6, 566)       3962        ['input_2[0][0]']
#
#  add (Add)                      (None, 6, 566)       0           ['input_1[0][0]',
#                                                                   'embedding[0][0]']
#
#  multi_head_attention (MultiHea  (None, 6, 566)      2833        ['add[0][0]',
#  dAttention)                                                      'add[0][0]',
#                                                                   'add[0][0]']
#
#  add_1 (Add)                    (None, 6, 566)       0           ['add[0][0]',
#                                                                   'multi_head_attention[0][0]']
#
#  layer_normalization (LayerNorm  (None, 6, 566)      1132        ['add_1[0][0]']
#  alization)
#
#  dense (Dense)                  (None, 6, 566)       320922      ['layer_normalization[0][0]']
#
#  dense_1 (Dense)                (None, 6, 566)       320922      ['dense[0][0]']
#
#  add_2 (Add)                    (None, 6, 566)       0           ['dense_1[0][0]',
#                                                                   'layer_normalization[0][0]']
#
#  layer_normalization_1 (LayerNo  (None, 6, 566)      1132        ['add_2[0][0]']
#  rmalization)
#
#  flatten (Flatten)              (None, 3396)         0           ['layer_normalization_1[0][0]']
#
#  dense_2 (Dense)                (None, 126)          428022      ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 1,078,925
# Trainable params: 1,078,925
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Epoch 1/500
# 3/3 [==============================] - 3s 243ms/step - loss: 109.4619 - metrics_pearsonr: 0.9968 - val_loss: 103.1357 - val_metrics_pearsonr: 0.9606
# Epoch 2/500
# 3/3 [==============================] - 0s 73ms/step - loss: 102.7922 - metrics_pearsonr: 0.9404 - val_loss: 97.0727 - val_metrics_pearsonr: 0.9104
# Epoch 3/500
# 3/3 [==============================] - 0s 72ms/step - loss: 96.6953 - metrics_pearsonr: 0.8847 - val_loss: 91.5098 - val_metrics_pearsonr: 0.8623
# Epoch 4/500
# 3/3 [==============================] - 0s 74ms/step - loss: 91.1008 - metrics_pearsonr: 0.8320 - val_loss: 86.4097 - val_metrics_pearsonr: 0.8164
# Epoch 5/500
# 3/3 [==============================] - 0s 71ms/step - loss: 85.9744 - metrics_pearsonr: 0.7827 - val_loss: 81.8474 - val_metrics_pearsonr: 0.7739
# Epoch 6/500
# 3/3 [==============================] - 0s 74ms/step - loss: 81.4023 - metrics_pearsonr: 0.7385 - val_loss: 77.8444 - val_metrics_pearsonr: 0.7367
# Epoch 7/500
# 3/3 [==============================] - 0s 73ms/step - loss: 77.4042 - metrics_pearsonr: 0.7008 - val_loss: 74.4461 - val_metrics_pearsonr: 0.7047
# Epoch 8/500
# 3/3 [==============================] - 0s 71ms/step - loss: 74.0249 - metrics_pearsonr: 0.6690 - val_loss: 71.6448 - val_metrics_pearsonr: 0.6767
# Epoch 9/500
# 3/3 [==============================] - 0s 68ms/step - loss: 71.2426 - metrics_pearsonr: 0.6418 - val_loss: 69.3803 - val_metrics_pearsonr: 0.6520
# Epoch 10/500
# 3/3 [==============================] - 0s 70ms/step - loss: 68.9950 - metrics_pearsonr: 0.6185 - val_loss: 67.5735 - val_metrics_pearsonr: 0.6303
# Epoch 11/500
# 3/3 [==============================] - 0s 74ms/step - loss: 67.1961 - metrics_pearsonr: 0.5985 - val_loss: 66.1284 - val_metrics_pearsonr: 0.6111
# Epoch 12/500
# 3/3 [==============================] - 0s 94ms/step - loss: 65.7485 - metrics_pearsonr: 0.5810 - val_loss: 64.9520 - val_metrics_pearsonr: 0.5937
# Epoch 13/500
# 3/3 [==============================] - 0s 73ms/step - loss: 64.5617 - metrics_pearsonr: 0.5650 - val_loss: 63.9641 - val_metrics_pearsonr: 0.5774
# Epoch 14/500
# 3/3 [==============================] - 0s 74ms/step - loss: 63.5601 - metrics_pearsonr: 0.5499 - val_loss: 63.1027 - val_metrics_pearsonr: 0.5619
# Epoch 15/500
# 3/3 [==============================] - 0s 77ms/step - loss: 62.6860 - metrics_pearsonr: 0.5355 - val_loss: 62.3249 - val_metrics_pearsonr: 0.5469
# Epoch 16/500
# 3/3 [==============================] - 0s 75ms/step - loss: 61.8990 - metrics_pearsonr: 0.5214 - val_loss: 61.6023 - val_metrics_pearsonr: 0.5322
# Epoch 17/500
# 3/3 [==============================] - 0s 77ms/step - loss: 61.1704 - metrics_pearsonr: 0.5075 - val_loss: 60.9146 - val_metrics_pearsonr: 0.5179
# Epoch 18/500
# 3/3 [==============================] - 0s 75ms/step - loss: 60.4776 - metrics_pearsonr: 0.4939 - val_loss: 60.2449 - val_metrics_pearsonr: 0.5038
# Epoch 19/500
# 3/3 [==============================] - 0s 72ms/step - loss: 59.8003 - metrics_pearsonr: 0.4805 - val_loss: 59.5783 - val_metrics_pearsonr: 0.4900
# Epoch 20/500
# 3/3 [==============================] - 0s 72ms/step - loss: 59.1218 - metrics_pearsonr: 0.4674 - val_loss: 58.9035 - val_metrics_pearsonr: 0.4764
# Epoch 21/500
# 3/3 [==============================] - 0s 83ms/step - loss: 58.4312 - metrics_pearsonr: 0.4545 - val_loss: 58.2120 - val_metrics_pearsonr: 0.4629
# Epoch 22/500
# 3/3 [==============================] - 0s 85ms/step - loss: 57.7207 - metrics_pearsonr: 0.4416 - val_loss: 57.4954 - val_metrics_pearsonr: 0.4493
# Epoch 23/500
# 3/3 [==============================] - 0s 75ms/step - loss: 56.9837 - metrics_pearsonr: 0.4286 - val_loss: 56.7469 - val_metrics_pearsonr: 0.4358
# Epoch 24/500
# 3/3 [==============================] - 0s 78ms/step - loss: 56.2147 - metrics_pearsonr: 0.4156 - val_loss: 55.9621 - val_metrics_pearsonr: 0.4222
# Epoch 25/500
# 3/3 [==============================] - 0s 70ms/step - loss: 55.4097 - metrics_pearsonr: 0.4027 - val_loss: 55.1381 - val_metrics_pearsonr: 0.4087
# Epoch 26/500
# 3/3 [==============================] - 0s 71ms/step - loss: 54.5659 - metrics_pearsonr: 0.3898 - val_loss: 54.2731 - val_metrics_pearsonr: 0.3953
# Epoch 27/500
# 3/3 [==============================] - 0s 72ms/step - loss: 53.6819 - metrics_pearsonr: 0.3769 - val_loss: 53.3666 - val_metrics_pearsonr: 0.3819
# Epoch 28/500
# 3/3 [==============================] - 0s 73ms/step - loss: 52.7571 - metrics_pearsonr: 0.3642 - val_loss: 52.4200 - val_metrics_pearsonr: 0.3687
# Epoch 29/500
# 3/3 [==============================] - 0s 70ms/step - loss: 51.7929 - metrics_pearsonr: 0.3515 - val_loss: 51.4351 - val_metrics_pearsonr: 0.3557
# Epoch 30/500
# 3/3 [==============================] - 0s 71ms/step - loss: 50.7916 - metrics_pearsonr: 0.3391 - val_loss: 50.4143 - val_metrics_pearsonr: 0.3428
# Epoch 31/500
# 3/3 [==============================] - 0s 74ms/step - loss: 49.7561 - metrics_pearsonr: 0.3267 - val_loss: 49.3627 - val_metrics_pearsonr: 0.3300
# Epoch 32/500
# 3/3 [==============================] - 0s 73ms/step - loss: 48.6905 - metrics_pearsonr: 0.3145 - val_loss: 48.2863 - val_metrics_pearsonr: 0.3176
# Epoch 33/500
# 3/3 [==============================] - 0s 70ms/step - loss: 47.5999 - metrics_pearsonr: 0.3025 - val_loss: 47.1895 - val_metrics_pearsonr: 0.3053
# Epoch 34/500
# 3/3 [==============================] - 0s 94ms/step - loss: 46.4895 - metrics_pearsonr: 0.2908 - val_loss: 46.0791 - val_metrics_pearsonr: 0.2934
# Epoch 35/500
# 3/3 [==============================] - 0s 67ms/step - loss: 45.3655 - metrics_pearsonr: 0.2793 - val_loss: 44.9629 - val_metrics_pearsonr: 0.2819
# Epoch 36/500
# 3/3 [==============================] - 0s 70ms/step - loss: 44.2347 - metrics_pearsonr: 0.2683 - val_loss: 43.8471 - val_metrics_pearsonr: 0.2708
# Epoch 37/500
# 3/3 [==============================] - 0s 76ms/step - loss: 43.1041 - metrics_pearsonr: 0.2576 - val_loss: 42.7400 - val_metrics_pearsonr: 0.2602
# Epoch 38/500
# 3/3 [==============================] - 0s 80ms/step - loss: 41.9813 - metrics_pearsonr: 0.2473 - val_loss: 41.6490 - val_metrics_pearsonr: 0.2501
# Epoch 39/500
# 3/3 [==============================] - 0s 78ms/step - loss: 40.8738 - metrics_pearsonr: 0.2376 - val_loss: 40.5808 - val_metrics_pearsonr: 0.2406
# Epoch 40/500
# 3/3 [==============================] - 0s 84ms/step - loss: 39.7889 - metrics_pearsonr: 0.2284 - val_loss: 39.5427 - val_metrics_pearsonr: 0.2317
# Epoch 41/500
# 3/3 [==============================] - 0s 77ms/step - loss: 38.7335 - metrics_pearsonr: 0.2198 - val_loss: 38.5394 - val_metrics_pearsonr: 0.2234
# Epoch 42/500
# 3/3 [==============================] - 0s 80ms/step - loss: 37.7134 - metrics_pearsonr: 0.2118 - val_loss: 37.5752 - val_metrics_pearsonr: 0.2156
# Epoch 43/500
# 3/3 [==============================] - 0s 99ms/step - loss: 36.7334 - metrics_pearsonr: 0.2043 - val_loss: 36.6521 - val_metrics_pearsonr: 0.2084
# Epoch 44/500
# 3/3 [==============================] - 0s 70ms/step - loss: 35.7960 - metrics_pearsonr: 0.1973 - val_loss: 35.7706 - val_metrics_pearsonr: 0.2018
# Epoch 45/500
# 3/3 [==============================] - 0s 77ms/step - loss: 34.9030 - metrics_pearsonr: 0.1908 - val_loss: 34.9302 - val_metrics_pearsonr: 0.1955
# Epoch 46/500
# 3/3 [==============================] - 0s 81ms/step - loss: 34.0544 - metrics_pearsonr: 0.1848 - val_loss: 34.1304 - val_metrics_pearsonr: 0.1897
# Epoch 47/500
# 3/3 [==============================] - 0s 82ms/step - loss: 33.2503 - metrics_pearsonr: 0.1791 - val_loss: 33.3710 - val_metrics_pearsonr: 0.1842
# Epoch 48/500
# 3/3 [==============================] - 0s 73ms/step - loss: 32.4906 - metrics_pearsonr: 0.1738 - val_loss: 32.6526 - val_metrics_pearsonr: 0.1790
# Epoch 49/500
# 3/3 [==============================] - 0s 79ms/step - loss: 31.7753 - metrics_pearsonr: 0.1689 - val_loss: 31.9756 - val_metrics_pearsonr: 0.1742
# Epoch 50/500
# 3/3 [==============================] - 0s 72ms/step - loss: 31.1039 - metrics_pearsonr: 0.1643 - val_loss: 31.3395 - val_metrics_pearsonr: 0.1697
# Epoch 51/500
# 3/3 [==============================] - 0s 73ms/step - loss: 30.4749 - metrics_pearsonr: 0.1599 - val_loss: 30.7425 - val_metrics_pearsonr: 0.1654
# Epoch 52/500
# 3/3 [==============================] - 0s 81ms/step - loss: 29.8858 - metrics_pearsonr: 0.1559 - val_loss: 30.1815 - val_metrics_pearsonr: 0.1614
# Epoch 53/500
# 3/3 [==============================] - 0s 91ms/step - loss: 29.3330 - metrics_pearsonr: 0.1521 - val_loss: 29.6529 - val_metrics_pearsonr: 0.1576
# Epoch 54/500
# 3/3 [==============================] - 0s 81ms/step - loss: 28.8125 - metrics_pearsonr: 0.1485 - val_loss: 29.1528 - val_metrics_pearsonr: 0.1540
# Epoch 55/500
# 3/3 [==============================] - 0s 75ms/step - loss: 28.3206 - metrics_pearsonr: 0.1450 - val_loss: 28.6776 - val_metrics_pearsonr: 0.1505
# Epoch 56/500
# 3/3 [==============================] - 0s 73ms/step - loss: 27.8535 - metrics_pearsonr: 0.1417 - val_loss: 28.2240 - val_metrics_pearsonr: 0.1472
# Epoch 57/500
# 3/3 [==============================] - 0s 72ms/step - loss: 27.4083 - metrics_pearsonr: 0.1386 - val_loss: 27.7893 - val_metrics_pearsonr: 0.1440
# Epoch 58/500
# 3/3 [==============================] - 0s 73ms/step - loss: 26.9825 - metrics_pearsonr: 0.1356 - val_loss: 27.3715 - val_metrics_pearsonr: 0.1409
# Epoch 59/500
# 3/3 [==============================] - 0s 71ms/step - loss: 26.5740 - metrics_pearsonr: 0.1326 - val_loss: 26.9691 - val_metrics_pearsonr: 0.1379
# Epoch 60/500
# 3/3 [==============================] - 0s 74ms/step - loss: 26.1814 - metrics_pearsonr: 0.1298 - val_loss: 26.5808 - val_metrics_pearsonr: 0.1349
# Epoch 61/500
# 3/3 [==============================] - 0s 75ms/step - loss: 25.8032 - metrics_pearsonr: 0.1271 - val_loss: 26.2058 - val_metrics_pearsonr: 0.1321
# Epoch 62/500
# 3/3 [==============================] - 0s 86ms/step - loss: 25.4385 - metrics_pearsonr: 0.1244 - val_loss: 25.8431 - val_metrics_pearsonr: 0.1294
# Epoch 63/500
# 3/3 [==============================] - 0s 84ms/step - loss: 25.0862 - metrics_pearsonr: 0.1219 - val_loss: 25.4921 - val_metrics_pearsonr: 0.1267
# Epoch 64/500
# 3/3 [==============================] - 0s 79ms/step - loss: 24.7455 - metrics_pearsonr: 0.1194 - val_loss: 25.1518 - val_metrics_pearsonr: 0.1242
# Epoch 65/500
# 3/3 [==============================] - 0s 72ms/step - loss: 24.4155 - metrics_pearsonr: 0.1170 - val_loss: 24.8214 - val_metrics_pearsonr: 0.1217
# Epoch 66/500
# 3/3 [==============================] - 0s 78ms/step - loss: 24.0957 - metrics_pearsonr: 0.1147 - val_loss: 24.5004 - val_metrics_pearsonr: 0.1193
# Epoch 67/500
# 3/3 [==============================] - 0s 73ms/step - loss: 23.7853 - metrics_pearsonr: 0.1125 - val_loss: 24.1881 - val_metrics_pearsonr: 0.1170
# Epoch 68/500
# 3/3 [==============================] - 0s 68ms/step - loss: 23.4840 - metrics_pearsonr: 0.1103 - val_loss: 23.8842 - val_metrics_pearsonr: 0.1148
# Epoch 69/500
# 3/3 [==============================] - 0s 72ms/step - loss: 23.1912 - metrics_pearsonr: 0.1083 - val_loss: 23.5885 - val_metrics_pearsonr: 0.1126
# Epoch 70/500
# 3/3 [==============================] - 0s 69ms/step - loss: 22.9065 - metrics_pearsonr: 0.1062 - val_loss: 23.3006 - val_metrics_pearsonr: 0.1105
# Epoch 71/500
# 3/3 [==============================] - 0s 70ms/step - loss: 22.6297 - metrics_pearsonr: 0.1043 - val_loss: 23.0202 - val_metrics_pearsonr: 0.1085
# Epoch 72/500
# 3/3 [==============================] - 0s 74ms/step - loss: 22.3604 - metrics_pearsonr: 0.1024 - val_loss: 22.7471 - val_metrics_pearsonr: 0.1066
# Epoch 73/500
# 3/3 [==============================] - 0s 99ms/step - loss: 22.0984 - metrics_pearsonr: 0.1006 - val_loss: 22.4809 - val_metrics_pearsonr: 0.1047
# Epoch 74/500
# 3/3 [==============================] - 0s 73ms/step - loss: 21.8432 - metrics_pearsonr: 0.0989 - val_loss: 22.2217 - val_metrics_pearsonr: 0.1029
# Epoch 75/500
# 3/3 [==============================] - 0s 79ms/step - loss: 21.5949 - metrics_pearsonr: 0.0972 - val_loss: 21.9692 - val_metrics_pearsonr: 0.1011
# Epoch 76/500
# 3/3 [==============================] - 0s 70ms/step - loss: 21.3530 - metrics_pearsonr: 0.0955 - val_loss: 21.7233 - val_metrics_pearsonr: 0.0994
# Epoch 77/500
# 3/3 [==============================] - 0s 73ms/step - loss: 21.1175 - metrics_pearsonr: 0.0939 - val_loss: 21.4840 - val_metrics_pearsonr: 0.0978
# Epoch 78/500
# 3/3 [==============================] - 0s 73ms/step - loss: 20.8881 - metrics_pearsonr: 0.0924 - val_loss: 21.2509 - val_metrics_pearsonr: 0.0962
# Epoch 79/500
# 3/3 [==============================] - 0s 71ms/step - loss: 20.6646 - metrics_pearsonr: 0.0909 - val_loss: 21.0241 - val_metrics_pearsonr: 0.0946
# Epoch 80/500
# 3/3 [==============================] - 0s 71ms/step - loss: 20.4470 - metrics_pearsonr: 0.0895 - val_loss: 20.8032 - val_metrics_pearsonr: 0.0932
# Epoch 81/500
# 3/3 [==============================] - 0s 74ms/step - loss: 20.2350 - metrics_pearsonr: 0.0881 - val_loss: 20.5881 - val_metrics_pearsonr: 0.0917
# Epoch 82/500
# 3/3 [==============================] - 0s 68ms/step - loss: 20.0285 - metrics_pearsonr: 0.0867 - val_loss: 20.3788 - val_metrics_pearsonr: 0.0903
# Epoch 83/500
# 3/3 [==============================] - 0s 80ms/step - loss: 19.8273 - metrics_pearsonr: 0.0854 - val_loss: 20.1749 - val_metrics_pearsonr: 0.0890
# Epoch 84/500
# 3/3 [==============================] - 0s 94ms/step - loss: 19.6314 - metrics_pearsonr: 0.0841 - val_loss: 19.9764 - val_metrics_pearsonr: 0.0877
# Epoch 85/500
# 3/3 [==============================] - 0s 83ms/step - loss: 19.4405 - metrics_pearsonr: 0.0829 - val_loss: 19.7832 - val_metrics_pearsonr: 0.0864
# Epoch 86/500
# 3/3 [==============================] - 0s 79ms/step - loss: 19.2545 - metrics_pearsonr: 0.0817 - val_loss: 19.5950 - val_metrics_pearsonr: 0.0852
# Epoch 87/500
# 3/3 [==============================] - 0s 79ms/step - loss: 19.0733 - metrics_pearsonr: 0.0806 - val_loss: 19.4118 - val_metrics_pearsonr: 0.0840
# Epoch 88/500
# 3/3 [==============================] - 0s 78ms/step - loss: 18.8967 - metrics_pearsonr: 0.0795 - val_loss: 19.2335 - val_metrics_pearsonr: 0.0829
# Epoch 89/500
# 3/3 [==============================] - 0s 79ms/step - loss: 18.7246 - metrics_pearsonr: 0.0784 - val_loss: 19.0600 - val_metrics_pearsonr: 0.0818
# Epoch 90/500
# 3/3 [==============================] - 0s 75ms/step - loss: 18.5568 - metrics_pearsonr: 0.0773 - val_loss: 18.8911 - val_metrics_pearsonr: 0.0807
# Epoch 91/500
# 3/3 [==============================] - 0s 75ms/step - loss: 18.3932 - metrics_pearsonr: 0.0763 - val_loss: 18.7268 - val_metrics_pearsonr: 0.0797
# Epoch 92/500
# 3/3 [==============================] - 0s 75ms/step - loss: 18.2335 - metrics_pearsonr: 0.0753 - val_loss: 18.5668 - val_metrics_pearsonr: 0.0787
# Epoch 93/500
# 3/3 [==============================] - 0s 100ms/step - loss: 18.0775 - metrics_pearsonr: 0.0744 - val_loss: 18.4108 - val_metrics_pearsonr: 0.0778
# Epoch 94/500
# 3/3 [==============================] - 0s 73ms/step - loss: 17.9252 - metrics_pearsonr: 0.0734 - val_loss: 18.2586 - val_metrics_pearsonr: 0.0768
# Epoch 95/500
# 3/3 [==============================] - 0s 80ms/step - loss: 17.7764 - metrics_pearsonr: 0.0725 - val_loss: 18.1100 - val_metrics_pearsonr: 0.0759
# Epoch 96/500
# 3/3 [==============================] - 0s 75ms/step - loss: 17.6309 - metrics_pearsonr: 0.0716 - val_loss: 17.9648 - val_metrics_pearsonr: 0.0750
# Epoch 97/500
# 3/3 [==============================] - 0s 70ms/step - loss: 17.4887 - metrics_pearsonr: 0.0708 - val_loss: 17.8229 - val_metrics_pearsonr: 0.0741
# Epoch 98/500
# 3/3 [==============================] - 0s 75ms/step - loss: 17.3499 - metrics_pearsonr: 0.0700 - val_loss: 17.6845 - val_metrics_pearsonr: 0.0733
# Epoch 99/500
# 3/3 [==============================] - 0s 70ms/step - loss: 17.2143 - metrics_pearsonr: 0.0691 - val_loss: 17.5494 - val_metrics_pearsonr: 0.0725
# Epoch 100/500
# 3/3 [==============================] - 0s 74ms/step - loss: 17.0819 - metrics_pearsonr: 0.0684 - val_loss: 17.4176 - val_metrics_pearsonr: 0.0717
# Epoch 101/500
# 3/3 [==============================] - 0s 81ms/step - loss: 16.9527 - metrics_pearsonr: 0.0676 - val_loss: 17.2892 - val_metrics_pearsonr: 0.0709
# Epoch 102/500
# 3/3 [==============================] - 0s 98ms/step - loss: 16.8266 - metrics_pearsonr: 0.0668 - val_loss: 17.1639 - val_metrics_pearsonr: 0.0702
# Epoch 103/500
# 3/3 [==============================] - 0s 77ms/step - loss: 16.7033 - metrics_pearsonr: 0.0661 - val_loss: 17.0417 - val_metrics_pearsonr: 0.0695
# Epoch 104/500
# 3/3 [==============================] - 0s 78ms/step - loss: 16.5827 - metrics_pearsonr: 0.0654 - val_loss: 16.9225 - val_metrics_pearsonr: 0.0687
# Epoch 105/500
# 3/3 [==============================] - 0s 80ms/step - loss: 16.4646 - metrics_pearsonr: 0.0647 - val_loss: 16.8064 - val_metrics_pearsonr: 0.0681
# Epoch 106/500
# 3/3 [==============================] - 0s 84ms/step - loss: 16.3488 - metrics_pearsonr: 0.0640 - val_loss: 16.6929 - val_metrics_pearsonr: 0.0674
# Epoch 107/500
# 3/3 [==============================] - 0s 77ms/step - loss: 16.2351 - metrics_pearsonr: 0.0634 - val_loss: 16.5820 - val_metrics_pearsonr: 0.0667
# Epoch 108/500
# 3/3 [==============================] - 0s 79ms/step - loss: 16.1233 - metrics_pearsonr: 0.0627 - val_loss: 16.4731 - val_metrics_pearsonr: 0.0661
# Epoch 109/500
# 3/3 [==============================] - 0s 78ms/step - loss: 16.0134 - metrics_pearsonr: 0.0621 - val_loss: 16.3659 - val_metrics_pearsonr: 0.0655
# Epoch 110/500
# 3/3 [==============================] - 0s 73ms/step - loss: 15.9054 - metrics_pearsonr: 0.0615 - val_loss: 16.2603 - val_metrics_pearsonr: 0.0649
# Epoch 111/500
# 3/3 [==============================] - 0s 75ms/step - loss: 15.7994 - metrics_pearsonr: 0.0609 - val_loss: 16.1566 - val_metrics_pearsonr: 0.0643
# Epoch 112/500
# 3/3 [==============================] - 0s 84ms/step - loss: 15.6955 - metrics_pearsonr: 0.0603 - val_loss: 16.0549 - val_metrics_pearsonr: 0.0637
# Epoch 113/500
# 3/3 [==============================] - 0s 68ms/step - loss: 15.5940 - metrics_pearsonr: 0.0597 - val_loss: 15.9555 - val_metrics_pearsonr: 0.0631
# Epoch 114/500
# 3/3 [==============================] - 0s 69ms/step - loss: 15.4947 - metrics_pearsonr: 0.0591 - val_loss: 15.8581 - val_metrics_pearsonr: 0.0625
# Epoch 115/500
# 3/3 [==============================] - 0s 75ms/step - loss: 15.3975 - metrics_pearsonr: 0.0586 - val_loss: 15.7628 - val_metrics_pearsonr: 0.0620
# Epoch 116/500
# 3/3 [==============================] - 0s 71ms/step - loss: 15.3023 - metrics_pearsonr: 0.0580 - val_loss: 15.6695 - val_metrics_pearsonr: 0.0615
# Epoch 117/500
# 3/3 [==============================] - 0s 74ms/step - loss: 15.2089 - metrics_pearsonr: 0.0575 - val_loss: 15.5781 - val_metrics_pearsonr: 0.0609
# Epoch 118/500
# 3/3 [==============================] - 0s 69ms/step - loss: 15.1169 - metrics_pearsonr: 0.0570 - val_loss: 15.4887 - val_metrics_pearsonr: 0.0604
# Epoch 119/500
# 3/3 [==============================] - 0s 77ms/step - loss: 15.0263 - metrics_pearsonr: 0.0565 - val_loss: 15.4011 - val_metrics_pearsonr: 0.0599
# Epoch 120/500
# 3/3 [==============================] - 0s 72ms/step - loss: 14.9367 - metrics_pearsonr: 0.0560 - val_loss: 15.3151 - val_metrics_pearsonr: 0.0594
# Epoch 121/500
# 3/3 [==============================] - 0s 72ms/step - loss: 14.8481 - metrics_pearsonr: 0.0555 - val_loss: 15.2303 - val_metrics_pearsonr: 0.0590
# Epoch 122/500
# 3/3 [==============================] - 0s 76ms/step - loss: 14.7605 - metrics_pearsonr: 0.0550 - val_loss: 15.1463 - val_metrics_pearsonr: 0.0585
# Epoch 123/500
# 3/3 [==============================] - 0s 84ms/step - loss: 14.6740 - metrics_pearsonr: 0.0545 - val_loss: 15.0629 - val_metrics_pearsonr: 0.0580
# Epoch 124/500
# 3/3 [==============================] - 0s 67ms/step - loss: 14.5887 - metrics_pearsonr: 0.0541 - val_loss: 14.9804 - val_metrics_pearsonr: 0.0575
# Epoch 125/500
# 3/3 [==============================] - 0s 72ms/step - loss: 14.5050 - metrics_pearsonr: 0.0536 - val_loss: 14.8992 - val_metrics_pearsonr: 0.0571
# Epoch 126/500
# 3/3 [==============================] - 0s 75ms/step - loss: 14.4229 - metrics_pearsonr: 0.0532 - val_loss: 14.8194 - val_metrics_pearsonr: 0.0566
# Epoch 127/500
# 3/3 [==============================] - 0s 81ms/step - loss: 14.3426 - metrics_pearsonr: 0.0527 - val_loss: 14.7411 - val_metrics_pearsonr: 0.0562
# Epoch 128/500
# 3/3 [==============================] - 0s 83ms/step - loss: 14.2638 - metrics_pearsonr: 0.0523 - val_loss: 14.6641 - val_metrics_pearsonr: 0.0558
# Epoch 129/500
# 3/3 [==============================] - 0s 84ms/step - loss: 14.1864 - metrics_pearsonr: 0.0519 - val_loss: 14.5884 - val_metrics_pearsonr: 0.0554
# Epoch 130/500
# 3/3 [==============================] - 0s 78ms/step - loss: 14.1102 - metrics_pearsonr: 0.0514 - val_loss: 14.5139 - val_metrics_pearsonr: 0.0550
# Epoch 131/500
# 3/3 [==============================] - 0s 83ms/step - loss: 14.0349 - metrics_pearsonr: 0.0510 - val_loss: 14.4407 - val_metrics_pearsonr: 0.0545
# Epoch 132/500
# 3/3 [==============================] - 0s 97ms/step - loss: 13.9604 - metrics_pearsonr: 0.0506 - val_loss: 14.3687 - val_metrics_pearsonr: 0.0542
# Epoch 133/500
# 3/3 [==============================] - 0s 82ms/step - loss: 13.8865 - metrics_pearsonr: 0.0502 - val_loss: 14.2980 - val_metrics_pearsonr: 0.0538
# Epoch 134/500
# 3/3 [==============================] - 0s 83ms/step - loss: 13.8130 - metrics_pearsonr: 0.0498 - val_loss: 14.2282 - val_metrics_pearsonr: 0.0534
# Epoch 135/500
# 3/3 [==============================] - 0s 84ms/step - loss: 13.7401 - metrics_pearsonr: 0.0494 - val_loss: 14.1589 - val_metrics_pearsonr: 0.0530
# Epoch 136/500
# 3/3 [==============================] - 0s 84ms/step - loss: 13.6676 - metrics_pearsonr: 0.0491 - val_loss: 14.0898 - val_metrics_pearsonr: 0.0526
# Epoch 137/500
# 3/3 [==============================] - 0s 73ms/step - loss: 13.5960 - metrics_pearsonr: 0.0487 - val_loss: 14.0208 - val_metrics_pearsonr: 0.0522
# Epoch 138/500
# 3/3 [==============================] - 0s 76ms/step - loss: 13.5252 - metrics_pearsonr: 0.0483 - val_loss: 13.9524 - val_metrics_pearsonr: 0.0519
# Epoch 139/500
# 3/3 [==============================] - 0s 69ms/step - loss: 13.4556 - metrics_pearsonr: 0.0479 - val_loss: 13.8849 - val_metrics_pearsonr: 0.0515
# Epoch 140/500
# 3/3 [==============================] - 0s 81ms/step - loss: 13.3873 - metrics_pearsonr: 0.0476 - val_loss: 13.8184 - val_metrics_pearsonr: 0.0512
# Epoch 141/500
# 3/3 [==============================] - 0s 74ms/step - loss: 13.3203 - metrics_pearsonr: 0.0472 - val_loss: 13.7530 - val_metrics_pearsonr: 0.0508
# Epoch 142/500
# 3/3 [==============================] - 0s 85ms/step - loss: 13.2544 - metrics_pearsonr: 0.0469 - val_loss: 13.6884 - val_metrics_pearsonr: 0.0505
# Epoch 143/500
# 3/3 [==============================] - 0s 70ms/step - loss: 13.1895 - metrics_pearsonr: 0.0465 - val_loss: 13.6247 - val_metrics_pearsonr: 0.0501
# Epoch 144/500
# 3/3 [==============================] - 0s 67ms/step - loss: 13.1254 - metrics_pearsonr: 0.0462 - val_loss: 13.5617 - val_metrics_pearsonr: 0.0498
# Epoch 145/500
# 3/3 [==============================] - 0s 70ms/step - loss: 13.0619 - metrics_pearsonr: 0.0459 - val_loss: 13.4996 - val_metrics_pearsonr: 0.0494
# Epoch 146/500
# 3/3 [==============================] - 0s 71ms/step - loss: 12.9988 - metrics_pearsonr: 0.0455 - val_loss: 13.4383 - val_metrics_pearsonr: 0.0491
# Epoch 147/500
# 3/3 [==============================] - 0s 76ms/step - loss: 12.9360 - metrics_pearsonr: 0.0452 - val_loss: 13.3781 - val_metrics_pearsonr: 0.0488
# Epoch 148/500
# 3/3 [==============================] - 0s 70ms/step - loss: 12.8734 - metrics_pearsonr: 0.0449 - val_loss: 13.3186 - val_metrics_pearsonr: 0.0485
# Epoch 149/500
# 3/3 [==============================] - 0s 73ms/step - loss: 12.8110 - metrics_pearsonr: 0.0446 - val_loss: 13.2596 - val_metrics_pearsonr: 0.0482
# Epoch 150/500
# 3/3 [==============================] - 0s 71ms/step - loss: 12.7489 - metrics_pearsonr: 0.0442 - val_loss: 13.2006 - val_metrics_pearsonr: 0.0478
# Epoch 151/500
# 3/3 [==============================] - 0s 68ms/step - loss: 12.6871 - metrics_pearsonr: 0.0439 - val_loss: 13.1414 - val_metrics_pearsonr: 0.0475
# Epoch 152/500
# 3/3 [==============================] - 0s 84ms/step - loss: 12.6258 - metrics_pearsonr: 0.0436 - val_loss: 13.0822 - val_metrics_pearsonr: 0.0472
# Epoch 153/500
# 3/3 [==============================] - 0s 88ms/step - loss: 12.5654 - metrics_pearsonr: 0.0433 - val_loss: 13.0235 - val_metrics_pearsonr: 0.0469
# Epoch 154/500
# 3/3 [==============================] - 0s 78ms/step - loss: 12.5058 - metrics_pearsonr: 0.0430 - val_loss: 12.9654 - val_metrics_pearsonr: 0.0466
# Epoch 155/500
# 3/3 [==============================] - 0s 87ms/step - loss: 12.4473 - metrics_pearsonr: 0.0427 - val_loss: 12.9082 - val_metrics_pearsonr: 0.0463
# Epoch 156/500
# 3/3 [==============================] - 0s 80ms/step - loss: 12.3898 - metrics_pearsonr: 0.0424 - val_loss: 12.8518 - val_metrics_pearsonr: 0.0460
# Epoch 157/500
# 3/3 [==============================] - 0s 76ms/step - loss: 12.3331 - metrics_pearsonr: 0.0422 - val_loss: 12.7960 - val_metrics_pearsonr: 0.0457
# Epoch 158/500
# 3/3 [==============================] - 0s 84ms/step - loss: 12.2773 - metrics_pearsonr: 0.0419 - val_loss: 12.7407 - val_metrics_pearsonr: 0.0455
# Epoch 159/500
# 3/3 [==============================] - 0s 79ms/step - loss: 12.2220 - metrics_pearsonr: 0.0416 - val_loss: 12.6860 - val_metrics_pearsonr: 0.0452
# Epoch 160/500
# 3/3 [==============================] - 0s 73ms/step - loss: 12.1672 - metrics_pearsonr: 0.0413 - val_loss: 12.6317 - val_metrics_pearsonr: 0.0449
# Epoch 161/500
# 3/3 [==============================] - 0s 72ms/step - loss: 12.1127 - metrics_pearsonr: 0.0410 - val_loss: 12.5781 - val_metrics_pearsonr: 0.0446
# Epoch 162/500
# 3/3 [==============================] - 0s 95ms/step - loss: 12.0584 - metrics_pearsonr: 0.0408 - val_loss: 12.5254 - val_metrics_pearsonr: 0.0443
# Epoch 163/500
# 3/3 [==============================] - 0s 80ms/step - loss: 12.0041 - metrics_pearsonr: 0.0405 - val_loss: 12.4734 - val_metrics_pearsonr: 0.0441
# Epoch 164/500
# 3/3 [==============================] - 0s 77ms/step - loss: 11.9498 - metrics_pearsonr: 0.0402 - val_loss: 12.4222 - val_metrics_pearsonr: 0.0438
# Epoch 165/500
# 3/3 [==============================] - 0s 72ms/step - loss: 11.8955 - metrics_pearsonr: 0.0400 - val_loss: 12.3710 - val_metrics_pearsonr: 0.0436
# Epoch 166/500
# 3/3 [==============================] - 0s 76ms/step - loss: 11.8414 - metrics_pearsonr: 0.0397 - val_loss: 12.3195 - val_metrics_pearsonr: 0.0433
# Epoch 167/500
# 3/3 [==============================] - 0s 76ms/step - loss: 11.7874 - metrics_pearsonr: 0.0394 - val_loss: 12.2676 - val_metrics_pearsonr: 0.0430
# Epoch 168/500
# 3/3 [==============================] - 0s 70ms/step - loss: 11.7339 - metrics_pearsonr: 0.0392 - val_loss: 12.2155 - val_metrics_pearsonr: 0.0428
# Epoch 169/500
# 3/3 [==============================] - 0s 67ms/step - loss: 11.6809 - metrics_pearsonr: 0.0389 - val_loss: 12.1638 - val_metrics_pearsonr: 0.0425
# Epoch 170/500
# 3/3 [==============================] - 0s 73ms/step - loss: 11.6288 - metrics_pearsonr: 0.0387 - val_loss: 12.1126 - val_metrics_pearsonr: 0.0423
# Epoch 171/500
# 3/3 [==============================] - 0s 69ms/step - loss: 11.5775 - metrics_pearsonr: 0.0384 - val_loss: 12.0622 - val_metrics_pearsonr: 0.0420
# Epoch 172/500
# 3/3 [==============================] - 0s 70ms/step - loss: 11.5270 - metrics_pearsonr: 0.0382 - val_loss: 12.0125 - val_metrics_pearsonr: 0.0418
# Epoch 173/500
# 3/3 [==============================] - 0s 104ms/step - loss: 11.4774 - metrics_pearsonr: 0.0380 - val_loss: 11.9633 - val_metrics_pearsonr: 0.0415
# Epoch 174/500
# 3/3 [==============================] - 0s 72ms/step - loss: 11.4284 - metrics_pearsonr: 0.0377 - val_loss: 11.9145 - val_metrics_pearsonr: 0.0413
# Epoch 175/500
# 3/3 [==============================] - 0s 71ms/step - loss: 11.3800 - metrics_pearsonr: 0.0375 - val_loss: 11.8661 - val_metrics_pearsonr: 0.0410
# Epoch 176/500
# 3/3 [==============================] - 0s 66ms/step - loss: 11.3320 - metrics_pearsonr: 0.0373 - val_loss: 11.8180 - val_metrics_pearsonr: 0.0408
# Epoch 177/500
# 3/3 [==============================] - 0s 68ms/step - loss: 11.2843 - metrics_pearsonr: 0.0370 - val_loss: 11.7702 - val_metrics_pearsonr: 0.0406
# Epoch 178/500
# 3/3 [==============================] - 0s 70ms/step - loss: 11.2368 - metrics_pearsonr: 0.0368 - val_loss: 11.7231 - val_metrics_pearsonr: 0.0403
# Epoch 179/500
# 3/3 [==============================] - 0s 73ms/step - loss: 11.1894 - metrics_pearsonr: 0.0366 - val_loss: 11.6767 - val_metrics_pearsonr: 0.0401
# Epoch 180/500
# 3/3 [==============================] - 0s 71ms/step - loss: 11.1418 - metrics_pearsonr: 0.0363 - val_loss: 11.6313 - val_metrics_pearsonr: 0.0399
# Epoch 181/500
# 3/3 [==============================] - 0s 80ms/step - loss: 11.0942 - metrics_pearsonr: 0.0361 - val_loss: 11.5866 - val_metrics_pearsonr: 0.0397
# Epoch 182/500
# 3/3 [==============================] - 0s 91ms/step - loss: 11.0465 - metrics_pearsonr: 0.0359 - val_loss: 11.5419 - val_metrics_pearsonr: 0.0395
# Epoch 183/500
# 3/3 [==============================] - 0s 70ms/step - loss: 10.9987 - metrics_pearsonr: 0.0357 - val_loss: 11.4968 - val_metrics_pearsonr: 0.0392
# Epoch 184/500
# 3/3 [==============================] - 0s 76ms/step - loss: 10.9509 - metrics_pearsonr: 0.0355 - val_loss: 11.4507 - val_metrics_pearsonr: 0.0390
# Epoch 185/500
# 3/3 [==============================] - 0s 77ms/step - loss: 10.9033 - metrics_pearsonr: 0.0352 - val_loss: 11.4042 - val_metrics_pearsonr: 0.0388
# Epoch 186/500
# 3/3 [==============================] - 0s 80ms/step - loss: 10.8562 - metrics_pearsonr: 0.0350 - val_loss: 11.3577 - val_metrics_pearsonr: 0.0386
# Epoch 187/500
# 3/3 [==============================] - 0s 80ms/step - loss: 10.8097 - metrics_pearsonr: 0.0348 - val_loss: 11.3118 - val_metrics_pearsonr: 0.0384
# Epoch 188/500
# 3/3 [==============================] - 0s 75ms/step - loss: 10.7640 - metrics_pearsonr: 0.0346 - val_loss: 11.2667 - val_metrics_pearsonr: 0.0381
# Epoch 189/500
# 3/3 [==============================] - 0s 77ms/step - loss: 10.7191 - metrics_pearsonr: 0.0344 - val_loss: 11.2223 - val_metrics_pearsonr: 0.0379
# Epoch 190/500
# 3/3 [==============================] - 0s 77ms/step - loss: 10.6749 - metrics_pearsonr: 0.0342 - val_loss: 11.1784 - val_metrics_pearsonr: 0.0377
# Epoch 191/500
# 3/3 [==============================] - 0s 93ms/step - loss: 10.6315 - metrics_pearsonr: 0.0340 - val_loss: 11.1350 - val_metrics_pearsonr: 0.0375
# Epoch 192/500
# 3/3 [==============================] - 0s 85ms/step - loss: 10.5886 - metrics_pearsonr: 0.0338 - val_loss: 11.0919 - val_metrics_pearsonr: 0.0373
# Epoch 193/500
# 3/3 [==============================] - 0s 78ms/step - loss: 10.5463 - metrics_pearsonr: 0.0336 - val_loss: 11.0490 - val_metrics_pearsonr: 0.0371
# Epoch 194/500
# 3/3 [==============================] - 0s 79ms/step - loss: 10.5043 - metrics_pearsonr: 0.0334 - val_loss: 11.0063 - val_metrics_pearsonr: 0.0369
# Epoch 195/500
# 3/3 [==============================] - 0s 73ms/step - loss: 10.4626 - metrics_pearsonr: 0.0332 - val_loss: 10.9638 - val_metrics_pearsonr: 0.0367
# Epoch 196/500
# 3/3 [==============================] - 0s 73ms/step - loss: 10.4210 - metrics_pearsonr: 0.0330 - val_loss: 10.9217 - val_metrics_pearsonr: 0.0365
# Epoch 197/500
# 3/3 [==============================] - 0s 75ms/step - loss: 10.3795 - metrics_pearsonr: 0.0328 - val_loss: 10.8804 - val_metrics_pearsonr: 0.0363
# Epoch 198/500
# 3/3 [==============================] - 0s 80ms/step - loss: 10.3378 - metrics_pearsonr: 0.0326 - val_loss: 10.8402 - val_metrics_pearsonr: 0.0362
# Epoch 199/500
# 3/3 [==============================] - 0s 74ms/step - loss: 10.2959 - metrics_pearsonr: 0.0325 - val_loss: 10.8011 - val_metrics_pearsonr: 0.0360
# Epoch 200/500
# 3/3 [==============================] - 0s 73ms/step - loss: 10.2539 - metrics_pearsonr: 0.0323 - val_loss: 10.7625 - val_metrics_pearsonr: 0.0358
# Epoch 201/500
# 3/3 [==============================] - 0s 93ms/step - loss: 10.2116 - metrics_pearsonr: 0.0321 - val_loss: 10.7234 - val_metrics_pearsonr: 0.0356
# Epoch 202/500
# 3/3 [==============================] - 0s 85ms/step - loss: 10.1691 - metrics_pearsonr: 0.0319 - val_loss: 10.6829 - val_metrics_pearsonr: 0.0354
# Epoch 203/500
# 3/3 [==============================] - 0s 74ms/step - loss: 10.1266 - metrics_pearsonr: 0.0317 - val_loss: 10.6411 - val_metrics_pearsonr: 0.0352
# Epoch 204/500
# 3/3 [==============================] - 0s 74ms/step - loss: 10.0843 - metrics_pearsonr: 0.0316 - val_loss: 10.5988 - val_metrics_pearsonr: 0.0350
# Epoch 205/500
# 3/3 [==============================] - 0s 70ms/step - loss: 10.0424 - metrics_pearsonr: 0.0314 - val_loss: 10.5570 - val_metrics_pearsonr: 0.0349
# Epoch 206/500
# 3/3 [==============================] - 0s 69ms/step - loss: 10.0012 - metrics_pearsonr: 0.0312 - val_loss: 10.5161 - val_metrics_pearsonr: 0.0347
# Epoch 207/500
# 3/3 [==============================] - 0s 71ms/step - loss: 9.9608 - metrics_pearsonr: 0.0310 - val_loss: 10.4761 - val_metrics_pearsonr: 0.0345
# Epoch 208/500
# 3/3 [==============================] - 0s 73ms/step - loss: 9.9213 - metrics_pearsonr: 0.0309 - val_loss: 10.4369 - val_metrics_pearsonr: 0.0343
# Epoch 209/500
# 3/3 [==============================] - 0s 69ms/step - loss: 9.8825 - metrics_pearsonr: 0.0307 - val_loss: 10.3981 - val_metrics_pearsonr: 0.0341
# Epoch 210/500
# 3/3 [==============================] - 0s 75ms/step - loss: 9.8444 - metrics_pearsonr: 0.0305 - val_loss: 10.3597 - val_metrics_pearsonr: 0.0340
# Epoch 211/500
# 3/3 [==============================] - 0s 73ms/step - loss: 9.8067 - metrics_pearsonr: 0.0304 - val_loss: 10.3215 - val_metrics_pearsonr: 0.0338
# Epoch 212/500
# 3/3 [==============================] - 0s 71ms/step - loss: 9.7696 - metrics_pearsonr: 0.0302 - val_loss: 10.2835 - val_metrics_pearsonr: 0.0336
# Epoch 213/500
# 3/3 [==============================] - 0s 84ms/step - loss: 9.7328 - metrics_pearsonr: 0.0300 - val_loss: 10.2454 - val_metrics_pearsonr: 0.0335
# Epoch 214/500
# 3/3 [==============================] - 0s 83ms/step - loss: 9.6962 - metrics_pearsonr: 0.0299 - val_loss: 10.2075 - val_metrics_pearsonr: 0.0333
# Epoch 215/500
# 3/3 [==============================] - 0s 84ms/step - loss: 9.6598 - metrics_pearsonr: 0.0297 - val_loss: 10.1698 - val_metrics_pearsonr: 0.0331
# Epoch 216/500
# 3/3 [==============================] - 0s 85ms/step - loss: 9.6234 - metrics_pearsonr: 0.0295 - val_loss: 10.1327 - val_metrics_pearsonr: 0.0330
# Epoch 217/500
# 3/3 [==============================] - 0s 83ms/step - loss: 9.5869 - metrics_pearsonr: 0.0294 - val_loss: 10.0968 - val_metrics_pearsonr: 0.0328
# Epoch 218/500
# 3/3 [==============================] - 0s 73ms/step - loss: 9.5502 - metrics_pearsonr: 0.0292 - val_loss: 10.0622 - val_metrics_pearsonr: 0.0327
# Epoch 219/500
# 3/3 [==============================] - 0s 74ms/step - loss: 9.5133 - metrics_pearsonr: 0.0291 - val_loss: 10.0287 - val_metrics_pearsonr: 0.0325
# Epoch 220/500
# 3/3 [==============================] - 0s 78ms/step - loss: 9.4761 - metrics_pearsonr: 0.0289 - val_loss: 9.9951 - val_metrics_pearsonr: 0.0324
# Epoch 221/500
# 3/3 [==============================] - 0s 79ms/step - loss: 9.4386 - metrics_pearsonr: 0.0288 - val_loss: 9.9602 - val_metrics_pearsonr: 0.0322
# Epoch 222/500
# 3/3 [==============================] - 0s 89ms/step - loss: 9.4009 - metrics_pearsonr: 0.0286 - val_loss: 9.9234 - val_metrics_pearsonr: 0.0321
# Epoch 223/500
# 3/3 [==============================] - 0s 81ms/step - loss: 9.3631 - metrics_pearsonr: 0.0285 - val_loss: 9.8852 - val_metrics_pearsonr: 0.0319
# Epoch 224/500
# 3/3 [==============================] - 0s 78ms/step - loss: 9.3254 - metrics_pearsonr: 0.0283 - val_loss: 9.8468 - val_metrics_pearsonr: 0.0317
# Epoch 225/500
# 3/3 [==============================] - 0s 76ms/step - loss: 9.2883 - metrics_pearsonr: 0.0282 - val_loss: 9.8094 - val_metrics_pearsonr: 0.0316
# Epoch 226/500
# 3/3 [==============================] - 0s 71ms/step - loss: 9.2519 - metrics_pearsonr: 0.0280 - val_loss: 9.7731 - val_metrics_pearsonr: 0.0314
# Epoch 227/500
# 3/3 [==============================] - 0s 82ms/step - loss: 9.2163 - metrics_pearsonr: 0.0279 - val_loss: 9.7380 - val_metrics_pearsonr: 0.0313
# Epoch 228/500
# 3/3 [==============================] - 0s 77ms/step - loss: 9.1816 - metrics_pearsonr: 0.0277 - val_loss: 9.7035 - val_metrics_pearsonr: 0.0311
# Epoch 229/500
# 3/3 [==============================] - 0s 78ms/step - loss: 9.1475 - metrics_pearsonr: 0.0276 - val_loss: 9.6693 - val_metrics_pearsonr: 0.0310
# Epoch 230/500
# 3/3 [==============================] - 0s 71ms/step - loss: 9.1140 - metrics_pearsonr: 0.0275 - val_loss: 9.6354 - val_metrics_pearsonr: 0.0308
# Epoch 231/500
# 3/3 [==============================] - 0s 73ms/step - loss: 9.0810 - metrics_pearsonr: 0.0273 - val_loss: 9.6015 - val_metrics_pearsonr: 0.0307
# Epoch 232/500
# 3/3 [==============================] - 0s 97ms/step - loss: 9.0483 - metrics_pearsonr: 0.0272 - val_loss: 9.5677 - val_metrics_pearsonr: 0.0306
# Epoch 233/500
# 3/3 [==============================] - 0s 65ms/step - loss: 9.0160 - metrics_pearsonr: 0.0270 - val_loss: 9.5339 - val_metrics_pearsonr: 0.0304
# Epoch 234/500
# 3/3 [==============================] - 0s 78ms/step - loss: 8.9839 - metrics_pearsonr: 0.0269 - val_loss: 9.5000 - val_metrics_pearsonr: 0.0303
# Epoch 235/500
# 3/3 [==============================] - 0s 84ms/step - loss: 8.9519 - metrics_pearsonr: 0.0268 - val_loss: 9.4664 - val_metrics_pearsonr: 0.0301
# Epoch 236/500
# 3/3 [==============================] - 0s 73ms/step - loss: 8.9200 - metrics_pearsonr: 0.0266 - val_loss: 9.4332 - val_metrics_pearsonr: 0.0300
# Epoch 237/500
# 3/3 [==============================] - 0s 76ms/step - loss: 8.8881 - metrics_pearsonr: 0.0265 - val_loss: 9.4009 - val_metrics_pearsonr: 0.0299
# Epoch 238/500
# 3/3 [==============================] - 0s 79ms/step - loss: 8.8560 - metrics_pearsonr: 0.0264 - val_loss: 9.3699 - val_metrics_pearsonr: 0.0297
# Epoch 239/500
# 3/3 [==============================] - 0s 80ms/step - loss: 8.8237 - metrics_pearsonr: 0.0262 - val_loss: 9.3402 - val_metrics_pearsonr: 0.0296
# Epoch 240/500
# 3/3 [==============================] - 0s 79ms/step - loss: 8.7912 - metrics_pearsonr: 0.0261 - val_loss: 9.3111 - val_metrics_pearsonr: 0.0295
# Epoch 241/500
# 3/3 [==============================] - 0s 103ms/step - loss: 8.7585 - metrics_pearsonr: 0.0260 - val_loss: 9.2813 - val_metrics_pearsonr: 0.0294
# Epoch 242/500
# 3/3 [==============================] - 0s 78ms/step - loss: 8.7254 - metrics_pearsonr: 0.0259 - val_loss: 9.2497 - val_metrics_pearsonr: 0.0292
# Epoch 243/500
# 3/3 [==============================] - 0s 81ms/step - loss: 8.6921 - metrics_pearsonr: 0.0257 - val_loss: 9.2162 - val_metrics_pearsonr: 0.0291
# Epoch 244/500
# 3/3 [==============================] - 0s 74ms/step - loss: 8.6588 - metrics_pearsonr: 0.0256 - val_loss: 9.1817 - val_metrics_pearsonr: 0.0290
# Epoch 245/500
# 3/3 [==============================] - 0s 82ms/step - loss: 8.6256 - metrics_pearsonr: 0.0255 - val_loss: 9.1475 - val_metrics_pearsonr: 0.0288
# Epoch 246/500
# 3/3 [==============================] - 0s 81ms/step - loss: 8.5929 - metrics_pearsonr: 0.0254 - val_loss: 9.1143 - val_metrics_pearsonr: 0.0287
# Epoch 247/500
# 3/3 [==============================] - 0s 74ms/step - loss: 8.5610 - metrics_pearsonr: 0.0252 - val_loss: 9.0824 - val_metrics_pearsonr: 0.0286
# Epoch 248/500
# 3/3 [==============================] - 0s 73ms/step - loss: 8.5298 - metrics_pearsonr: 0.0251 - val_loss: 9.0515 - val_metrics_pearsonr: 0.0285
# Epoch 249/500
# 3/3 [==============================] - 0s 72ms/step - loss: 8.4992 - metrics_pearsonr: 0.0250 - val_loss: 9.0211 - val_metrics_pearsonr: 0.0283
# Epoch 250/500
# 3/3 [==============================] - 0s 75ms/step - loss: 8.4693 - metrics_pearsonr: 0.0249 - val_loss: 8.9910 - val_metrics_pearsonr: 0.0282
# Epoch 251/500
# 3/3 [==============================] - 0s 71ms/step - loss: 8.4398 - metrics_pearsonr: 0.0248 - val_loss: 8.9611 - val_metrics_pearsonr: 0.0281
# Epoch 252/500
# 3/3 [==============================] - 0s 105ms/step - loss: 8.4107 - metrics_pearsonr: 0.0247 - val_loss: 8.9312 - val_metrics_pearsonr: 0.0280
# Epoch 253/500
# 3/3 [==============================] - 0s 79ms/step - loss: 8.3821 - metrics_pearsonr: 0.0245 - val_loss: 8.9012 - val_metrics_pearsonr: 0.0278
# Epoch 254/500
# 3/3 [==============================] - 0s 84ms/step - loss: 8.3537 - metrics_pearsonr: 0.0244 - val_loss: 8.8713 - val_metrics_pearsonr: 0.0277
# Epoch 255/500
# 3/3 [==============================] - 0s 77ms/step - loss: 8.3255 - metrics_pearsonr: 0.0243 - val_loss: 8.8414 - val_metrics_pearsonr: 0.0276
# Epoch 256/500
# 3/3 [==============================] - 0s 78ms/step - loss: 8.2976 - metrics_pearsonr: 0.0242 - val_loss: 8.8114 - val_metrics_pearsonr: 0.0275
# Epoch 257/500
# 3/3 [==============================] - 0s 78ms/step - loss: 8.2697 - metrics_pearsonr: 0.0241 - val_loss: 8.7816 - val_metrics_pearsonr: 0.0274
# Epoch 258/500
# 3/3 [==============================] - 0s 76ms/step - loss: 8.2419 - metrics_pearsonr: 0.0240 - val_loss: 8.7523 - val_metrics_pearsonr: 0.0273
# Epoch 259/500
# 3/3 [==============================] - 0s 77ms/step - loss: 8.2141 - metrics_pearsonr: 0.0239 - val_loss: 8.7239 - val_metrics_pearsonr: 0.0272
# Epoch 260/500
# 3/3 [==============================] - 0s 74ms/step - loss: 8.1862 - metrics_pearsonr: 0.0238 - val_loss: 8.6968 - val_metrics_pearsonr: 0.0270
# Epoch 261/500
# 3/3 [==============================] - 0s 74ms/step - loss: 8.1582 - metrics_pearsonr: 0.0237 - val_loss: 8.6709 - val_metrics_pearsonr: 0.0269
# Epoch 262/500
# 3/3 [==============================] - 0s 75ms/step - loss: 8.1300 - metrics_pearsonr: 0.0235 - val_loss: 8.6457 - val_metrics_pearsonr: 0.0268
# Epoch 263/500
# 3/3 [==============================] - 0s 102ms/step - loss: 8.1016 - metrics_pearsonr: 0.0234 - val_loss: 8.6201 - val_metrics_pearsonr: 0.0267
# Epoch 264/500
# 3/3 [==============================] - 0s 66ms/step - loss: 8.0730 - metrics_pearsonr: 0.0233 - val_loss: 8.5929 - val_metrics_pearsonr: 0.0266
# Epoch 265/500
# 3/3 [==============================] - 0s 69ms/step - loss: 8.0441 - metrics_pearsonr: 0.0232 - val_loss: 8.5638 - val_metrics_pearsonr: 0.0265
# Epoch 266/500
# 3/3 [==============================] - 0s 74ms/step - loss: 8.0150 - metrics_pearsonr: 0.0231 - val_loss: 8.5332 - val_metrics_pearsonr: 0.0264
# Epoch 267/500
# 3/3 [==============================] - 0s 69ms/step - loss: 7.9859 - metrics_pearsonr: 0.0230 - val_loss: 8.5024 - val_metrics_pearsonr: 0.0263
# Epoch 268/500
# 3/3 [==============================] - 0s 78ms/step - loss: 7.9571 - metrics_pearsonr: 0.0229 - val_loss: 8.4724 - val_metrics_pearsonr: 0.0262
# Epoch 269/500
# 3/3 [==============================] - 0s 76ms/step - loss: 7.9288 - metrics_pearsonr: 0.0228 - val_loss: 8.4437 - val_metrics_pearsonr: 0.0261
# Epoch 270/500
# 3/3 [==============================] - 0s 78ms/step - loss: 7.9012 - metrics_pearsonr: 0.0227 - val_loss: 8.4162 - val_metrics_pearsonr: 0.0260
# Epoch 271/500
# 3/3 [==============================] - 0s 71ms/step - loss: 7.8742 - metrics_pearsonr: 0.0226 - val_loss: 8.3894 - val_metrics_pearsonr: 0.0259
# Epoch 272/500
# 3/3 [==============================] - 0s 72ms/step - loss: 7.8477 - metrics_pearsonr: 0.0225 - val_loss: 8.3631 - val_metrics_pearsonr: 0.0258
# Epoch 273/500
# 3/3 [==============================] - 0s 74ms/step - loss: 7.8217 - metrics_pearsonr: 0.0224 - val_loss: 8.3369 - val_metrics_pearsonr: 0.0257
# Epoch 274/500
# 3/3 [==============================] - 0s 96ms/step - loss: 7.7961 - metrics_pearsonr: 0.0223 - val_loss: 8.3108 - val_metrics_pearsonr: 0.0255
# Epoch 275/500
# 3/3 [==============================] - 0s 63ms/step - loss: 7.7709 - metrics_pearsonr: 0.0222 - val_loss: 8.2846 - val_metrics_pearsonr: 0.0254
# Epoch 276/500
# 3/3 [==============================] - 0s 76ms/step - loss: 7.7460 - metrics_pearsonr: 0.0221 - val_loss: 8.2584 - val_metrics_pearsonr: 0.0253
# Epoch 277/500
# 3/3 [==============================] - 0s 73ms/step - loss: 7.7213 - metrics_pearsonr: 0.0221 - val_loss: 8.2322 - val_metrics_pearsonr: 0.0253
# Epoch 278/500
# ...
# Epoch 421/500
# 3/3 [==============================] - 0s 82ms/step - loss: 0.9136 - metrics_pearsonr: 0.0013 - val_loss: 1.1581 - val_metrics_pearsonr: 0.0018
# Epoch 422/500
# 3/3 [==============================] - 0s 80ms/step - loss: 0.9124 - metrics_pearsonr: 0.0013 - val_loss: 1.1551 - val_metrics_pearsonr: 0.0018
# Epoch 423/500
# 3/3 [==============================] - 0s 83ms/step - loss: 0.9109 - metrics_pearsonr: 0.0013 - val_loss: 1.1574 - val_metrics_pearsonr: 0.0018
# Epoch 424/500
# 3/3 [==============================] - 0s 81ms/step - loss: 0.9098 - metrics_pearsonr: 0.0013 - val_loss: 1.1629 - val_metrics_pearsonr: 0.0018
# Epoch 425/500
# 3/3 [==============================] - 0s 82ms/step - loss: 0.9096 - metrics_pearsonr: 0.0013 - val_loss: 1.1638 - val_metrics_pearsonr: 0.0018
# Epoch 426/500
# 3/3 [==============================] - 0s 82ms/step - loss: 0.9090 - metrics_pearsonr: 0.0013 - val_loss: 1.1582 - val_metrics_pearsonr: 0.0018
# Epoch 427/500
# 3/3 [==============================] - 0s 98ms/step - loss: 0.9068 - metrics_pearsonr: 0.0013 - val_loss: 1.1537 - val_metrics_pearsonr: 0.0018
# Epoch 428/500
# 3/3 [==============================] - 0s 93ms/step - loss: 0.9045 - metrics_pearsonr: 0.0013 - val_loss: 1.1554 - val_metrics_pearsonr: 0.0018
# Epoch 429/500
# 3/3 [==============================] - 0s 83ms/step - loss: 0.9042 - metrics_pearsonr: 0.0013 - val_loss: 1.1579 - val_metrics_pearsonr: 0.0018
# Epoch 430/500
# 3/3 [==============================] - 0s 76ms/step - loss: 0.9046 - metrics_pearsonr: 0.0013 - val_loss: 1.1557 - val_metrics_pearsonr: 0.0018
# Epoch 431/500
# 3/3 [==============================] - 0s 75ms/step - loss: 0.9039 - metrics_pearsonr: 0.0013 - val_loss: 1.1528 - val_metrics_pearsonr: 0.0018
# Epoch 432/500
# 3/3 [==============================] - 0s 78ms/step - loss: 0.9029 - metrics_pearsonr: 0.0013 - val_loss: 1.1533 - val_metrics_pearsonr: 0.0018
# Epoch 433/500
# 3/3 [==============================] - 0s 78ms/step - loss: 0.9029 - metrics_pearsonr: 0.0013 - val_loss: 1.1546 - val_metrics_pearsonr: 0.0018
# Epoch 434/500
# 3/3 [==============================] - 0s 82ms/step - loss: 0.9032 - metrics_pearsonr: 0.0013 - val_loss: 1.1537 - val_metrics_pearsonr: 0.0018
# Epoch 435/500
# 3/3 [==============================] - 0s 82ms/step - loss: 0.9027 - metrics_pearsonr: 0.0013 - val_loss: 1.1525 - val_metrics_pearsonr: 0.0018
# Epoch 436/500
# 3/3 [==============================] - 0s 80ms/step - loss: 0.9015 - metrics_pearsonr: 0.0013 - val_loss: 1.1528 - val_metrics_pearsonr: 0.0018
# Epoch 437/500
# 3/3 [==============================] - 0s 84ms/step - loss: 0.9005 - metrics_pearsonr: 0.0013 - val_loss: 1.1535 - val_metrics_pearsonr: 0.0018
# Epoch 438/500
# 3/3 [==============================] - 0s 80ms/step - loss: 0.8998 - metrics_pearsonr: 0.0013 - val_loss: 1.1531 - val_metrics_pearsonr: 0.0018
# Epoch 439/500
# 3/3 [==============================] - 0s 79ms/step - loss: 0.8992 - metrics_pearsonr: 0.0013 - val_loss: 1.1520 - val_metrics_pearsonr: 0.0018
# Epoch 440/500
# 3/3 [==============================] - 0s 100ms/step - loss: 0.8984 - metrics_pearsonr: 0.0013 - val_loss: 1.1515 - val_metrics_pearsonr: 0.0018
# Epoch 441/500
# 3/3 [==============================] - 0s 74ms/step - loss: 0.8978 - metrics_pearsonr: 0.0013 - val_loss: 1.1516 - val_metrics_pearsonr: 0.0018
# Epoch 442/500
# 3/3 [==============================] - 0s 81ms/step - loss: 0.8975 - metrics_pearsonr: 0.0013 - val_loss: 1.1517 - val_metrics_pearsonr: 0.0018
# Epoch 443/500
# 3/3 [==============================] - 0s 82ms/step - loss: 0.8973 - metrics_pearsonr: 0.0013 - val_loss: 1.1517 - val_metrics_pearsonr: 0.0018
# Epoch 444/500
# 3/3 [==============================] - 0s 78ms/step - loss: 0.8971 - metrics_pearsonr: 0.0013 - val_loss: 1.1517 - val_metrics_pearsonr: 0.0018
# Epoch 445/500
# 3/3 [==============================] - 0s 79ms/step - loss: 0.8970 - metrics_pearsonr: 0.0013 - val_loss: 1.1519 - val_metrics_pearsonr: 0.0018
# Epoch 446/500
# 3/3 [==============================] - 0s 84ms/step - loss: 0.8970 - metrics_pearsonr: 0.0013 - val_loss: 1.1517 - val_metrics_pearsonr: 0.0018
# Epoch 447/500
# 3/3 [==============================] - 0s 82ms/step - loss: 0.8970 - metrics_pearsonr: 0.0013 - val_loss: 1.1509 - val_metrics_pearsonr: 0.0018
# Epoch 448/500
# 3/3 [==============================] - 0s 82ms/step - loss: 0.8971 - metrics_pearsonr: 0.0013 - val_loss: 1.1499 - val_metrics_pearsonr: 0.0018
# Epoch 449/500
# 3/3 [==============================] - 0s 80ms/step - loss: 0.8973 - metrics_pearsonr: 0.0013 - val_loss: 1.1493 - val_metrics_pearsonr: 0.0018
# Epoch 450/500
# 3/3 [==============================] - 0s 82ms/step - loss: 0.8975 - metrics_pearsonr: 0.0013 - val_loss: 1.1495 - val_metrics_pearsonr: 0.0018
# Epoch 451/500
# 3/3 [==============================] - 0s 84ms/step - loss: 0.8978 - metrics_pearsonr: 0.0013 - val_loss: 1.1502 - val_metrics_pearsonr: 0.0018
# Epoch 452/500
# 3/3 [==============================] - 0s 91ms/step - loss: 0.8979 - metrics_pearsonr: 0.0013 - val_loss: 1.1508 - val_metrics_pearsonr: 0.0018
# Epoch 453/500
# 3/3 [==============================] - 0s 98ms/step - loss: 0.8979 - metrics_pearsonr: 0.0013 - val_loss: 1.1506 - val_metrics_pearsonr: 0.0018
# Epoch 454/500
# 3/3 [==============================] - 0s 81ms/step - loss: 0.8976 - metrics_pearsonr: 0.0013 - val_loss: 1.1498 - val_metrics_pearsonr: 0.0018
# Epoch 455/500
# 3/3 [==============================] - 0s 85ms/step - loss: 0.8974 - metrics_pearsonr: 0.0013 - val_loss: 1.1487 - val_metrics_pearsonr: 0.0018
# Epoch 456/500
# 3/3 [==============================] - 0s 81ms/step - loss: 0.8975 - metrics_pearsonr: 0.0013 - val_loss: 1.1475 - val_metrics_pearsonr: 0.0018
# Epoch 457/500
# 3/3 [==============================] - 0s 78ms/step - loss: 0.8981 - metrics_pearsonr: 0.0013 - val_loss: 1.1467 - val_metrics_pearsonr: 0.0018
# Epoch 458/500
# 3/3 [==============================] - 0s 78ms/step - loss: 0.8994 - metrics_pearsonr: 0.0013 - val_loss: 1.1467 - val_metrics_pearsonr: 0.0018
# Epoch 459/500
# 3/3 [==============================] - 0s 80ms/step - loss: 0.9012 - metrics_pearsonr: 0.0013 - val_loss: 1.1478 - val_metrics_pearsonr: 0.0018
# Epoch 460/500
# 3/3 [==============================] - 0s 79ms/step - loss: 0.9037 - metrics_pearsonr: 0.0013 - val_loss: 1.1507 - val_metrics_pearsonr: 0.0018
# Epoch 461/500
# 3/3 [==============================] - 0s 78ms/step - loss: 0.9067 - metrics_pearsonr: 0.0013 - val_loss: 1.1553 - val_metrics_pearsonr: 0.0018
# Epoch 462/500
# 3/3 [==============================] - 0s 78ms/step - loss: 0.9097 - metrics_pearsonr: 0.0013 - val_loss: 1.1607 - val_metrics_pearsonr: 0.0018
# Epoch 463/500
# 3/3 [==============================] - 0s 79ms/step - loss: 0.9120 - metrics_pearsonr: 0.0013 - val_loss: 1.1669 - val_metrics_pearsonr: 0.0018
# Epoch 464/500
# 3/3 [==============================] - 0s 86ms/step - loss: 0.9133 - metrics_pearsonr: 0.0013 - val_loss: 1.1786 - val_metrics_pearsonr: 0.0018
# Epoch 465/500
# 3/3 [==============================] - 0s 88ms/step - loss: 0.9159 - metrics_pearsonr: 0.0013 - val_loss: 1.2027 - val_metrics_pearsonr: 0.0018
# Epoch 466/500
# 3/3 [==============================] - 0s 73ms/step - loss: 0.9230 - metrics_pearsonr: 0.0013 - val_loss: 1.2314 - val_metrics_pearsonr: 0.0018
# Epoch 467/500
# 3/3 [==============================] - 0s 85ms/step - loss: 0.9319 - metrics_pearsonr: 0.0013 - val_loss: 1.2351 - val_metrics_pearsonr: 0.0018
# Epoch 468/500
# 3/3 [==============================] - 0s 83ms/step - loss: 0.9344 - metrics_pearsonr: 0.0013 - val_loss: 1.2145 - val_metrics_pearsonr: 0.0018
# Epoch 469/500
# 3/3 [==============================] - 0s 83ms/step - loss: 0.9346 - metrics_pearsonr: 0.0013 - val_loss: 1.2132 - val_metrics_pearsonr: 0.0019
# Epoch 470/500
# 3/3 [==============================] - 0s 79ms/step - loss: 0.9408 - metrics_pearsonr: 0.0013 - val_loss: 1.1908 - val_metrics_pearsonr: 0.0019
# Epoch 471/500
# 3/3 [==============================] - 0s 78ms/step - loss: 0.9366 - metrics_pearsonr: 0.0013 - val_loss: 1.1498 - val_metrics_pearsonr: 0.0018
# Epoch 472/500
# 3/3 [==============================] - 0s 84ms/step - loss: 0.9199 - metrics_pearsonr: 0.0013 - val_loss: 1.1877 - val_metrics_pearsonr: 0.0018
# Epoch 473/500
# 3/3 [==============================] - 0s 83ms/step - loss: 0.9249 - metrics_pearsonr: 0.0013 - val_loss: 1.1794 - val_metrics_pearsonr: 0.0018
# Epoch 474/500
# 3/3 [==============================] - 0s 86ms/step - loss: 0.9187 - metrics_pearsonr: 0.0013 - val_loss: 1.1755 - val_metrics_pearsonr: 0.0018
# Epoch 475/500
# 3/3 [==============================] - 0s 83ms/step - loss: 0.9099 - metrics_pearsonr: 0.0013 - val_loss: 1.1744 - val_metrics_pearsonr: 0.0018
# Epoch 476/500
# 3/3 [==============================] - 0s 78ms/step - loss: 0.9078 - metrics_pearsonr: 0.0013 - val_loss: 1.1638 - val_metrics_pearsonr: 0.0018
# Epoch 477/500
# 3/3 [==============================] - 0s 86ms/step - loss: 0.9011 - metrics_pearsonr: 0.0013 - val_loss: 1.1637 - val_metrics_pearsonr: 0.0018
# Epoch 478/500
# 3/3 [==============================] - 0s 97ms/step - loss: 0.8987 - metrics_pearsonr: 0.0013 - val_loss: 1.1528 - val_metrics_pearsonr: 0.0018
# Epoch 479/500
# 3/3 [==============================] - 0s 72ms/step - loss: 0.8935 - metrics_pearsonr: 0.0013 - val_loss: 1.1571 - val_metrics_pearsonr: 0.0018
# Epoch 480/500
# 3/3 [==============================] - 0s 89ms/step - loss: 0.8923 - metrics_pearsonr: 0.0013 - val_loss: 1.1523 - val_metrics_pearsonr: 0.0018
# Epoch 481/500
# 3/3 [==============================] - 0s 81ms/step - loss: 0.8890 - metrics_pearsonr: 0.0013 - val_loss: 1.1541 - val_metrics_pearsonr: 0.0018
# Epoch 482/500
# 3/3 [==============================] - 0s 84ms/step - loss: 0.8886 - metrics_pearsonr: 0.0013 - val_loss: 1.1517 - val_metrics_pearsonr: 0.0018
# Epoch 483/500
# 3/3 [==============================] - 0s 81ms/step - loss: 0.8873 - metrics_pearsonr: 0.0013 - val_loss: 1.1546 - val_metrics_pearsonr: 0.0018
# Epoch 484/500
# 3/3 [==============================] - 0s 79ms/step - loss: 0.8881 - metrics_pearsonr: 0.0013 - val_loss: 1.1518 - val_metrics_pearsonr: 0.0018
# Epoch 485/500
# 3/3 [==============================] - 0s 80ms/step - loss: 0.8876 - metrics_pearsonr: 0.0013 - val_loss: 1.1486 - val_metrics_pearsonr: 0.0018
# Epoch 486/500
# 3/3 [==============================] - 0s 81ms/step - loss: 0.8860 - metrics_pearsonr: 0.0013 - val_loss: 1.1439 - val_metrics_pearsonr: 0.0018
# Epoch 487/500
# 3/3 [==============================] - 0s 80ms/step - loss: 0.8840 - metrics_pearsonr: 0.0013 - val_loss: 1.1461 - val_metrics_pearsonr: 0.0018
# Epoch 488/500
# 3/3 [==============================] - 0s 76ms/step - loss: 0.8835 - metrics_pearsonr: 0.0013 - val_loss: 1.1480 - val_metrics_pearsonr: 0.0018
# Epoch 489/500
# 3/3 [==============================] - 0s 81ms/step - loss: 0.8820 - metrics_pearsonr: 0.0013 - val_loss: 1.1480 - val_metrics_pearsonr: 0.0018
# Epoch 490/500
# 3/3 [==============================] - 0s 109ms/step - loss: 0.8804 - metrics_pearsonr: 0.0013 - val_loss: 1.1440 - val_metrics_pearsonr: 0.0018
# Epoch 491/500
# 3/3 [==============================] - 0s 94ms/step - loss: 0.8786 - metrics_pearsonr: 0.0013 - val_loss: 1.1424 - val_metrics_pearsonr: 0.0018
# Epoch 492/500
# 3/3 [==============================] - 0s 90ms/step - loss: 0.8776 - metrics_pearsonr: 0.0013 - val_loss: 1.1438 - val_metrics_pearsonr: 0.0018
# Epoch 493/500
# 3/3 [==============================] - 0s 84ms/step - loss: 0.8775 - metrics_pearsonr: 0.0013 - val_loss: 1.1455 - val_metrics_pearsonr: 0.0018
# Epoch 494/500
# 3/3 [==============================] - 0s 83ms/step - loss: 0.8780 - metrics_pearsonr: 0.0013 - val_loss: 1.1443 - val_metrics_pearsonr: 0.0018
# Epoch 495/500
# 3/3 [==============================] - 0s 85ms/step - loss: 0.8779 - metrics_pearsonr: 0.0013 - val_loss: 1.1414 - val_metrics_pearsonr: 0.0018
# Epoch 496/500
# 3/3 [==============================] - 0s 82ms/step - loss: 0.8770 - metrics_pearsonr: 0.0013 - val_loss: 1.1405 - val_metrics_pearsonr: 0.0018
# Epoch 497/500
# 3/3 [==============================] - 0s 85ms/step - loss: 0.8762 - metrics_pearsonr: 0.0013 - val_loss: 1.1415 - val_metrics_pearsonr: 0.0018
# Epoch 498/500
# 3/3 [==============================] - 0s 85ms/step - loss: 0.8753 - metrics_pearsonr: 0.0013 - val_loss: 1.1424 - val_metrics_pearsonr: 0.0018
# Epoch 499/500
# 3/3 [==============================] - 0s 76ms/step - loss: 0.8745 - metrics_pearsonr: 0.0013 - val_loss: 1.1414 - val_metrics_pearsonr: 0.0018
# Epoch 500/500
# 3/3 [==============================] - 0s 80ms/step - loss: 0.8735 - metrics_pearsonr: 0.0013 - val_loss: 1.1401 - val_metrics_pearsonr: 0.0018
# 1/1 [==============================] - 0s 223ms/step
# 1/1 [==============================] - 0s 212ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 184ms/step
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000021AB0EF3550> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 186ms/step
# 相关系数 0.9855892098146382
# WARNING:absl:Found untraced functions such as query_layer_call_fn, query_layer_call_and_return_conditional_losses, key_layer_call_fn, key_layer_call_and_return_conditional_losses, value_layer_call_fn while saving (showing 5 of 12). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: E:/huawei/huawei_gnss_wind_u_5min_hight_k5_1\assets
# INFO:tensorflow:Assets written to: E:/huawei/huawei_gnss_wind_u_5min_hight_k5_1\assets
# WARNING:absl:Found untraced functions such as query_layer_call_fn, query_layer_call_and_return_conditional_losses, key_layer_call_fn, key_layer_call_and_return_conditional_losses, value_layer_call_fn while saving (showing 5 of 12). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: E:/huawei/huawei_gnss_wind_u_5min_hight_k5_2\assets
# INFO:tensorflow:Assets written to: E:/huawei/huawei_gnss_wind_u_5min_hight_k5_2\assets
# WARNING:absl:Found untraced functions such as query_layer_call_fn, query_layer_call_and_return_conditional_losses, key_layer_call_fn, key_layer_call_and_return_conditional_losses, value_layer_call_fn while saving (showing 5 of 12). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: E:/huawei/huawei_gnss_wind_u_5min_hight_k5_3\assets
# INFO:tensorflow:Assets written to: E:/huawei/huawei_gnss_wind_u_5min_hight_k5_3\assets
# WARNING:absl:Found untraced functions such as query_layer_call_fn, query_layer_call_and_return_conditional_losses, key_layer_call_fn, key_layer_call_and_return_conditional_losses, value_layer_call_fn while saving (showing 5 of 12). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: E:/huawei/huawei_gnss_wind_u_5min_hight_k5_4\assets
# INFO:tensorflow:Assets written to: E:/huawei/huawei_gnss_wind_u_5min_hight_k5_4\assets
# WARNING:absl:Found untraced functions such as query_layer_call_fn, query_layer_call_and_return_conditional_losses, key_layer_call_fn, key_layer_call_and_return_conditional_losses, value_layer_call_fn while saving (showing 5 of 12). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: E:/huawei/huawei_gnss_wind_u_5min_hight_k5_5\assets
# INFO:tensorflow:Assets written to: E:/huawei/huawei_gnss_wind_u_5min_hight_k5_5\assets

# %%
print(np.nanmean(np.abs(testy-predicty)))
# Out:
# 0.73865485

# %%
testy=np.array(testy).reshape(testy.shape[0],18,7)
predicty=np.array(predicty).reshape(predicty.shape[0],18,7)

# %%
print(testy.shape,predicty.shape)
# Out:
# (4341, 18, 7) (4341, 18, 7)

# %%
times=np.arange(4341)
testy_u=testy
predicty_u=predicty
levels=[110,760,1460,3010,4200,5570,7160]
station=np.array(wind_file['station'])

# %%
import numpy as np
import xarray as xr
import os



dim_names = ('times', 'station', 'levels')


testy_u_da = xr.DataArray(
    data=testy_u,
    coords={
        'times': times,
        'station': station,
        'levels': levels
    },
    dims=dim_names,
    name='testy_u' 
)


predicty_u_da = xr.DataArray(
    data=predicty_u,
    coords={
        'times': times,
        'station': station,
        'levels': levels
    },
    dims=dim_names,
    name='predicty_u'
)

testy_u_da.to_netcdf('E:/huawei/result/huawei_Transformer_5min_k5_gnss_to_wind_testy_u_hight.nc')
predicty_u_da.to_netcdf('E:/huawei/result/huawei_Transformer_5min_k5_gnss_to_wind_predicty_u_hight.nc')

# %%
import numpy as np
import xarray as xr
testy_u_file=xr.open_dataset('E:/huawei/result/huawei_Transformer_5min_k5_gnss_to_wind_testy_u_hight.nc')
predicty_u_file=xr.open_dataset('E:/huawei/result/huawei_Transformer_5min_k5_gnss_to_wind_predicty_u_hight.nc')
testy_u=np.array(testy_u_file['testy_u'])
predicty_u=np.array(predicty_u_file['predicty_u'])

# %%
#CDF匹配
def Auto_cdf_matching(vx,vy):
    import numpy as np
    from scipy.interpolate import InterpolatedUnivariateSpline
    from scipy.optimize import curve_fit

    if np.array(vx).ndim==1:
        vx_cdf = (np.arange(len(vx)) +  1) / (len(vx))
        vy_cdf = (np.arange(len(vy)) +  1) / (len(vy))
        
        spl = InterpolatedUnivariateSpline(vx_cdf, np.sort(vx))
        vx_interp = spl(vy_cdf)
        
        def func(x, a, b, c, d):
            return a*x + b*x**2 + c*x**3 + d
        
        popt = curve_fit(func, vx_interp, np.sort(vy))[0]
        
        matched_vx = func(vx, *popt)
    elif np.array(vx).ndim==2:
        matched_vx=np.zeros((vx.shape[0],vx.shape[1]))
        for i in range(vx.shape[1]):
            vx_cdf = (np.arange(len(vx[:,i])) +  1) / (len(vx[:,i]))
            vy_cdf = (np.arange(len(vy[:,i])) +  1) / (len(vy[:,i]))
            
            spl = InterpolatedUnivariateSpline(vx_cdf, np.sort(vx[:,i]))
            vx_interp = spl(vy_cdf)
            
            def func(x, a, b, c, d):
                return a*x + b*x**2 + c*x**3 + d
            
            popt = curve_fit(func, vx_interp, np.sort(vy[:,i]))[0]
            
            matched_vx[:,i] = func(vx[:,i], *popt)
    elif np.array(vx).ndim==3:
        matched_vx=np.zeros((vx.shape[0],vx.shape[1],vx.shape[2]))
        for i in range(vx.shape[1]):
            for j in range(vx.shape[2]):
                vx_cdf = (np.arange(len(vx[:,i,j])) +  1) / (len(vx[:,i,j]))
                vy_cdf = (np.arange(len(vy[:,i,j])) +  1) / (len(vy[:,i,j]))
                
                spl = InterpolatedUnivariateSpline(vx_cdf, np.sort(vx[:,i,j]))
                vx_interp = spl(vy_cdf)
                
                def func(x, a, b, c, d):
                    return a*x + b*x**2 + c*x**3 + d
                
                popt = curve_fit(func, vx_interp, np.sort(vy[:,i,j]))[0]
                
                matched_vx[:,i,j] = func(vx[:,i,j], *popt)
    elif np.array(vx).ndim==4:
        matched_vx=np.zeros((vx.shape[0],vx.shape[1],vx.shape[2],vx.shape[3]))
        for i in range(vx.shape[1]):
            for j in range(vx.shape[2]):
                for k in range(vx.shape[3]):
                    vx_cdf = (np.arange(len(vx[:,i,j,k])) +  1) / (len(vx[:,i,j,k]))
                    vy_cdf = (np.arange(len(vy[:,i,j,k])) +  1) / (len(vy[:,i,j,k]))
                    
                    spl = InterpolatedUnivariateSpline(vx_cdf, np.sort(vx[:,i,j,k]))
                    vx_interp = spl(vy_cdf)
                    
                    def func(x, a, b, c, d):
                        return a*x + b*x**2 + c*x**3 + d
                    
                    popt = curve_fit(func, vx_interp, np.sort(vy[:,i,j,k]))[0]
                    
                    matched_vx[:,i,j,k] = func(vx[:,i,j,k], *popt)

    return matched_vx

# %%
from sklearn.model_selection import train_test_split
import Auto_paint_self
np.random.seed(25)
trainy,testy,trainx,testx = train_test_split(np.array(vy).reshape(-1,18,7),vx,test_size=0.2,random_state=25)
predicty_u=Auto_cdf_matching(np.array(predicty_u),trainy[np.random.randint(0,trainy.shape[0], predicty_u.shape[0]),:,:])

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,mean_absolute_percentage_error
from scipy.stats import pearsonr
import numpy as np
import math
from tqdm import tqdm
from metpy.calc import wind_direction,wind_speed
from metpy.units import units
u_rmse=np.zeros((predicty_u.shape[1],predicty_u.shape[2]))
u_mae=np.zeros((predicty_u.shape[1],predicty_u.shape[2]))
u_pearson=np.zeros((predicty_u.shape[1],predicty_u.shape[2]))
u_mape=np.zeros((predicty_u.shape[1],predicty_u.shape[2]))
for i in tqdm(range(predicty_u.shape[1])):
    for j in range(predicty_u.shape[2]):
        u_rmse[i,j]=mean_squared_error(testy_u[:,i,j],predicty_u[:,i,j])
        u_pearson[i,j],_=pearsonr(testy_u[:,i,j],predicty_u[:,i,j])
        u_mae[i,j]=mean_absolute_error(testy_u[:,i,j],predicty_u[:,i,j])
        u_mape[i,j]=mean_absolute_percentage_error(testy_u[:,i,j],predicty_u[:,i,j])
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 18/18 [00:00<00:00, 66.20it/s]

# %%
print(np.nanmean(u_mae,axis=(0)))
print(np.nanmean(u_mae))
# Out:
# [0.65696095 0.60308396 0.69009008 0.7721113  0.84971948 0.82609872
#  0.96829512]
# 0.7666228005162684

# %%
print(np.nanmean(u_rmse,axis=(0)))
print(np.nanmean(u_rmse))
# Out:
# [0.90312404 0.69303932 0.92980738 1.26566886 1.86266186 1.67787327
#  2.45948026]
# 1.398807857442296

# %%
u_p=np.sqrt(u_rmse)/(np.nanmax(testy_u,axis=0)-np.nanmin(testy_u,axis=0))
#v_p=np.sqrt(v_rmse)/(np.nanmax(testy_v,axis=0)-np.nanmin(testy_v,axis=0))
#wind_p=np.sqrt(wind_rmse)/(np.nanmax(np.sqrt(testy_u**2+testy_v**2),axis=0)-np.nanmin(np.sqrt(testy_u**2+testy_v**2),axis=0))
print(np.nanmean(u_p,axis=(0)))
print(np.nanmean(u_p))
# Out:
# [0.02694835 0.02177323 0.01935475 0.01800701 0.02185547 0.01939678
#  0.02150192]
# 0.021262501204146637

# %%
import numpy as np
import xarray as xr
import os



dim_names = ('times', 'station', 'levels')

predicty_u_da_cdf = xr.DataArray(
    data=predicty_u,
    coords={
        'times': times,
        'station': station,
        'levels': levels
    },
    dims=dim_names,
    name='predicty_u'
)

predicty_u_da.to_netcdf('E:/huawei/result/huawei_Transformer_5min_k5_gnss_to_wind_predicty_u_cdf_hight.nc')
